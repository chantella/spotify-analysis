# %%
import billboard
from datetime import timedelta, date
import time
d = {}
def daterange(start_date, end_date):
    for n in range(int ((end_date - start_date).days)):
        yield start_date + timedelta(n)

start_date = date(2018, 1, 7)
end_date = date(2019, 11, 26)
fileSong = open("liya.txt", "x")
for single_date in daterange(start_date, end_date):
    if single_date.weekday() == 0:
        day = single_date.strftime("%Y-%m-%d")
        
        while True:
            try:
                chart = billboard.ChartData('hot-100', date=day)
                #chart2 = billboard.ChartData('artist-100', date=day)
                break
            except:
                print('waiting 60 sec...')
                time.sleep(60)
        
        for s in chart:
            fileSong = open("liya.txt", "a")
            fileSong.write(s.title + ": " + s.artist + "\n")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-1-2bcbd3a5b9da> in <module>
#       9 start_date = date(2018, 1, 7)
#      10 end_date = date(2019, 11, 26)
# ---> 11 fileSong = open("liya.txt", "x")
#      12 for single_date in daterange(start_date, end_date):
#      13     if single_date.weekday() == 0:
#
# FileExistsError: [Errno 17] File exists: 'liya.txt'

# %%
artistArray = []
for line in open("Songtest.txt"):
    data = line.split(": ")
    artist = data[1]
    index = line.find('\\')
    if "&" not in line and " x " not in line and "Featuring" not in line:
        artistArray.append(artist[0: index])
artistSet = set(artistArray)

print(artistSet)
# Out:
# {'Fifth Harmony', 'Tim McGraw', 'Justin Timberlake', 'SZA', 'Rihanna', 'Ella Henderson', 'Eminem', 'Amine', 'Yo Gotti', 'Eric Church', '6ix9ine', 'James Arthur', 'Lorde', 'Mr. Probz', 'Brett Young', 'Sia', 'The Weeknd', 'Becky G', 'Kip Moore', 'YBN Nahmir', 'Wham!', 'Ariana Grande', 'Rae Sremmurd', 'Lil Pump', 'Demi Lovato', 'Dylan Scott', 'Shawn Mendes', 'Camila Cabello', 'Kelsea Ballerini', 'Lee Brice', 'P!nk', 'Drake', 'Dua Lipa', 'Hozier', '21 Savage', 'Russell Dickerson', 'Milky Chance', 'Jessie J', 'Nick Jonas', 'Julia Michaels', 'Jason Aldean', 'Lady Gaga', 'Brothers Osborne', 'Lil Peep', 'Russ', 'Colbie Caillat', 'Chris Lane', 'Blake Shelton', 'Post Malone', 'Florida Georgia Line', 'Linkin Park', 'A Boogie Wit da Hoodie', 'Jon Bellion', 'Kelly Clarkson', 'Nicky Jam', 'Andy Williams', 'Halsey', 'Dustin Lynch', 'Carly Pearce', 'YoungBoy Never Broke Again', 'Bhad Bhabie', 'Niall Horan', 'Brenda Lee', 'Scotty McCreery', 'Keith Urban', 'Sophia Grace', 'blackbear', 'Rascal Flatts', 'Tank', 'Justin Moore', 'Miley Cyrus', 'Fetty Wap', 'Garth Brooks', 'Mariah Carey', 'LANCO', 'Future', 'Granger Smith', 'Tyler Farr', 'Alessia Cara', 'WALK THE MOON', 'One Direction', 'OneRepublic', 'Kenny Chesney', 'Midland', 'JAY-Z', 'G-Eazy', 'Luke Combs', 'RaeLynn', 'Cardi B', 'Tay-K', 'Brad Paisley', 'John Legend', 'Burl Ives', 'Lil Xan', 'Lil Uzi Vert', 'Devin Dawson', 'Meek Mill', 'Charli XCX', 'Zayn / Taylor Swift', 'Billy Currington', 'Nat King Cole', 'Walker Hayes', 'Kelsea Ballerin', 'Jon Pardi', 'Ed Sheeran', 'Beyonce', 'Liam Payne', 'Lady Antebellum', 'Carrie Underwood', 'Imagine Dragons', 'Chris Janson', 'Trey Songz', 'Darius Rucker', 'Parmalee', 'Lil Baby', 'Luke Bryan', 'BTS', 'Sam Smith', 'August Alsina', 'Bruno Mars', 'Brett Eldredge', 'NF', 'Tove Lo', 'Vance Joy', 'Justin Bieber + BloodPop', 'Jason Derulo', 'Kendrick Lamar', 'Pentatonix', 'Kesha', 'Fergie', 'Maluma', 'Kane Brown', 'twenty one pilots', 'Randy Houser', 'Jacquees', 'Chris Young', 'Chase Bryant', 'Taylor Swift', 'Ellie Goulding', 'O.T. Genasis', 'Sam Hunt', 'Dierks Bentley', 'DeJ Loaf', 'Jake Owen', 'Cole Swindell', 'Khalid', 'Zac Brown Band', 'Selena Gomez X Marshmello', 'Tee Grizzley', 'The Chainsmokers', 'AJR', 'Playboi Carti', 'The Revivalists', 'Bobby Shmurda', 'I Prevail', 'Charlie Puth', 'Chris Stapleton', 'Chris Brown', 'Kodak Black', 'Hailee Steinfeld', 'Selena Gomez', 'Big Sean', 'Portugal. The Man', 'Nicki Minaj', 'Chloe Kohanski', 'Fall Out Boy', 'Childish Gambino', 'Thomas Rhett', 'Meghan Trainor', 'Maroon 5', 'Old Dominion', 'J. Cole', 'Maren Morris', 'Sheppard', 'Descendants 2 Cast', 'Travis Scott', 'Romeo Santos', 'XXXTENTACION', 'MAGIC!'}

# %%
#Read data from text file and create a set containing all songs
sFile = open("Songtest.txt", "r")

for line in sFile:
    line = line.strip()
    splitLine = line.split(": ")
    #songSet.add(song)
    
    print(splitLine)
# Out:
# ['Blank Space', 'Taylor Swift']
# ['Uptown Funk!', 'Mark Ronson Featuring Bruno Mars']
# ['Take Me To Church', 'Hozier']
# ['Lips Are Movin', 'Meghan Trainor']
# ['All About That Bass', 'Meghan Trainor']
# ["I'm Not The Only One", 'Sam Smith']
# ['Thinking Out Loud', 'Ed Sheeran']
# ['Animals', 'Maroon 5']
# ['Shake It Off', 'Taylor Swift']
# ['Jealous', 'Nick Jonas']
# ['Love Me Harder', 'Ariana Grande & The Weeknd']
# ["I Don't F**k With You", 'Big Sean Featuring E-40']
# ['The Heart Wants What It Wants', 'Selena Gomez']
# ['Centuries', 'Fall Out Boy']
# ['Only', 'Nicki Minaj Featuring Drake, Lil Wayne & Chris Brown']
# ['The Hanging Tree', 'James Newton Howard Featuring Jennifer Lawrence']
# ['Bang Bang', 'Jessie J, Ariana Grande & Nicki Minaj']
# ['Tuesday', 'I LOVE MAKONNEN Featuring Drake']
# ['No Type', 'Rae Sremmurd']
# ['Habits (Stay High)', 'Tove Lo']
# ['Waves', 'Mr. Probz']
# ["Don't", 'Ed Sheeran']
# ['Hot Boy', 'Bobby Shmurda']
# ['Stay With Me', 'Sam Smith']
# ['7/11', 'Beyonce']
# ['CoCo', 'O.T. Genasis']
# ['Beg For It', 'Iggy Azalea Featuring M0']
# ["Don't Tell 'Em", 'Jeremih Featuring YG']
# ['Black Widow', 'Iggy Azalea Featuring Rita Ora']
# ['Trumpets', 'Jason Derulo']
# ['Blame', 'Calvin Harris Featuring John Newman']
# ['Riptide', 'Vance Joy']
# ["I Don't Mind", 'Usher Featuring Juicy J']
# ['Night Changes', 'One Direction']
# ['Rude', 'MAGIC!']
# ['Heroes (We Could Be)', 'Alesso Featuring Tove Lo']
# ['Something In The Water', 'Carrie Underwood']
# ['L.A.LOVE (la la)', 'Fergie']
# ['Chandelier', 'Sia']
# ['Sledgehammer', 'Fifth Harmony']
# ['Shotgun Rider', 'Tim McGraw']
# ['Lifestyle', 'Rich Gang Featuring Young Thug & Rich Homie Quan']
# ['Ghost', 'Ella Henderson']
# ['Rather Be', 'Clean Bandit Featuring Jess Glynne']
# ['Try Me', 'DeJ Loaf']
# ['Time Of Our Lives', 'Pitbull & Ne-Yo']
# ['Stolen Dance', 'Milky Chance']
# ['Anaconda', 'Nicki Minaj']
# ['Earned It (Fifty Shades Of Grey)', 'The Weeknd']
# ['Santa Tell Me', 'Ariana Grande']
# ['Steal My Girl', 'One Direction']
# ['Talladega', 'Eric Church']
# ['Sun Daze', 'Florida Georgia Line']
# ['I Bet My Life', 'Imagine Dragons']
# ['Hold You Down', 'DJ Khaled Featuring Chris Brown, August Alsina, Future & Jeremih']
# ['Touchin, Lovin', 'Trey Songz Featuring Nicki Minaj']
# ['I See You', 'Luke Bryan']
# ['G.D.F.R.', 'Flo Rida Featuring Sage The Gemini & Lookas']
# ['Feeling Myself', 'Nicki Minaj Featuring Beyonce']
# ['Drinking Class', 'Lee Brice']
# ['God Made Girls', 'RaeLynn']
# ['I Lived', 'OneRepublic']
# ['Perfect Storm', 'Brad Paisley']
# ['Dear Future Husband', 'Meghan Trainor']
# ['Often', 'The Weeknd']
# ['Try', 'Colbie Caillat']
# ['Mary, Did You Know?', 'Pentatonix']
# ['Masterpiece', 'Jessie J']
# ['Lonely Tonight', 'Blake Shelton Featuring Ashley Monroe']
# ['Dangerous', 'David Guetta Featuring Sam Martin']
# ['Prayer In C', 'Lillywood & Robin Schulz']
# ['Body Language', 'Kid Ink Featuring Usher & Tinashe']
# ['She Knows', 'Ne-Yo Featuring Juicy J']
# ["Just Gettin' Started", 'Jason Aldean']
# ['***Flawless', 'Beyonce Featuring Nicki Minaj Or Chimamanda Ngozi Adichie']
# ['Make Me Wanna', 'Thomas Rhett']
# ['Lonely Eyes', 'Chris Young']
# ['Bad Blood', 'Taylor Swift Featuring Kendrick Lamar']
# ['In Your Arms', 'Nico & Vinz']
# ['Bed Of Lies', 'Nicki Minaj Featuring Skylar Grey']
# ["Til It's Gone", 'Kenny Chesney']
# ['Somewhere In My Car', 'Keith Urban']
# ['Mean To Me', 'Brett Eldredge']
# ['Style', 'Taylor Swift']
# ['Close Your Eyes', 'Parmalee']
# ['Homegrown Honey', 'Darius Rucker']
# ["Burnin' Up", 'Jessie J Featuring 2 Chainz']
# ['No Love', 'August Alsina']
# ['Shut Up And Dance', 'WALK THE MOON']
# ['Yellow Flicker Beat', 'Lorde']
# ['Break The Rules', 'Charli XCX']
# ['Something Big', 'Shawn Mendes']
# ['Stuck On A Feeling', 'Prince Royce Featuring Snoop Dogg']
# ['Apparently', 'J. Cole']
# ['Bad B*tch', 'French Montana Featuring Jeremih']
# ['Like A Cowboy', 'Randy Houser']
# ['Neon Light', 'Blake Shelton']
# ["Can't Stop Dancin'", 'Becky G']
# ['Shell Shocked', 'Juicy J, Wiz Khalifa & Ty Dolla $ign Featuring Kill The Noise & Madsonik']
# ['Title', 'Meghan Trainor']
# ['Uptown Funk!', 'Mark Ronson Featuring Bruno Mars']
# ['Blank Space', 'Taylor Swift']
# ['Take Me To Church', 'Hozier']
# ['Thinking Out Loud', 'Ed Sheeran']
# ['Lips Are Movin', 'Meghan Trainor']
# ['All About That Bass', 'Meghan Trainor']
# ['Shake It Off', 'Taylor Swift']
# ["I'm Not The Only One", 'Sam Smith']
# ['Jealous', 'Nick Jonas']
# ['Animals', 'Maroon 5']
# ['Love Me Harder', 'Ariana Grande & The Weeknd']
# ["I Don't F**k With You", 'Big Sean Featuring E-40']
# ['Centuries', 'Fall Out Boy']
# ['The Heart Wants What It Wants', 'Selena Gomez']
# ['Bang Bang', 'Jessie J, Ariana Grande & Nicki Minaj']
# ['Only', 'Nicki Minaj Featuring Drake, Lil Wayne & Chris Brown']
# ['The Hanging Tree', 'James Newton Howard Featuring Jennifer Lawrence']
# ['Tuesday', 'I LOVE MAKONNEN Featuring Drake']
# ['Stay With Me', 'Sam Smith']
# ['Habits (Stay High)', 'Tove Lo']
# ['No Type', 'Rae Sremmurd']
# ['Waves', 'Mr. Probz']
# ["Don't", 'Ed Sheeran']
# ['7/11', 'Beyonce']
# ['Hot Boy', 'Bobby Shmurda']
# ['CoCo', 'O.T. Genasis']
# ['Rude', 'MAGIC!']
# ["I Don't Mind", 'Usher Featuring Juicy J']
# ['Beg For It', 'Iggy Azalea Featuring M0']
# ["Don't Tell 'Em", 'Jeremih Featuring YG']
# ['Black Widow', 'Iggy Azalea Featuring Rita Ora']
# ['Blame', 'Calvin Harris Featuring John Newman']
# ['Time Of Our Lives', 'Pitbull & Ne-Yo']
# ['Night Changes', 'One Direction']
# ['Only One', 'Kanye West Featuring Paul McCartney']
# ['Riptide', 'Vance Joy']
# ['Chandelier', 'Sia']
# ['L.A.LOVE (la la)', 'Fergie']
# ['Heroes (We Could Be)', 'Alesso Featuring Tove Lo']
# ['Trumpets', 'Jason Derulo']
# ['Ghost', 'Ella Henderson']
# ['Something In The Water', 'Carrie Underwood']
# ['Shotgun Rider', 'Tim McGraw']
# ['Rather Be', 'Clean Bandit Featuring Jess Glynne']
# ['Stolen Dance', 'Milky Chance']
# ['Sledgehammer', 'Fifth Harmony']
# ['Try Me', 'DeJ Loaf']
# ['Anaconda', 'Nicki Minaj']
# ['Talladega', 'Eric Church']
# ['Lifestyle', 'Rich Gang Featuring Young Thug & Rich Homie Quan']
# ['Sun Daze', 'Florida Georgia Line']
# ['Touchin, Lovin', 'Trey Songz Featuring Nicki Minaj']
# ['I Lived', 'OneRepublic']
# ['G.D.F.R.', 'Flo Rida Featuring Sage The Gemini & Lookas']
# ['Steal My Girl', 'One Direction']
# ['I See You', 'Luke Bryan']
# ['Perfect Storm', 'Brad Paisley']
# ['I Bet My Life', 'Imagine Dragons']
# ['Feeling Myself', 'Nicki Minaj Featuring Beyonce']
# ['Prayer In C', 'Lillywood & Robin Schulz']
# ['She Knows', 'Ne-Yo Featuring Juicy J']
# ['Lonely Tonight', 'Blake Shelton Featuring Ashley Monroe']
# ['Drinking Class', 'Lee Brice']
# ['Hold You Down', 'DJ Khaled Featuring Chris Brown, August Alsina, Future & Jeremih']
# ['Try', 'Colbie Caillat']
# ["Just Gettin' Started", 'Jason Aldean']
# ['God Made Girls', 'RaeLynn']
# ["Til It's Gone", 'Kenny Chesney']
# ['Often', 'The Weeknd']
# ['Dangerous', 'David Guetta Featuring Sam Martin']
# ['Style', 'Taylor Swift']
# ['Make Me Wanna', 'Thomas Rhett']
# ['Lonely Eyes', 'Chris Young']
# ['Close Your Eyes', 'Parmalee']
# ['Mean To Me', 'Brett Eldredge']
# ['Body Language', 'Kid Ink Featuring Usher & Tinashe']
# ['Shut Up And Dance', 'WALK THE MOON']
# ['Stuck On A Feeling', 'Prince Royce Featuring Snoop Dogg']
# ['Somewhere In My Car', 'Keith Urban']
# ['Something Big', 'Shawn Mendes']
# ['***Flawless', 'Beyonce Featuring Nicki Minaj Or Chimamanda Ngozi Adichie']
# ['Homegrown Honey', 'Darius Rucker']
# ['Like A Cowboy', 'Randy Houser']
# ['Dear Future Husband', 'Meghan Trainor']
# ['In Your Arms', 'Nico & Vinz']
# ['Apparently', 'J. Cole']
# ['Earned It (Fifty Shades Of Grey)', 'The Weeknd']
# ['No Love', 'August Alsina']
# ['Neon Light', 'Blake Shelton']
# ['Outside', 'Calvin Harris Featuring Ellie Goulding']
# ['Bed Of Lies', 'Nicki Minaj Featuring Skylar Grey']
# ['Throw Sum Mo', 'Rae Sremmurd Featuring Nicki Minaj & Young Thug']
# ['Take Your Time', 'Sam Hunt']
# ['Yellow Flicker Beat', 'Lorde']
# ["What We Ain't Got", 'Jake Owen']
# ['Geronimo', 'Sheppard']
# ['A Guy Walks Into A Bar', 'Tyler Farr']
# ['Take It On Back', 'Chase Bryant']
# ["Ain't Worth The Whiskey", 'Cole Swindell']
# ['I Mean It', 'G-Eazy Featuring Remo']
# ['Uptown Funk!', 'Mark Ronson Featuring Bruno Mars']
# ['Blank Space', 'Taylor Swift']
# ['Take Me To Church', 'Hozier']
# ['Thinking Out Loud', 'Ed Sheeran']
# ["I'm Not The Only One", 'Sam Smith']
# ['Lips Are Movin', 'Meghan Trainor']
# ['Jealous', 'Nick Jonas']
# ['Love Me Harder', 'Ariana Grande & The Weeknd']
# ['Shake It Off', 'Taylor Swift']
# ['All About That Bass', 'Meghan Trainor']
# ['Animals', 'Maroon 5']
# ["I Don't F**k With You", 'Big Sean Featuring E-40']
# ['The Heart Wants What It Wants', 'Selena Gomez']
# ['The Hanging Tree', 'James Newton Howard Featuring Jennifer Lawrence']
# ['Centuries', 'Fall Out Boy']
# ['Only', 'Nicki Minaj Featuring Drake, Lil Wayne & Chris Brown']
# ['Elastic Heart', 'Sia']
# ['No Type', 'Rae Sremmurd']
# ['Tuesday', 'I LOVE MAKONNEN Featuring Drake']
# ['7/11', 'Beyonce']
# ['Stay With Me', 'Sam Smith']
# ['Waves', 'Mr. Probz']
# ["I Don't Mind", 'Usher Featuring Juicy J']
# ['Habits (Stay High)', 'Tove Lo']
# ['Bang Bang', 'Jessie J, Ariana Grande & Nicki Minaj']
# ['CoCo', 'O.T. Genasis']
# ["Don't", 'Ed Sheeran']
# ['Ghost', 'Ella Henderson']
# ['Hot Boy', 'Bobby Shmurda']
# ['Chandelier', 'Sia']
# ['Heroes (We Could Be)', 'Alesso Featuring Tove Lo']
# ['Blame', 'Calvin Harris Featuring John Newman']
# ['Riptide', 'Vance Joy']
# ['I Lived', 'OneRepublic']
# ['Time Of Our Lives', 'Pitbull & Ne-Yo']
# ["Don't Tell 'Em", 'Jeremih Featuring YG']
# ['Black Widow', 'Iggy Azalea Featuring Rita Ora']
# ['Rude', 'MAGIC!']
# ['Night Changes', 'One Direction']
# ['Ayo', 'Chris Brown & Tyga']
# ['Something In The Water', 'Carrie Underwood']
# ['Beg For It', 'Iggy Azalea Featuring M0']
# ['Stolen Dance', 'Milky Chance']
# ['Sledgehammer', 'Fifth Harmony']
# ['Love Me Like You Do', 'Ellie Goulding']
# ['Rather Be', 'Clean Bandit Featuring Jess Glynne']
# ['Try Me', 'DeJ Loaf']
# ['Shotgun Rider', 'Tim McGraw']
# ['G.D.F.R.', 'Flo Rida Featuring Sage The Gemini & Lookas']
# ['Talladega', 'Eric Church']
# ['I See You', 'Luke Bryan']
# ['Sun Daze', 'Florida Georgia Line']
# ['Prayer In C', 'Lillywood & Robin Schulz']
# ['Only One', 'Kanye West Featuring Paul McCartney']
# ['L.A.LOVE (la la)', 'Fergie']
# ['She Knows', 'Ne-Yo Featuring Juicy J']
# ['Perfect Storm', 'Brad Paisley']
# ['Touchin, Lovin', 'Trey Songz Featuring Nicki Minaj']
# ['Lonely Tonight', 'Blake Shelton Featuring Ashley Monroe']
# ['Hold You Down', 'DJ Khaled Featuring Chris Brown, August Alsina, Future & Jeremih']
# ['Feeling Myself', 'Nicki Minaj Featuring Beyonce']
# ["Til It's Gone", 'Kenny Chesney']
# ['Stuck On A Feeling', 'Prince Royce Featuring Snoop Dogg']
# ['I Bet My Life', 'Imagine Dragons']
# ['Often', 'The Weeknd']
# ['Make Me Wanna', 'Thomas Rhett']
# ['Drinking Class', 'Lee Brice']
# ["Just Gettin' Started", 'Jason Aldean']
# ['Steal My Girl', 'One Direction']
# ['God Made Girls', 'RaeLynn']
# ['Shut Up And Dance', 'WALK THE MOON']
# ['Style', 'Taylor Swift']
# ['Lonely Eyes', 'Chris Young']
# ['Mean To Me', 'Brett Eldredge']
# ['Take Your Time', 'Sam Hunt']
# ['Outside', 'Calvin Harris Featuring Ellie Goulding']
# ['Irresistible', 'Fall Out Boy']
# ['Like A Cowboy', 'Randy Houser']
# ['Apparently', 'J. Cole']
# ['Homegrown Honey', 'Darius Rucker']
# ['Dangerous', 'David Guetta Featuring Sam Martin']
# ['Earned It (Fifty Shades Of Grey)', 'The Weeknd']
# ['Body Language', 'Kid Ink Featuring Usher & Tinashe']
# ['Somewhere In My Car', 'Keith Urban']
# ['Throw Sum Mo', 'Rae Sremmurd Featuring Nicki Minaj & Young Thug']
# ['Close Your Eyes', 'Parmalee']
# ['Best Friends', 'Sophia Grace']
# ['***Flawless', 'Beyonce Featuring Nicki Minaj Or Chimamanda Ngozi Adichie']
# ["Ain't Worth The Whiskey", 'Cole Swindell']
# ['Blank Space', 'I Prevail']
# ['No Love', 'August Alsina']
# ['Take It On Back', 'Chase Bryant']
# ['Geronimo', 'Sheppard']
# ["What We Ain't Got", 'Jake Owen']
# ['Dear Future Husband', 'Meghan Trainor']
# ['Not For Long', 'B.o.B Featuring Trey Songz']
# ['A Guy Walks Into A Bar', 'Tyler Farr']
# ['Post To Be', 'Omarion Featuring Chris Brown & Jhene Aiko']
# ['Neon Light', 'Blake Shelton']
# ['All About It', 'Hoodie Allen Featuring Ed Sheeran']
# ['Uptown Funk!', 'Mark Ronson Featuring Bruno Mars']
# ['Thinking Out Loud', 'Ed Sheeran']
# ['Blank Space', 'Taylor Swift']
# ['Take Me To Church', 'Hozier']
# ['Shake It Off', 'Taylor Swift']
# ['Lips Are Movin', 'Meghan Trainor']
# ["I'm Not The Only One", 'Sam Smith']
# ['Sugar', 'Maroon 5']
# ['Jealous', 'Nick Jonas']
# ['All About That Bass', 'Meghan Trainor']
# ['Love Me Harder', 'Ariana Grande & The Weeknd']
# ['Centuries', 'Fall Out Boy']
# ['The Hanging Tree', 'James Newton Howard Featuring Jennifer Lawrence']
# ["I Don't F**k With You", 'Big Sean Featuring E-40']
# ['The Heart Wants What It Wants', 'Selena Gomez']
# ['Animals', 'Maroon 5']
# ["I Don't Mind", 'Usher Featuring Juicy J']
# ['7/11', 'Beyonce']
# ['Only', 'Nicki Minaj Featuring Drake, Lil Wayne & Chris Brown']
# ['No Type', 'Rae Sremmurd']
# ['Tuesday', 'I LOVE MAKONNEN Featuring Drake']
# ['Ghost', 'Ella Henderson']
# ['Bang Bang', 'Jessie J, Ariana Grande & Nicki Minaj']
# ['Time Of Our Lives', 'Pitbull & Ne-Yo']
# ['Waves', 'Mr. Probz']
# ['CoCo', 'O.T. Genasis']
# ['Stay With Me', 'Sam Smith']
# ['Habits (Stay High)', 'Tove Lo']
# ['Elastic Heart', 'Sia']
# ['Riptide', 'Vance Joy']
# ["Don't", 'Ed Sheeran']
# ['I Lived', 'OneRepublic']
# ['Chandelier', 'Sia']
# ['Hot Boy', 'Bobby Shmurda']
# ['Heroes (We Could Be)', 'Alesso Featuring Tove Lo']
# ['Love Me Like You Do', 'Ellie Goulding']
# ['Heartbeat Song', 'Kelly Clarkson']
# ['G.D.F.R.', 'Flo Rida Featuring Sage The Gemini & Lookas']
# ["Don't Tell 'Em", 'Jeremih Featuring YG']
# ['Blame', 'Calvin Harris Featuring John Newman']
# ['Something In The Water', 'Carrie Underwood']
# ['Night Changes', 'One Direction']
# ['Rude', 'MAGIC!']
# ['Black Widow', 'Iggy Azalea Featuring Rita Ora']
# ['I See You', 'Luke Bryan']
# ['Talladega', 'Eric Church']
# ['Prayer In C', 'Lillywood & Robin Schulz']
# ['Homegrown', 'Zac Brown Band']
# ['Sun Daze', 'Florida Georgia Line']
# ['She Knows', 'Ne-Yo Featuring Juicy J']
# ['Sledgehammer', 'Fifth Harmony']
# ['Style', 'Taylor Swift']
# ['Try Me', 'DeJ Loaf']
# ['Lonely Tonight', 'Blake Shelton Featuring Ashley Monroe']
# ['Shotgun Rider', 'Tim McGraw']
# ['Stuck On A Feeling', 'Prince Royce Featuring Snoop Dogg']
# ['Beg For It', 'Iggy Azalea Featuring M0']
# ['Outside', 'Calvin Harris Featuring Ellie Goulding']
# ['Make Me Wanna', 'Thomas Rhett']
# ["Til It's Gone", 'Kenny Chesney']
# ['Feeling Myself', 'Nicki Minaj Featuring Beyonce']
# ['Touchin, Lovin', 'Trey Songz Featuring Nicki Minaj']
# ['Drinking Class', 'Lee Brice']
# ["Just Gettin' Started", 'Jason Aldean']
# ['Perfect Storm', 'Brad Paisley']
# ['L.A.LOVE (la la)', 'Fergie']
# ['Often', 'The Weeknd']
# ['Hold You Down', 'DJ Khaled Featuring Chris Brown, August Alsina, Future & Jeremih']
# ['I Bet My Life', 'Imagine Dragons']
# ['Earned It (Fifty Shades Of Grey)', 'The Weeknd']
# ['Take Your Time', 'Sam Hunt']
# ['Ayo', 'Chris Brown & Tyga']
# ['Uma Thurman', 'Fall Out Boy']
# ['Shut Up And Dance', 'WALK THE MOON']
# ['Mean To Me', 'Brett Eldredge']
# ['God Made Girls', 'RaeLynn']
# ['Like A Cowboy', 'Randy Houser']
# ['All About It', 'Hoodie Allen Featuring Ed Sheeran']
# ['Lonely Eyes', 'Chris Young']
# ['Homegrown Honey', 'Darius Rucker']
# ['Apparently', 'J. Cole']
# ['Steal My Girl', 'One Direction']
# ["Ain't Worth The Whiskey", 'Cole Swindell']
# ['Dear Future Husband', 'Meghan Trainor']
# ['Only One', 'Kanye West Featuring Paul McCartney']
# ['Take It On Back', 'Chase Bryant']
# ['Throw Sum Mo', 'Rae Sremmurd Featuring Nicki Minaj & Young Thug']
# ['Geronimo', 'Sheppard']
# ['Body Language', 'Kid Ink Featuring Usher & Tinashe']
# ['Dangerous', 'David Guetta Featuring Sam Martin']
# ['Post To Be', 'Omarion Featuring Chris Brown & Jhene Aiko']
# ['Glory', 'Common & John Legend']
# ['***Flawless', 'Beyonce Featuring Nicki Minaj Or Chimamanda Ngozi Adichie']
# ["What We Ain't Got", 'Jake Owen']
# ['Not For Long', 'B.o.B Featuring Trey Songz']
# ['Say You Do', 'Dierks Bentley']
# ['No Love', 'August Alsina']
# ['The Body', 'Wale Featuring Jeremih']
# ['A Guy Walks Into A Bar', 'Tyler Farr']
# ['I Mean It', 'G-Eazy Featuring Remo']
# ['Uptown Funk!', 'Mark Ronson Featuring Bruno Mars']
# ['Thinking Out Loud', 'Ed Sheeran']
# ['Take Me To Church', 'Hozier']
# ['Blank Space', 'Taylor Swift']
# ['Shake It Off', 'Taylor Swift']
# ['Sugar', 'Maroon 5']
# ['Lips Are Movin', 'Meghan Trainor']
# ["I'm Not The Only One", 'Sam Smith']
# ['Jealous', 'Nick Jonas']
# ['Centuries', 'Fall Out Boy']
# ['All About That Bass', 'Meghan Trainor']
# ['Love Me Harder', 'Ariana Grande & The Weeknd']
# ["I Don't F**k With You", 'Big Sean Featuring E-40']
# ["I Don't Mind", 'Usher Featuring Juicy J']
# ['The Heart Wants What It Wants', 'Selena Gomez']
# ['The Hanging Tree', 'James Newton Howard Featuring Jennifer Lawrence']
# ['Only', 'Nicki Minaj Featuring Drake, Lil Wayne & Chris Brown']
# ['Animals', 'Maroon 5']
# ['7/11', 'Beyonce']
# ['Love Me Like You Do', 'Ellie Goulding']
# ['Time Of Our Lives', 'Pitbull & Ne-Yo']
# ['No Type', 'Rae Sremmurd']
# ['CoCo', 'O.T. Genasis']
# ['Ghost', 'Ella Henderson']
# ['Tuesday', 'I LOVE MAKONNEN Featuring Drake']
# ['Stay With Me', 'Sam Smith']
# ['Earned It (Fifty Shades Of Grey)', 'The Weeknd']
# ['Bang Bang', 'Jessie J, Ariana Grande & Nicki Minaj']
# ['Waves', 'Mr. Probz']
# ['Habits (Stay High)', 'Tove Lo']
# ['Riptide', 'Vance Joy']
# ['Elastic Heart', 'Sia']
# ['Chandelier', 'Sia']
# ['G.D.F.R.', 'Flo Rida Featuring Sage The Gemini & Lookas']
# ['Heroes (We Could Be)', 'Alesso Featuring Tove Lo']
# ["Don't", 'Ed Sheeran']
# ['Style', 'Taylor Swift']
# ['She Knows', 'Ne-Yo Featuring Juicy J']
# ['I Lived', 'OneRepublic']
# ['Prayer In C', 'Lillywood & Robin Schulz']
# ['I See You', 'Luke Bryan']
# ['Something In The Water', 'Carrie Underwood']
# ['Talladega', 'Eric Church']
# ['Sun Daze', 'Florida Georgia Line']
# ['Rude', 'MAGIC!']
# ['Night Changes', 'One Direction']
# ["Don't Tell 'Em", 'Jeremih Featuring YG']
# ['Black Widow', 'Iggy Azalea Featuring Rita Ora']
# ['Sledgehammer', 'Fifth Harmony']
# ['Blame', 'Calvin Harris Featuring John Newman']
# ['Lonely Tonight', 'Blake Shelton Featuring Ashley Monroe']
# ['Stuck On A Feeling', 'Prince Royce Featuring Snoop Dogg']
# ['Take Your Time', 'Sam Hunt']
# ['FourFiveSeconds', 'Rihanna & Kanye West & Paul McCartney']
# ['Make Me Wanna', 'Thomas Rhett']
# ['Outside', 'Calvin Harris Featuring Ellie Goulding']
# ['Try Me', 'DeJ Loaf']
# ['Feeling Myself', 'Nicki Minaj Featuring Beyonce']
# ['Often', 'The Weeknd']
# ['Drinking Class', 'Lee Brice']
# ["Just Gettin' Started", 'Jason Aldean']
# ['Shotgun Rider', 'Tim McGraw']
# ['I Bet My Life', 'Imagine Dragons']
# ['Shut Up And Dance', 'WALK THE MOON']
# ['Ayo', 'Chris Brown & Tyga']
# ['Mean To Me', 'Brett Eldredge']
# ['Heartbeat Song', 'Kelly Clarkson']
# ['Like A Cowboy', 'Randy Houser']
# ["Til It's Gone", 'Kenny Chesney']
# ['Apparently', 'J. Cole']
# ['Truffle Butter', 'Nicki Minaj Featuring Drake & Lil Wayne']
# ['Beg For It', 'Iggy Azalea Featuring M0']
# ['Throw Sum Mo', 'Rae Sremmurd Featuring Nicki Minaj & Young Thug']
# ['Lonely Eyes', 'Chris Young']
# ['God Made Girls', 'RaeLynn']
# ['All About It', 'Hoodie Allen Featuring Ed Sheeran']
# ["Ain't Worth The Whiskey", 'Cole Swindell']
# ['Perfect Storm', 'Brad Paisley']
# ['L.A.LOVE (la la)', 'Fergie']
# ['Homegrown Honey', 'Darius Rucker']
# ['Homegrown', 'Zac Brown Band']
# ['Worth It', 'Fifth Harmony Featuring Kid Ink']
# ['Take It On Back', 'Chase Bryant']
# ['Steal My Girl', 'One Direction']
# ['Uma Thurman', 'Fall Out Boy']
# ['Trap Queen', 'Fetty Wap']
# ['Body Language', 'Kid Ink Featuring Usher & Tinashe']
# ['Geronimo', 'Sheppard']
# ['Post To Be', 'Omarion Featuring Chris Brown & Jhene Aiko']
# ['Say You Do', 'Dierks Bentley']
# ['Not For Long', 'B.o.B Featuring Trey Songz']
# ["What We Ain't Got", 'Jake Owen']
# ['The Body', 'Wale Featuring Jeremih']
# ['Somebody', 'Natalie La Rose Featuring Jeremih']
# ["Can't Stop Dancin'", 'Becky G']
# ['Immortals', 'Fall Out Boy']
# ['Dangerous', 'David Guetta Featuring Sam Martin']
# ['A Guy Walks Into A Bar', 'Tyler Farr']
# ['Slow Motion', 'Trey Songz']
# ['***Flawless', 'Beyonce Featuring Nicki Minaj Or Chimamanda Ngozi Adichie']
# ['Uptown Funk!', 'Mark Ronson Featuring Bruno Mars']
# ['Thinking Out Loud', 'Ed Sheeran']
# ['Take Me To Church', 'Hozier']
# ['Blank Space', 'Taylor Swift']
# ['Sugar', 'Maroon 5']
# ['Lips Are Movin', 'Meghan Trainor']
# ["I'm Not The Only One", 'Sam Smith']
# ['Jealous', 'Nick Jonas']
# ['Shake It Off', 'Taylor Swift']
# ['Centuries', 'Fall Out Boy']
# ['Time Of Our Lives', 'Pitbull & Ne-Yo']
# ['All About That Bass', 'Meghan Trainor']
# ["I Don't Mind", 'Usher Featuring Juicy J']
# ['Love Me Like You Do', 'Ellie Goulding']
# ['FourFiveSeconds', 'Rihanna & Kanye West & Paul McCartney']
# ['Love Me Harder', 'Ariana Grande & The Weeknd']
# ['Only', 'Nicki Minaj Featuring Drake, Lil Wayne & Chris Brown']
# ["I Don't F**k With You", 'Big Sean Featuring E-40']
# ['The Heart Wants What It Wants', 'Selena Gomez']
# ['CoCo', 'O.T. Genasis']
# ['Stay With Me', 'Sam Smith']
# ['7/11', 'Beyonce']
# ['Animals', 'Maroon 5']
# ['No Type', 'Rae Sremmurd']
# ['She Knows', 'Ne-Yo Featuring Juicy J']
# ['Ghost', 'Ella Henderson']
# ['Truffle Butter', 'Nicki Minaj Featuring Drake & Lil Wayne']
# ['The Hanging Tree', 'James Newton Howard Featuring Jennifer Lawrence']
# ['Style', 'Taylor Swift']
# ['Tuesday', 'I LOVE MAKONNEN Featuring Drake']
# ['G.D.F.R.', 'Flo Rida Featuring Sage The Gemini & Lookas']
# ['Riptide', 'Vance Joy']
# ['Prayer In C', 'Lillywood & Robin Schulz']
# ['Habits (Stay High)', 'Tove Lo']
# ['Bang Bang', 'Jessie J, Ariana Grande & Nicki Minaj']
# ['Elastic Heart', 'Sia']
# ['Chandelier', 'Sia']
# ['Earned It (Fifty Shades Of Grey)', 'The Weeknd']
# ['Waves', 'Mr. Probz']
# ["Don't", 'Ed Sheeran']
# ['I See You', 'Luke Bryan']
# ['Heroes (We Could Be)', 'Alesso Featuring Tove Lo']
# ['Stuck On A Feeling', 'Prince Royce Featuring Snoop Dogg']
# ['Rude', 'MAGIC!']
# ['I Lived', 'OneRepublic']
# ['Talladega', 'Eric Church']
# ['Sun Daze', 'Florida Georgia Line']
# ['Lonely Tonight', 'Blake Shelton Featuring Ashley Monroe']
# ['Take Your Time', 'Sam Hunt']
# ['Outside', 'Calvin Harris Featuring Ellie Goulding']
# ['Night Changes', 'One Direction']
# ['Make Me Wanna', 'Thomas Rhett']
# ['Today', 'Brad Paisley']
# ['Million Reasons', 'Lady Gaga']
# ['Immortal', 'J. Cole']
# ['What They Want', 'Russ']
# ['Just Hold On', 'Steve Aoki & Louis Tomlinson']
# ['If The Boot Fits', 'Granger Smith']
# ['Bad And Boujee', 'Migos Featuring Lil Uzi Vert']
# ['Shape Of You', 'Ed Sheeran']
# ['Black Beatles', 'Rae Sremmurd Featuring Gucci Mane']
# ['Closer', 'The Chainsmokers Featuring Halsey']
# ['Starboy', 'The Weeknd Featuring Daft Punk']
# ['Bad Things', 'Machine Gun Kelly x Camila Cabello']
# ['Paris', 'The Chainsmokers']
# ["I Don't Wanna Live Forever (Fifty Shades Darker)", 'Zayn / Taylor Swift']
# ["Don't Wanna Know", 'Maroon 5 Featuring Kendrick Lamar']
# ['24K Magic', 'Bruno Mars']
# ['Fake Love', 'Drake']
# ['Side To Side', 'Ariana Grande Featuring Nicki Minaj']
# ['Scars To Your Beautiful', 'Alessia Cara']
# ['Caroline', 'Amine']
# ['Bounce Back', 'Big Sean']
# ['Let Me Love You', 'DJ Snake Featuring Justin Bieber']
# ['Love On The Brain', 'Rihanna']
# ['Juju On That Beat (TZ Anthem)', 'Zay Hilfigerrr & Zayion McCall']
# ['I Feel It Coming', 'The Weeknd Featuring Daft Punk']
# ['Heathens', 'twenty one pilots']
# ['Broccoli', 'D.R.A.M. Featuring Lil Yachty']
# ['All Time Low', 'Jon Bellion']
# ['Starving', 'Hailee Steinfeld & Grey Featuring Zedd']
# ["Can't Stop The Feeling!", 'Justin Timberlake']
# ['Mercy', 'Shawn Mendes']
# ['Treat You Better', 'Shawn Mendes']
# ['Cheap Thrills', 'Sia Featuring Sean Paul']
# ['Castle On The Hill', 'Ed Sheeran']
# ['This Town', 'Niall Horan']
# ["Say You Won't Let Go", 'James Arthur']
# ['Love Me Now', 'John Legend']
# ['El Amante', 'Nicky Jam']
# ['Weak', 'AJR']
# ["It Ain't My Fault", 'Brothers Osborne']
# ['Subeme La Radio', 'Enrique Iglesias Featuring Descemer Bueno, Zion & Lennox Or Sean Paul']
# ['Woman', 'Kesha Featuring The Dap-Kings Horns']
# ['Rollin', 'Calvin Harris Featuring Future & Khalid']
# ['Element.', 'Kendrick Lamar']
# ['Glorious', 'Macklemore Featuring Skylar Grey']
# ['No Complaints', 'Metro Boomin Featuring Offset & Drake']
# ['Despacito', 'Luis Fonsi & Daddy Yankee Featuring Justin Bieber']
# ['Wild Thoughts', 'DJ Khaled Featuring Rihanna & Bryson Tiller']
# ["That's What I Like", 'Bruno Mars']
# ["I'm The One", 'DJ Khaled Featuring Justin Bieber, Quavo, Chance The Rapper & Lil Wayne']
# ['Believer', 'Imagine Dragons']
# ['Unforgettable', 'French Montana Featuring Swae Lee']
# ['Shape Of You', 'Ed Sheeran']
# ["There's Nothing Holdin' Me Back", 'Shawn Mendes']
# ['Attention', 'Charlie Puth']
# ['Body Like A Back Road', 'Sam Hunt']
# ['Congratulations', 'Post Malone Featuring Quavo']
# ['Humble.', 'Kendrick Lamar']
# ['Redbone', 'Childish Gambino']
# ['Stay', 'Zedd & Alessia Cara']
# ['Something Just Like This', 'The Chainsmokers & Coldplay']
# ['Strip That Down', 'Liam Payne Featuring Quavo']
# ['XO TOUR Llif3', 'Lil Uzi Vert']
# ['Slow Hands', 'Niall Horan']
# ['Now Or Never', 'Halsey']
# ['Mask Off', 'Future']
# ['Bank Account', '21 Savage']
# ["It Ain't Me", 'Kygo x Selena Gomez']
# ['Feels', 'Calvin Harris Featuring Pharrell Williams, Katy Perry & Big Sean']
# ["Say You Won't Let Go", 'James Arthur']
# ['Castle On The Hill', 'Ed Sheeran']
# ['Sorry Not Sorry', 'Demi Lovato']
# ['Location', 'Khalid']
# ['Bodak Yellow (Money Moves)', 'Cardi B']
# ['2U', 'David Guetta Featuring Justin Bieber']
# ['Mi Gente', 'J Balvin & Willy William Featuring Beyonce']
# ['Slippery', 'Migos Featuring Gucci Mane']
# ['Rake It Up', 'Yo Gotti Featuring Nicki Minaj']
# ['Magnolia', 'Playboi Carti']
# ['Numb', 'Linkin Park']
# ['Issues', 'Julia Michaels']
# ['Everyday We Lit', 'YFN Lucci Featuring PnB Rock']
# ['In The End', 'Linkin Park']
# ['Praying', 'Kesha']
# ['Closer', 'The Chainsmokers Featuring Halsey']
# ['Back To You', 'Louis Tomlinson Featuring Bebe Rexha & Digital Farm Animals']
# ['Fetish', 'Selena Gomez Featuring Gucci Mane']
# ['Malibu', 'Miley Cyrus']
# ['Drowning', 'A Boogie Wit da Hoodie Featuring Kodak Black']
# ["In Case You Didn't Know", 'Brett Young']
# ['Heavy', 'Linkin Park Featuring Kiiara']
# ['Love Galore', 'SZA Featuring Travis Scott']
# ['The Fighter', 'Keith Urban Featuring Carrie Underwood']
# ['Craving You', 'Thomas Rhett Featuring Maren Morris']
# ['Small Town Boy', 'Dustin Lynch']
# ['Rolex', 'Ayo & Teo']
# ['Whatever You Need', 'Meek Mill Featuring Chris Brown & Ty Dolla $ign']
# ['My Girl', 'Dylan Scott']
# ['Versace On The Floor', 'Bruno Mars']
# ['Bad Liar', 'Selena Gomez']
# ['Feel It Still', 'Portugal. The Man']
# ['Felices Los 4', 'Maluma']
# ['1-800-273-8255', 'Logic Featuring Alessia Cara & Khalid']
# ['Do I Make You Wanna', 'Billy Currington']
# ['DNA.', 'Kendrick Lamar']
# ["Drinkin' Problem", 'Midland']
# ["What's My Name", 'China Anne McClain, Thomas Doherty & Dylan Playfair']
# ["It's A Vibe", '2 Chainz Featuring Ty Dolla $ign, Trey Songz & Jhene Aiko']
# ['What Ifs', 'Kane Brown Featuring Lauren Alaina']
# ['Loyalty.', 'Kendrick Lamar Featuring Rihanna']
# ['Butterfly Effect', 'Travis Scott']
# ['No Such Thing As A Broken Heart', 'Old Dominion']
# ['Flatliner', 'Cole Swindell']
# ['No Promises', 'Cheat Codes Featuring Demi Lovato']
# ['Thunder', 'Imagine Dragons']
# ['You Look Good', 'Lady Antebellum']
# ['Escapate Conmigo', 'Wisin Featuring Ozuna']
# ['Most Girls', 'Hailee Steinfeld']
# ['Heartache On The Dance Floor', 'Jon Pardi']
# ['Crew', 'GoldLink Featuring Brent Faiyaz & Shy Glizzy']
# ['Love.', 'Kendrick Lamar Featuring Zacari']
# ['Somebody Else Will', 'Justin Moore']
# ['Issues', 'Meek Mill']
# ['Privacy', 'Chris Brown']
# ['Wins & Losses', 'Meek Mill']
# ['Passionfruit', 'Drake']
# ["It's Goin' Down", 'Descendants 2 Cast']
# ['Young Dumb & Broke', 'Khalid']
# ['1942 Flows', 'Meek Mill']
# ['First Day Out', 'Tee Grizzley']
# ['Glorious', 'Macklemore Featuring Skylar Grey']
# ['Swalla', 'Jason Derulo Featuring Nicki Minaj & Ty Dolla $ign']
# ['Yours If You Want It', 'Rascal Flatts']
# ['4 AM', '2 Chainz Featuring Travis Scott']
# ['God, Your Mama, And Me', 'Florida Georgia Line Featuring Backstreet Boys']
# ['Down', 'Fifth Harmony Featuring Gucci Mane']
# ['Imitadora', 'Romeo Santos']
# ['Subeme La Radio', 'Enrique Iglesias Featuring Descemer Bueno, Zion & Lennox Or Sean Paul']
# ["It Ain't My Fault", 'Brothers Osborne']
# ['El Amante', 'Nicky Jam']
# ['The Story Of O.J.', 'JAY-Z']
# ['We Ball', 'Meek Mill Featuring Young Thug']
# ['F**k That Check Up', 'Meek Mill Featuring Lil Uzi Vert']
# ['Signs', 'Drake']
# ['Heavy Heart', 'Meek Mill']
# ['Reminder', 'The Weeknd']
# ['Despacito', 'Luis Fonsi & Daddy Yankee Featuring Justin Bieber']
# ['Wild Thoughts', 'DJ Khaled Featuring Rihanna & Bryson Tiller']
# ['Unforgettable', 'French Montana Featuring Swae Lee']
# ["That's What I Like", 'Bruno Mars']
# ['Believer', 'Imagine Dragons']
# ["I'm The One", 'DJ Khaled Featuring Justin Bieber, Quavo, Chance The Rapper & Lil Wayne']
# ['Attention', 'Charlie Puth']
# ["There's Nothing Holdin' Me Back", 'Shawn Mendes']
# ['Shape Of You', 'Ed Sheeran']
# ['Body Like A Back Road', 'Sam Hunt']
# ['Congratulations', 'Post Malone Featuring Quavo']
# ['Redbone', 'Childish Gambino']
# ['Humble.', 'Kendrick Lamar']
# ['Bodak Yellow (Money Moves)', 'Cardi B']
# ['Slow Hands', 'Niall Horan']
# ['Strip That Down', 'Liam Payne Featuring Quavo']
# ['Something Just Like This', 'The Chainsmokers & Coldplay']
# ['Bank Account', '21 Savage']
# ['Stay', 'Zedd & Alessia Cara']
# ['XO TOUR Llif3', 'Lil Uzi Vert']
# ['Feels', 'Calvin Harris Featuring Pharrell Williams, Katy Perry & Big Sean']
# ['Now Or Never', 'Halsey']
# ['Mask Off', 'Future']
# ["It Ain't Me", 'Kygo x Selena Gomez']
# ["Say You Won't Let Go", 'James Arthur']
# ['Rake It Up', 'Yo Gotti Featuring Nicki Minaj']
# ['Location', 'Khalid']
# ['Mi Gente', 'J Balvin & Willy William Featuring Beyonce']
# ['Castle On The Hill', 'Ed Sheeran']
# ['Sorry Not Sorry', 'Demi Lovato']
# ['Loyalty.', 'Kendrick Lamar Featuring Rihanna']
# ['Praying', 'Kesha']
# ['Slippery', 'Migos Featuring Gucci Mane']
# ['Feel It Still', 'Portugal. The Man']
# ['Magnolia', 'Playboi Carti']
# ['Everyday We Lit', 'YFN Lucci Featuring PnB Rock']
# ['Love Galore', 'SZA Featuring Travis Scott']
# ['You Da Baddest', 'Future Featuring Nicki Minaj']
# ['Issues', 'Julia Michaels']
# ['Drowning', 'A Boogie Wit da Hoodie Featuring Kodak Black']
# ['Fetish', 'Selena Gomez Featuring Gucci Mane']
# ['Small Town Boy', 'Dustin Lynch']
# ["In Case You Didn't Know", 'Brett Young']
# ['2U', 'David Guetta Featuring Justin Bieber']
# ['Craving You', 'Thomas Rhett Featuring Maren Morris']
# ['Versace On The Floor', 'Bruno Mars']
# ['Do I Make You Wanna', 'Billy Currington']
# ['What Ifs', 'Kane Brown Featuring Lauren Alaina']
# ['Rolex', 'Ayo & Teo']
# ["Drinkin' Problem", 'Midland']
# ['No Promises', 'Cheat Codes Featuring Demi Lovato']
# ['1-800-273-8255', 'Logic Featuring Alessia Cara & Khalid']
# ["It's A Vibe", '2 Chainz Featuring Ty Dolla $ign, Trey Songz & Jhene Aiko']
# ['Thunder', 'Imagine Dragons']
# ['Malibu', 'Miley Cyrus']
# ['Flatliner', 'Cole Swindell']
# ['My Girl', 'Dylan Scott']
# ['Felices Los 4', 'Maluma']
# ['No Such Thing As A Broken Heart', 'Old Dominion']
# ['DNA.', 'Kendrick Lamar']
# ['Butterfly Effect', 'Travis Scott']
# ['Whatever You Need', 'Meek Mill Featuring Chris Brown & Ty Dolla $ign']
# ['Heartache On The Dance Floor', 'Jon Pardi']
# ['Young Dumb & Broke', 'Khalid']
# ['Most Girls', 'Hailee Steinfeld']
# ['Crew', 'GoldLink Featuring Brent Faiyaz & Shy Glizzy']
# ['Bad Liar', 'Selena Gomez']
# ['Unforgettable', 'Thomas Rhett']
# ['Somebody Else Will', 'Justin Moore']
# ['You Look Good', 'Lady Antebellum']
# ['Escapate Conmigo', 'Wisin Featuring Ozuna']
# ['Love.', 'Kendrick Lamar Featuring Zacari']
# ['Reminder', 'The Weeknd']
# ['Back To You', 'Louis Tomlinson Featuring Bebe Rexha & Digital Farm Animals']
# ['Do Re Mi', 'blackbear']
# ['Glorious', 'Macklemore Featuring Skylar Grey']
# ["It's Goin' Down", 'Descendants 2 Cast']
# ['Privacy', 'Chris Brown']
# ['First Day Out', 'Tee Grizzley']
# ['Down', 'Fifth Harmony Featuring Gucci Mane']
# ['Passionfruit', 'Drake']
# ['Swalla', 'Jason Derulo Featuring Nicki Minaj & Ty Dolla $ign']
# ['4 AM', '2 Chainz Featuring Travis Scott']
# ["What's My Name", 'China Anne McClain, Thomas Doherty & Dylan Playfair']
# ['When It Rains It Pours', 'Luke Combs']
# ["It Ain't My Fault", 'Brothers Osborne']
# ["They Don't Know", 'Jason Aldean']
# ['Honest', 'The Chainsmokers']
# ['The Weekend', 'SZA']
# ['New Rules', 'Dua Lipa']
# ['Subeme La Radio', 'Enrique Iglesias Featuring Descemer Bueno, Zion & Lennox Or Sean Paul']
# ['El Amante', 'Nicky Jam']
# ['Wish I Knew You', 'The Revivalists']
# ['Every Little Thing', 'Carly Pearce']
# ['God, Your Mama, And Me', 'Florida Georgia Line Featuring Backstreet Boys']
# ['Heavy', 'Linkin Park Featuring Kiiara']
# ['Learn To Let Go', 'Kesha']
# ['All The Pretty Girls', 'Kenny Chesney']
# ['For Her', 'Chris Lane']
# ['Signs', 'Drake']
# ['Despacito', 'Luis Fonsi & Daddy Yankee Featuring Justin Bieber']
# ['Wild Thoughts', 'DJ Khaled Featuring Rihanna & Bryson Tiller']
# ['Unforgettable', 'French Montana Featuring Swae Lee']
# ['Believer', 'Imagine Dragons']
# ['Attention', 'Charlie Puth']
# ["There's Nothing Holdin' Me Back", 'Shawn Mendes']
# ["That's What I Like", 'Bruno Mars']
# ['Bodak Yellow (Money Moves)', 'Cardi B']
# ['Shape Of You', 'Ed Sheeran']
# ["I'm The One", 'DJ Khaled Featuring Justin Bieber, Quavo, Chance The Rapper & Lil Wayne']
# ['Body Like A Back Road', 'Sam Hunt']
# ['Bank Account', '21 Savage']
# ['Redbone', 'Childish Gambino']
# ['Congratulations', 'Post Malone Featuring Quavo']
# ['Strip That Down', 'Liam Payne Featuring Quavo']
# ['Humble.', 'Kendrick Lamar']
# ['Slow Hands', 'Niall Horan']
# ['XO TOUR Llif3', 'Lil Uzi Vert']
# ['Something Just Like This', 'The Chainsmokers & Coldplay']
# ['Stay', 'Zedd & Alessia Cara']
# ['Feels', 'Calvin Harris Featuring Pharrell Williams, Katy Perry & Big Sean']
# ['Rake It Up', 'Yo Gotti Featuring Nicki Minaj']
# ['Mi Gente', 'J Balvin & Willy William Featuring Beyonce']
# ['Praying', 'Kesha']
# ['Mask Off', 'Future']
# ['Now Or Never', 'Halsey']
# ["Say You Won't Let Go", 'James Arthur']
# ['Sorry Not Sorry', 'Demi Lovato']
# ['Location', 'Khalid']
# ['Feel It Still', 'Portugal. The Man']
# ["It Ain't Me", 'Kygo x Selena Gomez']
# ['Loyalty.', 'Kendrick Lamar Featuring Rihanna']
# ['Castle On The Hill', 'Ed Sheeran']
# ['Magnolia', 'Playboi Carti']
# ['Love Galore', 'SZA Featuring Travis Scott']
# ['Everyday We Lit', 'YFN Lucci Featuring PnB Rock']
# ['Slippery', 'Migos Featuring Gucci Mane']
# ['Small Town Boy', 'Dustin Lynch']
# ['Drowning', 'A Boogie Wit da Hoodie Featuring Kodak Black']
# ['What Ifs', 'Kane Brown Featuring Lauren Alaina']
# ["In Case You Didn't Know", 'Brett Young']
# ['No Promises', 'Cheat Codes Featuring Demi Lovato']
# ['Versace On The Floor', 'Bruno Mars']
# ['Issues', 'Julia Michaels']
# ['2U', 'David Guetta Featuring Justin Bieber']
# ["It's A Vibe", '2 Chainz Featuring Ty Dolla $ign, Trey Songz & Jhene Aiko']
# ['Fetish', 'Selena Gomez Featuring Gucci Mane']
# ["Drinkin' Problem", 'Midland']
# ['Young Dumb & Broke', 'Khalid']
# ['1-800-273-8255', 'Logic Featuring Alessia Cara & Khalid']
# ['No Such Thing As A Broken Heart', 'Old Dominion']
# ['Do I Make You Wanna', 'Billy Currington']
# ['Thunder', 'Imagine Dragons']
# ['Heartache On The Dance Floor', 'Jon Pardi']
# ['Butterfly Effect', 'Travis Scott']
# ['Flatliner', 'Cole Swindell']
# ['Whatever You Need', 'Meek Mill Featuring Chris Brown & Ty Dolla $ign']
# ['Crew', 'GoldLink Featuring Brent Faiyaz & Shy Glizzy']
# ['DNA.', 'Kendrick Lamar']
# ['Most Girls', 'Hailee Steinfeld']
# ['Felices Los 4', 'Maluma']
# ['Back To You', 'Louis Tomlinson Featuring Bebe Rexha & Digital Farm Animals']
# ['Craving You', 'Thomas Rhett Featuring Maren Morris']
# ['Somebody Else Will', 'Justin Moore']
# ['Reminder', 'The Weeknd']
# ['My Girl', 'Dylan Scott']
# ['Do Re Mi', 'blackbear']
# ['Escapate Conmigo', 'Wisin Featuring Ozuna']
# ['You Look Good', 'Lady Antebellum']
# ['The Race', 'Tay-K']
# ['Glorious', 'Macklemore Featuring Skylar Grey']
# ['Love.', 'Kendrick Lamar Featuring Zacari']
# ['Malibu', 'Miley Cyrus']
# ['Bad Liar', 'Selena Gomez']
# ['The Weekend', 'SZA']
# ['Patty Cake', 'Kodak Black']
# ['Honest', 'The Chainsmokers']
# ['First Day Out', 'Tee Grizzley']
# ['Privacy', 'Chris Brown']
# ['When It Rains It Pours', 'Luke Combs']
# ['OMG', 'Camila Cabello Featuring Quavo']
# ['What About Us', 'P!nk']
# ['New Rules', 'Dua Lipa']
# ['Perplexing Pegasus', 'Rae Sremmurd']
# ["What's My Name", 'China Anne McClain, Thomas Doherty & Dylan Playfair']
# ['Unforgettable', 'Thomas Rhett']
# ['You Da Baddest', 'Future Featuring Nicki Minaj']
# ['Wish I Knew You', 'The Revivalists']
# ["They Don't Know", 'Jason Aldean']
# ['Down', 'Fifth Harmony Featuring Gucci Mane']
# ["It Ain't My Fault", 'Brothers Osborne']
# ['All The Pretty Girls', 'Kenny Chesney']
# ['4 AM', '2 Chainz Featuring Travis Scott']
# ['B.E.D.', 'Jacquees']
# ["Chillin' Like A Villain", 'Sofia Carson, Cameron Boyce, Booboo Stewart & Mitchell Hope']
# ["It's Goin' Down", 'Descendants 2 Cast']
# ['For Her', 'Chris Lane']
# ['Every Little Thing', 'Carly Pearce']
# ['Havana', 'Camila Cabello Featuring Young Thug']
# ['El Amante', 'Nicky Jam']
# ['Despacito', 'Luis Fonsi & Daddy Yankee Featuring Justin Bieber']
# ['Wild Thoughts', 'DJ Khaled Featuring Rihanna & Bryson Tiller']
# ['Bodak Yellow (Money Moves)', 'Cardi B']
# ['Unforgettable', 'French Montana Featuring Swae Lee']
# ['Believer', 'Imagine Dragons']
# ['Attention', 'Charlie Puth']
# ["There's Nothing Holdin' Me Back", 'Shawn Mendes']
# ["That's What I Like", 'Bruno Mars']
# ['Shape Of You', 'Ed Sheeran']
# ['Body Like A Back Road', 'Sam Hunt']
# ["I'm The One", 'DJ Khaled Featuring Justin Bieber, Quavo, Chance The Rapper & Lil Wayne']
# ['Bank Account', '21 Savage']
# ['Strip That Down', 'Liam Payne Featuring Quavo']
# ['Congratulations', 'Post Malone Featuring Quavo']
# ['Slow Hands', 'Niall Horan']
# ['Redbone', 'Childish Gambino']
# ['Humble.', 'Kendrick Lamar']
# ['XO TOUR Llif3', 'Lil Uzi Vert']
# ['Something Just Like This', 'The Chainsmokers & Coldplay']
# ['Feels', 'Calvin Harris Featuring Pharrell Williams, Katy Perry & Big Sean']
# ['Mi Gente', 'J Balvin & Willy William Featuring Beyonce']
# ['Praying', 'Kesha']
# ['Stay', 'Zedd & Alessia Cara']
# ['Rake It Up', 'Yo Gotti Featuring Nicki Minaj']
# ['Sorry Not Sorry', 'Demi Lovato']
# ['Feel It Still', 'Portugal. The Man']
# ['Location', 'Khalid']
# ['Mask Off', 'Future']
# ['What About Us', 'P!nk']
# ["Say You Won't Let Go", 'James Arthur']
# ['Loyalty.', 'Kendrick Lamar Featuring Rihanna']
# ['Now Or Never', 'Halsey']
# ['Versace On The Floor', 'Bruno Mars']
# ["It Ain't Me", 'Kygo x Selena Gomez']
# ['Love Galore', 'SZA Featuring Travis Scott']
# ['Magnolia', 'Playboi Carti']
# ['1-800-273-8255', 'Logic Featuring Alessia Cara & Khalid']
# ['Small Town Boy', 'Dustin Lynch']
# ['Castle On The Hill', 'Ed Sheeran']
# ['Everyday We Lit', 'YFN Lucci Featuring PnB Rock']
# ['Drowning', 'A Boogie Wit da Hoodie Featuring Kodak Black']
# ['Silence', 'Marshmello Featuring Khalid']
# ['No Promises', 'Cheat Codes Featuring Demi Lovato']
# ['What Ifs', 'Kane Brown Featuring Lauren Alaina']
# ["In Case You Didn't Know", 'Brett Young']
# ['Slippery', 'Migos Featuring Gucci Mane']
# ["It's A Vibe", '2 Chainz Featuring Ty Dolla $ign, Trey Songz & Jhene Aiko']
# ['Fetish', 'Selena Gomez Featuring Gucci Mane']
# ['Young Dumb & Broke', 'Khalid']
# ['No Such Thing As A Broken Heart', 'Old Dominion']
# ["Drinkin' Problem", 'Midland']
# ['The Race', 'Tay-K']
# ['Felices Los 4', 'Maluma']
# ['Crew', 'GoldLink Featuring Brent Faiyaz & Shy Glizzy']
# ['Heartache On The Dance Floor', 'Jon Pardi']
# ['Back To You', 'Louis Tomlinson Featuring Bebe Rexha & Digital Farm Animals']
# ['Thunder', 'Imagine Dragons']
# ['Butterfly Effect', 'Travis Scott']
# ['Somebody Else Will', 'Justin Moore']
# ['Craving You', 'Thomas Rhett Featuring Maren Morris']
# ['Whatever You Need', 'Meek Mill Featuring Chris Brown & Ty Dolla $ign']
# ['Do I Make You Wanna', 'Billy Currington']
# ['Do Re Mi', 'blackbear']
# ['2U', 'David Guetta Featuring Justin Bieber']
# ['You Look Good', 'Lady Antebellum']
# ['DNA.', 'Kendrick Lamar']
# ['Most Girls', 'Hailee Steinfeld']
# ['When It Rains It Pours', 'Luke Combs']
# ['Escapate Conmigo', 'Wisin Featuring Ozuna']
# ['Love.', 'Kendrick Lamar Featuring Zacari']
# ['Glorious', 'Macklemore Featuring Skylar Grey']
# ['My Girl', 'Dylan Scott']
# ['Unforgettable', 'Thomas Rhett']
# ['Flatliner', 'Cole Swindell']
# ['The Weekend', 'SZA']
# ['Reminder', 'The Weeknd']
# ['Honest', 'The Chainsmokers']
# ['Malibu', 'Miley Cyrus']
# ["It Ain't My Fault", 'Brothers Osborne']
# ['All The Pretty Girls', 'Kenny Chesney']
# ['New Rules', 'Dua Lipa']
# ["They Don't Know", 'Jason Aldean']
# ['Bad Liar', 'Selena Gomez']
# ['First Day Out', 'Tee Grizzley']
# ['Every Little Thing', 'Carly Pearce']
# ['Patty Cake', 'Kodak Black']
# ['Wish I Knew You', 'The Revivalists']
# ['More Girls Like You', 'Kip Moore']
# ['B.E.D.', 'Jacquees']
# ['4 AM', '2 Chainz Featuring Travis Scott']
# ['Privacy', 'Chris Brown']
# ['Something New', 'Wiz Khalifa Featuring Ty Dolla $ign']
# ['Perplexing Pegasus', 'Rae Sremmurd']
# ['For Her', 'Chris Lane']
# ['Untouchable', 'YoungBoy Never Broke Again']
# ["It's Goin' Down", 'Descendants 2 Cast']
# ['I Could Use A Love Song', 'Maren Morris']
# ['Fix A Drink', 'Chris Janson']
# ['El Amante', 'Nicky Jam']
# ['Wokeuplikethis*', 'Playboi Carti Featuring Lil Uzi Vert']
# ['Despacito', 'Luis Fonsi & Daddy Yankee Featuring Justin Bieber']
# ['Wild Thoughts', 'DJ Khaled Featuring Rihanna & Bryson Tiller']
# ['Bodak Yellow (Money Moves)', 'Cardi B']
# ['Believer', 'Imagine Dragons']
# ['Attention', 'Charlie Puth']
# ['Unforgettable', 'French Montana Featuring Swae Lee']
# ["There's Nothing Holdin' Me Back", 'Shawn Mendes']
# ["That's What I Like", 'Bruno Mars']
# ['Shape Of You', 'Ed Sheeran']
# ['Rake It Up', 'Yo Gotti Featuring Nicki Minaj']
# ['Strip That Down', 'Liam Payne Featuring Quavo']
# ['Bank Account', '21 Savage']
# ['Body Like A Back Road', 'Sam Hunt']
# ['Slow Hands', 'Niall Horan']
# ['Congratulations', 'Post Malone Featuring Quavo']
# ["I'm The One", 'DJ Khaled Featuring Justin Bieber, Quavo, Chance The Rapper & Lil Wayne']
# ['Redbone', 'Childish Gambino']
# ['Sorry Not Sorry', 'Demi Lovato']
# ['Humble.', 'Kendrick Lamar']
# ['Friends', 'Justin Bieber + BloodPop']
# ['Something Just Like This', 'The Chainsmokers & Coldplay']
# ['Feels', 'Calvin Harris Featuring Pharrell Williams, Katy Perry & Big Sean']
# ['Feel It Still', 'Portugal. The Man']
# ['Mi Gente', 'J Balvin & Willy William Featuring Beyonce']
# ['XO TOUR Llif3', 'Lil Uzi Vert']
# ['Location', 'Khalid']
# ['Stay', 'Zedd & Alessia Cara']
# ['Praying', 'Kesha']
# ['1-800-273-8255', 'Logic Featuring Alessia Cara & Khalid']
# ['Mask Off', 'Future']
# ["Say You Won't Let Go", 'James Arthur']
# ['Loyalty.', 'Kendrick Lamar Featuring Rihanna']
# ['Love Galore', 'SZA Featuring Travis Scott']
# ['I Get The Bag', 'Gucci Mane Featuring Migos']
# ['What About Us', 'P!nk']
# ['Small Town Boy', 'Dustin Lynch']
# ["It Ain't Me", 'Kygo x Selena Gomez']
# ['What Ifs', 'Kane Brown Featuring Lauren Alaina']
# ['No Promises', 'Cheat Codes Featuring Demi Lovato']
# ['Now Or Never', 'Halsey']
# ['Young Dumb & Broke', 'Khalid']
# ['Versace On The Floor', 'Bruno Mars']
# ['Everyday We Lit', 'YFN Lucci Featuring PnB Rock']
# ["It's A Vibe", '2 Chainz Featuring Ty Dolla $ign, Trey Songz & Jhene Aiko']
# ["Drinkin' Problem", 'Midland']
# ['Drowning', 'A Boogie Wit da Hoodie Featuring Kodak Black']
# ['Magnolia', 'Playboi Carti']
# ['Castle On The Hill', 'Ed Sheeran']
# ['The Race', 'Tay-K']
# ['No Such Thing As A Broken Heart', 'Old Dominion']
# ['Crew', 'GoldLink Featuring Brent Faiyaz & Shy Glizzy']
# ['Silence', 'Marshmello Featuring Khalid']
# ['Roll In Peace', 'Kodak Black Featuring XXXTENTACION']
# ['Do Re Mi', 'blackbear']
# ['Fetish', 'Selena Gomez Featuring Gucci Mane']
# ['Heartache On The Dance Floor', 'Jon Pardi']
# ['Butterfly Effect', 'Travis Scott']
# ['When It Rains It Pours', 'Luke Combs']
# ['Thunder', 'Imagine Dragons']
# ['Back To You', 'Louis Tomlinson Featuring Bebe Rexha & Digital Farm Animals']
# ['Felices Los 4', 'Maluma']
# ['You Look Good', 'Lady Antebellum']
# ['Escapate Conmigo', 'Wisin Featuring Ozuna']
# ['Whatever You Need', 'Meek Mill Featuring Chris Brown & Ty Dolla $ign']
# ['DNA.', 'Kendrick Lamar']
# ['Do I Make You Wanna', 'Billy Currington']
# ['Unforgettable', 'Thomas Rhett']
# ['Glorious', 'Macklemore Featuring Skylar Grey']
# ['Somebody Else Will', 'Justin Moore']
# ['Most Girls', 'Hailee Steinfeld']
# ['Love.', 'Kendrick Lamar Featuring Zacari']
# ['The Weekend', 'SZA']
# ['2U', 'David Guetta Featuring Justin Bieber']
# ['New Rules', 'Dua Lipa']
# ['B.E.D.', 'Jacquees']
# ['All The Pretty Girls', 'Kenny Chesney']
# ['Look What You Made Me Do', 'Taylor Swift']
# ['My Girl', 'Dylan Scott']
# ['Younger Now', 'Miley Cyrus']
# ['Its Every Night Sis', 'RiceGum Featuring Alissa Violet']
# ['Honest', 'The Chainsmokers']
# ["Transportin'", 'Kodak Black']
# ["It Ain't My Fault", 'Brothers Osborne']
# ['Every Little Thing', 'Carly Pearce']
# ['Wish I Knew You', 'The Revivalists']
# ["They Don't Know", 'Jason Aldean']
# ['Reminder', 'The Weeknd']
# ['Flatliner', 'Cole Swindell']
# ['More Girls Like You', 'Kip Moore']
# ['Questions', 'Chris Brown']
# ['Perplexing Pegasus', 'Rae Sremmurd']
# ['For Her', 'Chris Lane']
# ['Patty Cake', 'Kodak Black']
# ['Havana', 'Camila Cabello Featuring Young Thug']
# ['4 AM', '2 Chainz Featuring Travis Scott']
# ['Untouchable', 'YoungBoy Never Broke Again']
# ['Privacy', 'Chris Brown']
# ['Relationship', 'Young Thug Featuring Future']
# ['Know No Better', 'Major Lazer Featuring Travis Scott, Camila Cabello & Quavo']
# ['I Could Use A Love Song', 'Maren Morris']
# ['Look What You Made Me Do', 'Taylor Swift']
# ['Despacito', 'Luis Fonsi & Daddy Yankee Featuring Justin Bieber']
# ['Bodak Yellow (Money Moves)', 'Cardi B']
# ['Wild Thoughts', 'DJ Khaled Featuring Rihanna & Bryson Tiller']
# ['Attention', 'Charlie Puth']
# ['Believer', 'Imagine Dragons']
# ['Unforgettable', 'French Montana Featuring Swae Lee']
# ["There's Nothing Holdin' Me Back", 'Shawn Mendes']
# ['1-800-273-8255', 'Logic Featuring Alessia Cara & Khalid']
# ['Strip That Down', 'Liam Payne Featuring Quavo']
# ['Shape Of You', 'Ed Sheeran']
# ['Bank Account', '21 Savage']
# ['Rake It Up', 'Yo Gotti Featuring Nicki Minaj']
# ['Humble.', 'Kendrick Lamar']
# ['Slow Hands', 'Niall Horan']
# ['XO TOUR Llif3', 'Lil Uzi Vert']
# ["That's What I Like", 'Bruno Mars']
# ['Sorry Not Sorry', 'Demi Lovato']
# ['Body Like A Back Road', 'Sam Hunt']
# ['Feel It Still', 'Portugal. The Man']
# ['Congratulations', 'Post Malone Featuring Quavo']
# ['Feels', 'Calvin Harris Featuring Pharrell Williams, Katy Perry & Big Sean']
# ['Mi Gente', 'J Balvin & Willy William Featuring Beyonce']
# ["I'm The One", 'DJ Khaled Featuring Justin Bieber, Quavo, Chance The Rapper & Lil Wayne']
# ['Redbone', 'Childish Gambino']
# ['Something Just Like This', 'The Chainsmokers & Coldplay']
# ['Praying', 'Kesha']
# ['What About Us', 'P!nk']
# ['Location', 'Khalid']
# ['Stay', 'Zedd & Alessia Cara']
# ['Jocelyn Flores', 'XXXTENTACION']
# ['Young Dumb & Broke', 'Khalid']
# ['Friends', 'Justin Bieber + BloodPop']
# ["Say You Won't Let Go", 'James Arthur']
# ['Loyalty.', 'Kendrick Lamar Featuring Rihanna']
# ['Love Galore', 'SZA Featuring Travis Scott']
# ['Mask Off', 'Future']
# ['Small Town Boy', 'Dustin Lynch']
# ['The Way Life Goes', 'Lil Uzi Vert Featuring Nicki Minaj']
# ['What Ifs', 'Kane Brown Featuring Lauren Alaina']
# ['F**k Love', 'XXXTENTACION Featuring Trippie Redd']
# ['I Get The Bag', 'Gucci Mane Featuring Migos']
# ['No Promises', 'Cheat Codes Featuring Demi Lovato']
# ["It Ain't Me", 'Kygo x Selena Gomez']
# ['Thunder', 'Imagine Dragons']
# ['No Such Thing As A Broken Heart', 'Old Dominion']
# ['Swish Swish', 'Katy Perry Featuring Nicki Minaj']
# ["It's A Vibe", '2 Chainz Featuring Ty Dolla $ign, Trey Songz & Jhene Aiko']
# ['Sauce It Up', 'Lil Uzi Vert']
# ['Do Re Mi', 'blackbear']
# ['Crew', 'GoldLink Featuring Brent Faiyaz & Shy Glizzy']
# ['Silence', 'Marshmello Featuring Khalid']
# ['Magnolia', 'Playboi Carti']
# ['Everybody Dies In Their Nightmares', 'XXXTENTACION']
# ["Transportin'", 'Kodak Black']
# ['When It Rains It Pours', 'Luke Combs']
# ['Heartache On The Dance Floor', 'Jon Pardi']
# ['Fetish', 'Selena Gomez Featuring Gucci Mane']
# ['Butterfly Effect', 'Travis Scott']
# ['444+222', 'Lil Uzi Vert']
# ['Roll In Peace', 'Kodak Black Featuring XXXTENTACION']
# ['Back To You', 'Louis Tomlinson Featuring Bebe Rexha & Digital Farm Animals']
# ['DNA.', 'Kendrick Lamar']
# ['The Race', 'Tay-K']
# ['Unforgettable', 'Thomas Rhett']
# ["Drinkin' Problem", 'Midland']
# ['New Rules', 'Dua Lipa']
# ['The Weekend', 'SZA']
# ['Glorious', 'Macklemore Featuring Skylar Grey']
# ['Felices Los 4', 'Maluma']
# ['Versace On The Floor', 'Bruno Mars']
# ['Escapate Conmigo', 'Wisin Featuring Ozuna']
# ['What Lovers Do', 'Maroon 5 Featuring SZA']
# ['Whatever You Need', 'Meek Mill Featuring Chris Brown & Ty Dolla $ign']
# ['All The Pretty Girls', 'Kenny Chesney']
# ['Light It Up', 'Luke Bryan']
# ['Revenge', 'XXXTENTACION']
# ['Do I Make You Wanna', 'Billy Currington']
# ...
# ['Bad At Love', 'Halsey']
# ['Bank Account', '21 Savage']
# ['I Get The Bag', 'Gucci Mane Featuring Migos']
# ['MotorSport', 'Migos, Nicki Minaj & Cardi B']
# ['New Rules', 'Dua Lipa']
# ['Despacito', 'Luis Fonsi & Daddy Yankee Featuring Justin Bieber']
# ['Wolves', 'Selena Gomez X Marshmello']
# ['I Fall Apart', 'Post Malone']
# ['Young Dumb & Broke', 'Khalid']
# ['Believer', 'Imagine Dragons']
# ['...Ready For It?', 'Taylor Swift']
# ['What About Us', 'P!nk']
# ['Praying', 'Kesha']
# ['Rake It Up', 'Yo Gotti Featuring Nicki Minaj']
# ['Unforgettable', 'French Montana Featuring Swae Lee']
# ['Gummo', '6ix9ine']
# ['Attention', 'Charlie Puth']
# ['Shape Of You', 'Ed Sheeran']
# ["That's What I Like", 'Bruno Mars']
# ["There's Nothing Holdin' Me Back", 'Shawn Mendes']
# ['How Long', 'Charlie Puth']
# ['Congratulations', 'Post Malone Featuring Quavo']
# ['Strip That Down', 'Liam Payne Featuring Quavo']
# ['The Weekend', 'SZA']
# ['The Way Life Goes', 'Lil Uzi Vert Featuring Nicki Minaj']
# ['Love.', 'Kendrick Lamar Featuring Zacari']
# ['Slow Hands', 'Niall Horan']
# ['Do Re Mi', 'blackbear']
# ['Meant To Be', 'Bebe Rexha & Florida Georgia Line']
# ['Silence', 'Marshmello Featuring Khalid']
# ['Look What You Made Me Do', 'Taylor Swift']
# ['Greatest Love Story', 'LANCO']
# ['Pills And Automobiles', 'Chris Brown Featuring Yo Gotti, A Boogie Wit da Hoodie & Kodak Black']
# ['Echame La Culpa', 'Luis Fonsi & Demi Lovato']
# ['Let You Down', 'NF']
# ['Humble.', 'Kendrick Lamar']
# ['Plain Jane', 'A$AP Ferg Featuring Nicki Minaj']
# ['When It Rains It Pours', 'Luke Combs']
# ['Rubbin Off The Paint', 'YBN Nahmir']
# ['Let Me Go', 'Hailee Steinfeld & Alesso Featuring Florida Georgia Line & Watt']
# ['Ric Flair Drip', 'Offset & Metro Boomin']
# ['Walk On Water', 'Eminem Featuring Beyonce']
# ['Roll In Peace', 'Kodak Black Featuring XXXTENTACION']
# ['Unforgettable', 'Thomas Rhett']
# ['Sky Walker', 'Miguel Featuring Travis Scott']
# ['Light It Up', 'Luke Bryan']
# ['Love So Soft', 'Kelly Clarkson']
# ['Like I Loved You', 'Brett Young']
# ["I'll Name The Dogs", 'Blake Shelton']
# ['Lemon', 'N*E*R*D & Rihanna']
# ['Wanted You', 'NAV Featuring Lil Uzi Vert']
# ['Ghostface Killers', '21 Savage, Offset & Metro Boomin Featuring Travis Scott']
# ['Candy Paint', 'Post Malone']
# ['Good Old Days', 'Macklemore Featuring Kesha']
# ['Dusk Till Dawn', 'Zayn Featuring Sia']
# ['Betrayed', 'Lil Xan']
# ['Lights Down Low', 'MAX Featuring gnash']
# ['The Race', 'Tay-K']
# ['Round Here Buzz', 'Eric Church']
# ['Yours', 'Russell Dickerson']
# ['Mayores', 'Becky G Featuring Bad Bunny']
# ['Losing Sleep', 'Chris Young']
# ['Ask Me How I Know', 'Garth Brooks']
# ['I Could Use A Love Song', 'Maren Morris']
# ['Fix A Drink', 'Chris Janson']
# ['Awful Things', 'Lil Peep']
# ['F**k Love', 'XXXTENTACION Featuring Trippie Redd']
# ['Relationship', 'Young Thug Featuring Future']
# ["Transportin'", 'Kodak Black']
# ['Jocelyn Flores', 'XXXTENTACION']
# ['Every Little Thing', 'Carly Pearce']
# ['You Broke Up With Me', 'Walker Hayes']
# ['End Game', 'Taylor Swift Featuring Ed Sheeran & Future']
# ['Too Much To Ask', 'Niall Horan']
# ['Sauce It Up', 'Lil Uzi Vert']
# ['Pick It Up', 'Famous Dex Featuring A$AP Rocky']
# ['Home', 'Machine Gun Kelly, X Ambassadors & Bebe Rexha']
# ['Go Flex', 'Post Malone']
# ['When We', 'Tank']
# ['Glorious', 'Macklemore Featuring Skylar Grey']
# ['Questions', 'Chris Brown']
# ['Beautiful Trauma', 'P!nk']
# ['No Smoke', 'YoungBoy Never Broke Again']
# ['Broken Halos', 'Chris Stapleton']
# ['The Rest Of Our Life', 'Tim McGraw & Faith Hill']
# ['Written In The Sand', 'Old Dominion']
# ['Faking It', 'Calvin Harris Featuring Kehlani & Lil Yachty']
# ['Rockstar', 'Post Malone Featuring 21 Savage']
# ['Havana', 'Camila Cabello Featuring Young Thug']
# ['Perfect', 'Ed Sheeran']
# ['Gucci Gang', 'Lil Pump']
# ['Thunder', 'Imagine Dragons']
# ['Too Good At Goodbyes', 'Sam Smith']
# ['Bodak Yellow (Money Moves)', 'Cardi B']
# ['No Limit', 'G-Eazy Featuring A$AP Rocky & Cardi B']
# ['What Lovers Do', 'Maroon 5 Featuring SZA']
# ['Feel It Still', 'Portugal. The Man']
# ['Bad At Love', 'Halsey']
# ['Sorry Not Sorry', 'Demi Lovato']
# ['Mi Gente', 'J Balvin & Willy William Featuring Beyonce']
# ['1-800-273-8255', 'Logic Featuring Alessia Cara & Khalid']
# ['New Rules', 'Dua Lipa']
# ['I Get The Bag', 'Gucci Mane Featuring Migos']
# ['MotorSport', 'Migos, Nicki Minaj & Cardi B']
# ['Bank Account', '21 Savage']
# ['I Fall Apart', 'Post Malone']
# ['Wolves', 'Selena Gomez X Marshmello']
# ['All I Want For Christmas Is You', 'Mariah Carey']
# ['Young Dumb & Broke', 'Khalid']
# ['Despacito', 'Luis Fonsi & Daddy Yankee Featuring Justin Bieber']
# ['Unforgettable', 'French Montana Featuring Swae Lee']
# ['Believer', 'Imagine Dragons']
# ['Shape Of You', 'Ed Sheeran']
# ['Love.', 'Kendrick Lamar Featuring Zacari']
# ['MIC Drop', 'BTS Featuring Desiigner']
# ['Let You Down', 'NF']
# ['Attention', 'Charlie Puth']
# ['...Ready For It?', 'Taylor Swift']
# ['How Long', 'Charlie Puth']
# ['What About Us', 'P!nk']
# ['Rake It Up', 'Yo Gotti Featuring Nicki Minaj']
# ['Praying', 'Kesha']
# ['Silence', 'Marshmello Featuring Khalid']
# ["That's What I Like", 'Bruno Mars']
# ['The Weekend', 'SZA']
# ['The Way Life Goes', 'Lil Uzi Vert Featuring Nicki Minaj']
# ['Meant To Be', 'Bebe Rexha & Florida Georgia Line']
# ['Strip That Down', 'Liam Payne Featuring Quavo']
# ["There's Nothing Holdin' Me Back", 'Shawn Mendes']
# ['Plain Jane', 'A$AP Ferg Featuring Nicki Minaj']
# ['Do Re Mi', 'blackbear']
# ['Congratulations', 'Post Malone Featuring Quavo']
# ['Rubbin Off The Paint', 'YBN Nahmir']
# ['Humble.', 'Kendrick Lamar']
# ['Greatest Love Story', 'LANCO']
# ['Ric Flair Drip', 'Offset & Metro Boomin']
# ['Slow Hands', 'Niall Horan']
# ['Pills And Automobiles', 'Chris Brown Featuring Yo Gotti, A Boogie Wit da Hoodie & Kodak Black']
# ['Codeine Dreaming', 'Kodak Black Featuring Lil Wayne']
# ['Let Me Go', 'Hailee Steinfeld & Alesso Featuring Florida Georgia Line & Watt']
# ['Gummo', '6ix9ine']
# ['Sky Walker', 'Miguel Featuring Travis Scott']
# ['When It Rains It Pours', 'Luke Combs']
# ['Roll In Peace', 'Kodak Black Featuring XXXTENTACION']
# ['Light It Up', 'Luke Bryan']
# ['Unforgettable', 'Thomas Rhett']
# ['Look What You Made Me Do', 'Taylor Swift']
# ["I'll Name The Dogs", 'Blake Shelton']
# ['Like I Loved You', 'Brett Young']
# ['Lemon', 'N*E*R*D & Rihanna']
# ['Candy Paint', 'Post Malone']
# ['Good Old Days', 'Macklemore Featuring Kesha']
# ['Lights Down Low', 'MAX Featuring gnash']
# ['Betrayed', 'Lil Xan']
# ['Round Here Buzz', 'Eric Church']
# ['Yours', 'Russell Dickerson']
# ['Love So Soft', 'Kelly Clarkson']
# ['Ask Me How I Know', 'Garth Brooks']
# ['Wanted You', 'NAV Featuring Lil Uzi Vert']
# ['Losing Sleep', 'Chris Young']
# ['Dusk Till Dawn', 'Zayn Featuring Sia']
# ['Ghostface Killers', '21 Savage, Offset & Metro Boomin Featuring Travis Scott']
# ['Echame La Culpa', 'Luis Fonsi & Demi Lovato']
# ['The Race', 'Tay-K']
# ['I Could Use A Love Song', 'Maren Morris']
# ['Walk On Water', 'Eminem Featuring Beyonce']
# ['Mayores', 'Becky G Featuring Bad Bunny']
# ['F**k Love', 'XXXTENTACION Featuring Trippie Redd']
# ['Pick It Up', 'Famous Dex Featuring A$AP Rocky']
# ['End Game', 'Taylor Swift Featuring Ed Sheeran & Future']
# ['You Broke Up With Me', 'Walker Hayes']
# ['Jocelyn Flores', 'XXXTENTACION']
# ['Krippy Kush', 'Farruko, Nicki Minaj, Bad Bunny, 21 Savage & Rvssian']
# ["Transportin'", 'Kodak Black']
# ['When We', 'Tank']
# ['Too Much To Ask', 'Niall Horan']
# ['Fix A Drink', 'Chris Janson']
# ["It's Everyday Bro", 'Jake Paul Featuring Team 10']
# ['Written In The Sand', 'Old Dominion']
# ['All On Me', 'Devin Dawson']
# ['Faking It', 'Calvin Harris Featuring Kehlani & Lil Yachty']
# ['Go Flex', 'Post Malone']
# ['Sauce It Up', 'Lil Uzi Vert']
# ['Beautiful Trauma', 'P!nk']
# ['Legends', 'Kelsea Ballerini']
# ['Total Eclipse Of The Heart', 'Chloe Kohanski']
# ['Perro Fiel', 'Shakira Featuring Nicky Jam']
# ['Perfect', 'Ed Sheeran']
# ['Rockstar', 'Post Malone Featuring 21 Savage']
# ['Havana', 'Camila Cabello Featuring Young Thug']
# ['Gucci Gang', 'Lil Pump']
# ['Thunder', 'Imagine Dragons']
# ['Too Good At Goodbyes', 'Sam Smith']
# ['No Limit', 'G-Eazy Featuring A$AP Rocky & Cardi B']
# ['Bad At Love', 'Halsey']
# ['Bodak Yellow (Money Moves)', 'Cardi B']
# ['What Lovers Do', 'Maroon 5 Featuring SZA']
# ['All I Want For Christmas Is You', 'Mariah Carey']
# ['Feel It Still', 'Portugal. The Man']
# ['Gummo', '6ix9ine']
# ['I Get The Bag', 'Gucci Mane Featuring Migos']
# ['MotorSport', 'Migos, Nicki Minaj & Cardi B']
# ['Sorry Not Sorry', 'Demi Lovato']
# ['New Rules', 'Dua Lipa']
# ['Mi Gente', 'J Balvin & Willy William Featuring Beyonce']
# ['1-800-273-8255', 'Logic Featuring Alessia Cara & Khalid']
# ['Wolves', 'Selena Gomez X Marshmello']
# ['Him & I', 'G-Eazy & Halsey']
# ['Let You Down', 'NF']
# ['I Fall Apart', 'Post Malone']
# ['Bank Account', '21 Savage']
# ['Shape Of You', 'Ed Sheeran']
# ['How Long', 'Charlie Puth']
# ['Love.', 'Kendrick Lamar Featuring Zacari']
# ['Young Dumb & Broke', 'Khalid']
# ['The Way Life Goes', 'Lil Uzi Vert Featuring Nicki Minaj']
# ['Believer', 'Imagine Dragons']
# ['Meant To Be', 'Bebe Rexha & Florida Georgia Line']
# ['Despacito', 'Luis Fonsi & Daddy Yankee Featuring Justin Bieber']
# ['Silence', 'Marshmello Featuring Khalid']
# ['Unforgettable', 'French Montana Featuring Swae Lee']
# ['Sky Walker', 'Miguel Featuring Travis Scott']
# ['Attention', 'Charlie Puth']
# ["Rockin' Around The Christmas Tree", 'Brenda Lee']
# ['The Weekend', 'SZA']
# ['End Game', 'Taylor Swift Featuring Ed Sheeran & Future']
# ["That's What I Like", 'Bruno Mars']
# ['Plain Jane', 'A$AP Ferg Featuring Nicki Minaj']
# ['The Christmas Song (Merry Christmas To You)', 'Nat King Cole']
# ['...Ready For It?', 'Taylor Swift']
# ['Ric Flair Drip', 'Offset & Metro Boomin']
# ["It's The Most Wonderful Time Of The Year", 'Andy Williams']
# ["There's Nothing Holdin' Me Back", 'Shawn Mendes']
# ['A Holly Jolly Christmas', 'Burl Ives']
# ['Rubbin Off The Paint', 'YBN Nahmir']
# ['Congratulations', 'Post Malone Featuring Quavo']
# ['Humble.', 'Kendrick Lamar']
# ['What About Us', 'P!nk']
# ['Pills And Automobiles', 'Chris Brown Featuring Yo Gotti, A Boogie Wit da Hoodie & Kodak Black']
# ['Tell Me You Love Me', 'Demi Lovato']
# ['Greatest Love Story', 'LANCO']
# ['Let Me Go', 'Hailee Steinfeld & Alesso Featuring Florida Georgia Line & Watt']
# ['Roll In Peace', 'Kodak Black Featuring XXXTENTACION']
# ['Light It Up', 'Luke Bryan']
# ['Codeine Dreaming', 'Kodak Black Featuring Lil Wayne']
# ['Candy Paint', 'Post Malone']
# ['Lemon', 'N*E*R*D & Rihanna']
# ['Kooda', '6ix9ine']
# ['Like I Loved You', 'Brett Young']
# ["I'll Name The Dogs", 'Blake Shelton']
# ['Good Old Days', 'Macklemore Featuring Kesha']
# ['When It Rains It Pours', 'Luke Combs']
# ['Lights Down Low', 'MAX Featuring gnash']
# ['Yours', 'Russell Dickerson']
# ['Betrayed', 'Lil Xan']
# ['Unforgettable', 'Thomas Rhett']
# ['Round Here Buzz', 'Eric Church']
# ['MIC Drop', 'BTS Featuring Desiigner']
# ['Look What You Made Me Do', 'Taylor Swift']
# ['Pick It Up', 'Famous Dex Featuring A$AP Rocky']
# ['The Race', 'Tay-K']
# ['Echame La Culpa', 'Luis Fonsi & Demi Lovato']
# ['Wanted You', 'NAV Featuring Lil Uzi Vert']
# ['Losing Sleep', 'Chris Young']
# ['Dusk Till Dawn', 'Zayn Featuring Sia']
# ['Love So Soft', 'Kelly Clarkson']
# ['I Could Use A Love Song', 'Maren Morris']
# ['Ghostface Killers', '21 Savage, Offset & Metro Boomin Featuring Travis Scott']
# ['F**k Love', 'XXXTENTACION Featuring Trippie Redd']
# ['Mayores', 'Becky G Featuring Bad Bunny']
# ['You Broke Up With Me', 'Walker Hayes']
# ['Krippy Kush', 'Farruko, Nicki Minaj, Bad Bunny, 21 Savage & Rvssian']
# ['When We', 'Tank']
# ['Jocelyn Flores', 'XXXTENTACION']
# ['Written In The Sand', 'Old Dominion']
# ['Too Much To Ask', 'Niall Horan']
# ['Broken Halos', 'Chris Stapleton']
# ['All On Me', 'Devin Dawson']
# ["Transportin'", 'Kodak Black']
# ['Juice', 'Yo Gotti']
# ['Ask Me How I Know', 'Garth Brooks']
# ['Bella y Sensual', 'Romeo Santos Featuring Nicky Jam & Daddy Yankee']
# ['Faking It', 'Calvin Harris Featuring Kehlani & Lil Yachty']
# ['Marry Me', 'Thomas Rhett']
# ['Five More Minutes', 'Scotty McCreery']
# ['Criminal', 'Natti Natasha x Ozuna']
# ['Sauce It Up', 'Lil Uzi Vert']
# ['Perfect', 'Ed Sheeran']
# ['Rockstar', 'Post Malone Featuring 21 Savage']
# ['Havana', 'Camila Cabello Featuring Young Thug']
# ['Gucci Gang', 'Lil Pump']
# ['Thunder', 'Imagine Dragons']
# ['MotorSport', 'Migos, Nicki Minaj & Cardi B']
# ['Too Good At Goodbyes', 'Sam Smith']
# ['Bad At Love', 'Halsey']
# ['All I Want For Christmas Is You', 'Mariah Carey']
# ['No Limit', 'G-Eazy Featuring A$AP Rocky & Cardi B']
# ['Bodak Yellow (Money Moves)', 'Cardi B']
# ['Gummo', '6ix9ine']
# ['What Lovers Do', 'Maroon 5 Featuring SZA']
# ['New Rules', 'Dua Lipa']
# ['I Get The Bag', 'Gucci Mane Featuring Migos']
# ['Let You Down', 'NF']
# ['Feel It Still', 'Portugal. The Man']
# ['Sorry Not Sorry', 'Demi Lovato']
# ['I Fall Apart', 'Post Malone']
# ['Mi Gente', 'J Balvin & Willy William Featuring Beyonce']
# ['Wolves', 'Selena Gomez X Marshmello']
# ['1-800-273-8255', 'Logic Featuring Alessia Cara & Khalid']
# ['Shape Of You', 'Ed Sheeran']
# ['The Way Life Goes', 'Lil Uzi Vert Featuring Nicki Minaj']
# ['Love.', 'Kendrick Lamar Featuring Zacari']
# ['Him & I', 'G-Eazy & Halsey']
# ['Bank Account', '21 Savage']
# ['Meant To Be', 'Bebe Rexha & Florida Georgia Line']
# ['How Long', 'Charlie Puth']
# ['Silence', 'Marshmello Featuring Khalid']
# ['Despacito', 'Luis Fonsi & Daddy Yankee Featuring Justin Bieber']
# ['Young Dumb & Broke', 'Khalid']
# ['Believer', 'Imagine Dragons']
# ["Rockin' Around The Christmas Tree", 'Brenda Lee']
# ["It's The Most Wonderful Time Of The Year", 'Andy Williams']
# ['Sky Walker', 'Miguel Featuring Travis Scott']
# ['...Ready For It?', 'Taylor Swift']
# ['The Christmas Song (Merry Christmas To You)', 'Nat King Cole']
# ['The Weekend', 'SZA']
# ['Unforgettable', 'French Montana Featuring Swae Lee']
# ['A Holly Jolly Christmas', 'Burl Ives']
# ['Attention', 'Charlie Puth']
# ["That's What I Like", 'Bruno Mars']
# ['Last Christmas', 'Wham!']
# ['Ric Flair Drip', 'Offset & Metro Boomin']
# ['Plain Jane', 'A$AP Ferg Featuring Nicki Minaj']
# ['Humble.', 'Kendrick Lamar']
# ["There's Nothing Holdin' Me Back", 'Shawn Mendes']
# ['End Game', 'Taylor Swift Featuring Ed Sheeran & Future']
# ['Kooda', '6ix9ine']
# ['Roll In Peace', 'Kodak Black Featuring XXXTENTACION']
# ['Greatest Love Story', 'LANCO']
# ['Pills And Automobiles', 'Chris Brown Featuring Yo Gotti, A Boogie Wit da Hoodie & Kodak Black']
# ['Like I Loved You', 'Brett Young']
# ['Rubbin Off The Paint', 'YBN Nahmir']
# ['Let Me Go', 'Hailee Steinfeld & Alesso Featuring Florida Georgia Line & Watt']
# ['What About Us', 'P!nk']
# ['Lemon', 'N*E*R*D & Rihanna']
# ['Lights Down Low', 'MAX Featuring gnash']
# ["I'll Name The Dogs", 'Blake Shelton']
# ['Never Be The Same', 'Camila Cabello']
# ['Candy Paint', 'Post Malone']
# ['Codeine Dreaming', 'Kodak Black Featuring Lil Wayne']
# ['Good Old Days', 'Macklemore Featuring Kesha']
# ['Light It Up', 'Luke Bryan']
# ['Yours', 'Russell Dickerson']
# ['Go Legend', 'Big Sean & Metro Boomin Featuring Travis Scott']
# ['When It Rains It Pours', 'Luke Combs']
# ['Round Here Buzz', 'Eric Church']
# ['Look What You Made Me Do', 'Taylor Swift']
# ['Unforgettable', 'Thomas Rhett']
# ['Dark Knight Dummo', 'Trippie Redd Featuring Travis Scott']
# ['Betrayed', 'Lil Xan']
# ['Losing Sleep', 'Chris Young']
# ['Echame La Culpa', 'Luis Fonsi & Demi Lovato']
# ['Pick It Up', 'Famous Dex Featuring A$AP Rocky']
# ['My Dawg', 'Lil Baby']
# ['I Could Use A Love Song', 'Maren Morris']
# ['MIC Drop', 'BTS Featuring Desiigner']
# ['Pull Up N Wreck', 'Big Sean & Metro Boomin Featuring 21 Savage']
# ['Tell Me You Love Me', 'Demi Lovato']
# ['Danger', 'Migos & Marshmello']
# ['You Broke Up With Me', 'Walker Hayes']
# ['Wanted You', 'NAV Featuring Lil Uzi Vert']
# ['Dusk Till Dawn', 'Zayn Featuring Sia']
# ['Untouchable', 'Eminem']
# ['Mayores', 'Becky G Featuring Bad Bunny']
# ['F**k Love', 'XXXTENTACION Featuring Trippie Redd']
# ['Written In The Sand', 'Old Dominion']
# ['Ghostface Killers', '21 Savage, Offset & Metro Boomin Featuring Travis Scott']
# ['Too Much To Ask', 'Niall Horan']
# ['Marry Me', 'Thomas Rhett']
# ['No Smoke', 'YoungBoy Never Broke Again']
# ['When We', 'Tank']
# ['Five More Minutes', 'Scotty McCreery']
# ['Juice', 'Yo Gotti']
# ['All On Me', 'Devin Dawson']
# ['Jocelyn Flores', 'XXXTENTACION']
# ['Legends', 'Kelsea Ballerini']

# %%
#Read data from text file and create a set containing all song titles
sFile = open("Songtest.txt", "r")

songTitles = []
songArtist = []
for line in sFile:
    if "&" not in line and " x " not in line and "Featuring" not in line:
        sline = line.strip()
        splitLine = line.split(": ")
        songTitles.append(splitLine[0])
        songArtist.append(splitLine[1])
       
print(songTitles)
print(songArtist)
# Out:
# ['Blank Space', 'Take Me To Church', 'Lips Are Movin', 'All About That Bass', "I'm Not The Only One", 'Thinking Out Loud', 'Animals', 'Shake It Off', 'Jealous', 'The Heart Wants What It Wants', 'Centuries', 'No Type', 'Habits (Stay High)', 'Waves', "Don't", 'Hot Boy', 'Stay With Me', '7/11', 'CoCo', 'Trumpets', 'Riptide', 'Night Changes', 'Rude', 'Something In The Water', 'L.A.LOVE (la la)', 'Chandelier', 'Sledgehammer', 'Shotgun Rider', 'Ghost', 'Try Me', 'Stolen Dance', 'Anaconda', 'Earned It (Fifty Shades Of Grey)', 'Santa Tell Me', 'Steal My Girl', 'Talladega', 'Sun Daze', 'I Bet My Life', 'I See You', 'Drinking Class', 'God Made Girls', 'I Lived', 'Perfect Storm', 'Dear Future Husband', 'Often', 'Try', 'Mary, Did You Know?', 'Masterpiece', "Just Gettin' Started", 'Make Me Wanna', 'Lonely Eyes', "Til It's Gone", 'Somewhere In My Car', 'Mean To Me', 'Style', 'Close Your Eyes', 'Homegrown Honey', 'No Love', 'Shut Up And Dance', 'Yellow Flicker Beat', 'Break The Rules', 'Something Big', 'Apparently', 'Like A Cowboy', 'Neon Light', "Can't Stop Dancin'", 'Title', 'Blank Space', 'Take Me To Church', 'Thinking Out Loud', 'Lips Are Movin', 'All About That Bass', 'Shake It Off', "I'm Not The Only One", 'Jealous', 'Animals', 'Centuries', 'The Heart Wants What It Wants', 'Stay With Me', 'Habits (Stay High)', 'No Type', 'Waves', "Don't", '7/11', 'Hot Boy', 'CoCo', 'Rude', 'Night Changes', 'Riptide', 'Chandelier', 'L.A.LOVE (la la)', 'Trumpets', 'Ghost', 'Something In The Water', 'Shotgun Rider', 'Stolen Dance', 'Sledgehammer', 'Try Me', 'Anaconda', 'Talladega', 'Sun Daze', 'I Lived', 'Steal My Girl', 'I See You', 'Perfect Storm', 'I Bet My Life', 'Drinking Class', 'Try', "Just Gettin' Started", 'God Made Girls', "Til It's Gone", 'Often', 'Style', 'Make Me Wanna', 'Lonely Eyes', 'Close Your Eyes', 'Mean To Me', 'Shut Up And Dance', 'Somewhere In My
milky Chance\n', 'Fifth Harmony\n', 'Ellie Goulding\n', 'DeJ Loaf\n', 'Tim McGraw\n', 'Eric Church\n', 'Luke Bryan\n', 'Florida Georgia Line\n', 'Fergie\n', 'Brad Paisley\n', 'Kenny Chesney\n', 'Imagine Dragons\n', 'The Weeknd\n', 'Thomas Rhett\n', 'Lee Brice\n', 'Jason Aldean\n', 'One Direction\n', 'RaeLynn\n', 'WALK THE MOON\n', 'Taylor Swift\n', 'Chris Young\n', 'Brett Eldredge\n', 'Sam Hunt\n', 'Fall Out Boy\n', 'Randy Houser\n', 'J. Cole\n', 'Darius Rucker\n', 'The Weeknd\n', 'Keith Urban\n', 'Parmalee\n', 'Sophia Grace\n', 'Cole Swindell\n', 'I Prevail\n', 'August Alsina\n', 'Chase Bryant\n', 'Sheppard\n', 'Jake Owen\n', 'Meghan Trainor\n', 'Tyler Farr\n', 'Blake Shelton\n', 'Ed Sheeran\n', 'Taylor Swift\n', 'Hozier\n', 'Taylor Swift\n', 'Meghan Trainor\n', 'Sam Smith\n', 'Maroon 5\n', 'Nick Jonas\n', 'Meghan Trainor\n', 'Fall Out Boy\n', 'Selena Gomez\n', 'Maroon 5\n', 'Beyonce\n', 'Rae Sremmurd\n', 'Ella Henderson\n', 'Mr. Probz\n', 'O.T. Genasis\n', 'Sam Smith\n', 'Tove Lo\n', 'Sia\n', 'Vance Joy\n', 'Ed Sheeran\n', 'OneRepublic\n', 'Sia\n', 'Bobby Shmurda\n', 'Ellie Goulding\n', 'Kelly Clarkson\n', 'Carrie Underwood\n', 'One Direction\n', 'MAGIC!\n', 'Luke Bryan\n', 'Eric Church\n', 'Zac Brown Band\n', 'Florida Georgia Line\n', 'Fifth Harmony\n', 'Taylor Swift\n', 'DeJ L ...

# %%
for art in artistSet:
    result = sp.search(art) #search query
    print(result['tracks']['items']['artists'])
    #print(result['artists'])
    #print(result['tracks']['items'][0])
    print("\n")
    #print(result['tracks'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-8166497ba883> in <module>
#       1 for art in artistSet:
#       2     result = sp.search(art) #search query
# ----> 3     print(result['tracks']['items']['artists'])
#       4     #print(result['artists'])
#       5     #print(result['tracks']['items'][0])
#
# TypeError: list indices must be integers or slices, not str

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials #To access authorised Spotify data
import matplotlib.pyplot as plt

client_id = "93d31c01487f4b4c982f44ba2d6546a4"
client_secret = "9d8244915bda4809958c7771e3ae5fc9"
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) #spotify object to access API

genre = {}
titles = []
dance = []
energy = []
loud = []

# artist = songArtist[]
# results = sp.search(q='artist:' + name, type='artist')

ind = 0
while ind < len(songArtist):
    name = songArtist[ind];

    results = sp.search(q='artist:' + name, type='artist')
    
    print(ind)
    print(name)
    if 'genres' in results['artists']['items'][0]:
        items = results['artists']['items'][0]['genres']

        for i in items:
            if i not in genre:
                genre[i] = 1
            else:
                x = genre.get(i) + 1
                genre[i] = x;
    print(genre)

    ind = ind + 1
            
# print(results)
# try:
#     if "genre" in results['artists']['items'][0]['genres']:
#         items = results['artists']['items'][0]['genres']
#         for i in items:
#             if i not in genre:
#                 genre[i] = 1
#             else:
#                 genre.update(i, genre[i] + 1)

# except:
#     print("hi")
# print(genre)

        
# ind = 0
# while ind < len(songArtist):
#     artist = songArtist[index]
#     results = sp.search(q='artist:' + name, type='artist')

#     try:
#         if "genre" in results['artists']['items'][0]['genres']:
#             items = results['artists']['items'][0]['genres']
#             for i in items:
#                 if i not in genre:
#                     genre[i] = 1
#                 else:
#                     genre.update(i, genre[i] + 1)
    
#     except:
#         print(results)
    
#     ind = ind + 1;

#     print(genre)
# Out:
# 0
# Taylor Swift
#
# {'pop': 1, 'post-teen pop': 1}
# 1
# Hozier
#
# {'pop': 2, 'post-teen pop': 1, 'folk-pop': 1, 'irish singer-songwriter': 1}
# 2
# Meghan Trainor
#
# {'pop': 3, 'post-teen pop': 2, 'folk-pop': 1, 'irish singer-songwriter': 1, 'dance pop': 1, 'hip pop': 1}
# 3
# Meghan Trainor
#
# {'pop': 4, 'post-teen pop': 3, 'folk-pop': 1, 'irish singer-songwriter': 1, 'dance pop': 2, 'hip pop': 2}
# 4
# Sam Smith
#
# {'pop': 5, 'post-teen pop': 3, 'folk-pop': 1, 'irish singer-songwriter': 1, 'dance pop': 2, 'hip pop': 2, 'uk pop': 1}
# 5
# Ed Sheeran
#
# {'pop': 6, 'post-teen pop': 3, 'folk-pop': 1, 'irish singer-songwriter': 1, 'dance pop': 2, 'hip pop': 2, 'uk pop': 2}
# 6
# Maroon 5
#
# {'pop': 7, 'post-teen pop': 3, 'folk-pop': 1, 'irish singer-songwriter': 1, 'dance pop': 2, 'hip pop': 2, 'uk pop': 2, 'pop rock': 1}
# 7
# Taylor Swift
#
# {'pop': 8, 'post-teen pop': 4, 'folk-pop': 1, 'irish singer-songwriter': 1, 'dance pop': 2, 'hip pop': 2, 'uk pop': 2, 'pop rock': 1}
# 8
# Nick Jonas
#
# {'pop': 9, 'post-teen pop': 5, 'folk-pop': 1, 'irish singer-songwriter': 1, 'dance pop': 3, 'hip pop': 2, 'uk pop': 2, 'pop rock': 1, 'viral pop': 1}
# 9
# Selena Gomez
#
# {'pop': 10, 'post-teen pop': 6, 'folk-pop': 1, 'irish singer-songwriter': 1, 'dance pop': 4, 'hip pop': 2, 'uk pop': 2, 'pop rock': 1, 'viral pop': 1}
# 10
# Fall Out Boy
#
# {'pop': 10, 'post-teen pop': 6, 'folk-pop': 1, 'irish singer-songwriter': 1, 'dance pop': 4, 'hip pop': 2, 'uk pop': 2, 'pop rock': 1, 'viral pop': 1, 'emo': 1, 'modern rock': 1, 'pop punk': 1}
# 11
# Rae Sremmurd
#
# {'pop': 10, 'post-teen pop': 6, 'folk-pop': 1, 'irish singer-songwriter': 1, 'dance pop': 4, 'hip pop': 2, 'uk pop': 2, 'pop rock': 1, 'viral pop': 1, 'emo': 1, 'modern rock': 1, 'pop punk': 1, 'hip hop': 1, 'melodic rap': 1, 'pop rap': 1, 'rap': 1, 'southern hip hop': 1, 'trap': 1}
# 12
# Tove Lo
#
# {'pop': 11, 'post-teen pop': 7, 'folk-pop': 1, 'irish singer-songwriter': 1, 'dance pop': 5, 'hip pop': 2, 'uk pop': 2, 'pop rock': 1, 'viral pop': 1, 'emo': 1, 'modern rock': 1, 'pop punk': 1, 'hip hop': 1, 'melodic rap': 1, 'pop rap': 1, 'rap': 1, 'southern hip hop': 1, 'trap': 1, 'electropop': 1, 'metropopolis': 1, 'swedish electropop': 1, 'swedish pop': 1, 'swedish synthpop': 1, 'tropical house':
# 372
# The Chainsmokers
#
# {'pop': 202, 'post-teen pop': 102, 'folk-pop': 19, 'irish singer-songwriter': 6, 'dance pop': 107, 'hip pop': 19, 'uk pop': 36, 'pop rock': 30, 'viral pop': 11, 'emo': 10, 'modern rock': 26, 'pop punk': 10, 'hip hop': 18, 'melodic rap': 6, 'pop rap': 45, 'rap': 27, 'southern hip hop': 18, 'trap': 26, 'electropop': 10, 'metropopolis': 13, 'swedish electropop': 6, 'swedish pop': 6, 'swedish synthpop': 6, 'tropical house': 24, 'nyc rap': 4, 'r&b': 11, 'gangster rap': 6, 'viral trap': 6, 'urban contemporary': 12, 'boy band': 11, 'talent show': 24, 'reggae fusion': 6, 'contemporary country': 115, 'country': 101, 'country dawn': 5, 'oklahoma country': 8, 'australian dance': 10, 'australian pop': 15, 'girl group': 5, 'country road': 100, 'deep pop r&b': 9, 'detroit hip hop': 5, 'trap queen': 5, 'german pop': 3, 'canadian contemporary r&b': 11, 'canadian pop': 13, 'modern country rock': 73, 'country pop': 23, 'deep talent show': 5, 'neo mellow': 10, 'piano rock': 6, 'a cappella': 1, 'australian country': 3, 'modern uplift': 3, 'indie pop': 5, 'indie poptimism': 5, 'art pop': 2, 'nz pop': 2, 'candy pop': 1, 'conscious hip hop': 6, 'nc hip hop': 6, 'redneck': 10, 'latin': 2, 'latin viral pop': 2, 'rap latina': 2, 'reggaeton': 2, 'australian indie': 4, 'edm': 4, 'social media pop': 1, 'nu-metalcore': 1, 'new jersey rap': 1, 'hawaiian hip hop': 1, 'texas country': 1}
# 373
# Zayn / Taylor Swift
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-155-f4b9851537d6> in <module>
#      25     print(ind)
#      26     print(name)
# ---> 27     if 'genres' in results['artists']['items'][0]:
#      28         items = results['artists']['items'][0]['genres']
#      29
#
# IndexError: list index out of range

# %%
import operator
sorted_val = sorted(genre.items(), key=operator.itemgetter(1))
top5 = sorted_val[len(sorted_val)-5:]
print(top5)
# Out:
# [('country', 101), ('post-teen pop', 102), ('dance pop', 107), ('contemporary country', 115), ('pop', 202)]

# %%
popDance = []
popEnergy = []
popLoudness = []
popTempo = []
popInstrumentalness = []
popAcousticness = []

contemporaryDance = []
contemporaryEnergy = []
contemporaryLoudness = []
contemporaryTempo = []
contemporaryInstrumentalness = []
contemporaryAcousticness = []

danceDance = []
danceEnergy = []
danceLoudness = []
danceTempo = []
danceInstrumentalness = []
danceAcousticness = []

teenDance = []
teenEnergy = []
teenLoudness = []
teenTempo = []
teenInstrumentalness = []
teenAcousticness = []

countryDance = []
countryEnergy = []
countryLoudness = []
countryTempo = []
countryInstrumentalness = []
countryAcousticness = []

# %%
ind = 0
while ind < len(songArtist):
    name = songArtist[ind]
    song = songTitles[ind]

    query = sp.search(name)
    results = sp.search(q='artist:' + name, type='artist')
    song_uri = query['tracks']['items'][0]['uri']
    
    print(results['artists']['items'][0]['genres'])
    print(sp.audio_features(song_uri))
    print
    #song_id = query['tracks']['items'][0]['id']


    if 'genres' in results['artists']['items'][0]:
        items = results['artists']['items'][0]['genres']
        a = sp.audio_features(song_uri)
        print("items")
        print(items)
        for i in items:
            print("i = " + i)
            if i == "pop":
                print("in loop: " + i )
                popDance.append(a[0]['danceability'])
                popEnergy.append(a[0]['energy'])
                popLoudness.append(a[0]['loudness'])
                popTempo.append(a[0]['tempo'])
                popInstrumentalness.append(a[0]['instrumentalness'])
                popAcousticness.append(a[0]['acousticness'])

            if i == "contemporary country":
                contemporaryDance.append(a[0]['danceability'])
                contemporaryEnergy.append(a[0]['energy'])
                contemporaryLoudness.append(a[0]['loudness'])
                contemporaryTempo.append(a[0]['tempo'])
                contemporaryInstrumentalness.append(a[0]['instrumentalness'])
                contemporaryAcousticness.append(a[0]['acousticness'])
                    
            if i == "dance pop":
                danceDance.append(a[0]['danceability'])
                danceEnergy.append(a[0]['energy'])
                danceLoudness.append(a[0]['loudness'])
                danceTempo.append(a[0]['tempo'])
                danceInstrumentalness.append(a[0]['instrumentalness'])
                danceAcousticness.append(a[0]['acousticness'])
                
            if i == "post-teen pop":
                teenDance.append(a[0]['danceability'])
                teenEnergy.append(a[0]['energy'])
                teenLoudness.append(a[0]['loudness'])
                teenTempo.append(a[0]['tempo'])
                teenInstrumentalness.append(a[0]['instrumentalness'])
                teenAcousticness.append(a[0]['acousticness'])
                
            if i == "country":
                countryDance.append(a[0]['danceability'])
                countryEnergy.append(a[0]['energy'])
                countryLoudness.append(a[0]['loudness'])
                countryTempo.append(a[0]['tempo'])
                countryInstrumentalness.append(a[0]['instrumentalness'])
                countryAcousticness.append(a[0]['acousticness']) 
                
    ind = ind + 1
    
print(popDance)
print(contemporaryDance)
print(danceDance)
print(teenDance)
print(countryDance)
# Out:
# ['pop', 'post-teen pop']
# [{'danceability': 0.359, 'energy': 0.543, 'key': 7, 'loudness': -7.582, 'mode': 1, 'speechiness': 0.0919, 'acousticness': 0.492, 'instrumentalness': 1.58e-05, 'liveness': 0.118, 'valence': 0.453, 'tempo': 68.534, 'type': 'audio_features', 'id': '1dGr1c8CrMLDpV6mPbImSI', 'uri': 'spotify:track:1dGr1c8CrMLDpV6mPbImSI', 'track_href': 'https://api.spotify.com/v1/tracks/1dGr1c8CrMLDpV6mPbImSI', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1dGr1c8CrMLDpV6mPbImSI', 'duration_ms': 221307, 'time_signature': 4}]
# items
# ['pop', 'post-teen pop']
# i = pop
# in loop: pop
# i = post-teen pop
# ['folk-pop', 'irish singer-songwriter', 'pop']
# [{'danceability': 0.561, 'energy': 0.597, 'key': 11, 'loudness': -6.0, 'mode': 0, 'speechiness': 0.0405, 'acousticness': 0.286, 'instrumentalness': 0, 'liveness': 0.0979, 'valence': 0.355, 'tempo': 76.826, 'type': 'audio_features', 'id': '1yTTMcUhL7rtz08Dsgb7Qb', 'uri': 'spotify:track:1yTTMcUhL7rtz08Dsgb7Qb', 'track_href': 'https://api.spotify.com/v1/tracks/1yTTMcUhL7rtz08Dsgb7Qb', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1yTTMcUhL7rtz08Dsgb7Qb', 'duration_ms': 197299, 'time_signature': 4}]
# items
# ['folk-pop', 'irish singer-songwriter', 'pop']
# i = folk-pop
# i = irish singer-songwriter
# i = pop
# in loop: pop
# ['dance pop', 'hip pop', 'pop', 'post-teen pop']
# [{'danceability': 0.63, 'energy': 0.53, 'key': 0, 'loudness': -7.259, 'mode': 1, 'speechiness': 0.0434, 'acousticness': 0.4, 'instrumentalness': 0, 'liveness': 0.177, 'valence': 0.417, 'tempo': 108.038, 'type': 'audio_features', 'id': '2YlZnw2ikdb837oKMKjBkW', 'uri': 'spotify:track:2YlZnw2ikdb837oKMKjBkW', 'track_href': 'https://api.spotify.com/v1/tracks/2YlZnw2ikdb837oKMKjBkW', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2YlZnw2ikdb837oKMKjBkW', 'duration_ms': 225053, 'time_signature': 3}]
# items
# ['dance pop', 'hip pop', 'pop', 'post-teen pop']
# i = dance pop
# i = hip pop
# i = pop
# in loop: pop
# i = post-teen pop
# ['dance pop', 'hip pop', 'pop', 'post-teen pop']
# [{'danceability': 0.63, 'energy': 0.53, 'key': 0, 'loudness': -7.259, 'mode': 1, 'speechiness': 0.0434, 'acousticness': 0.4, 'instrumentalness': 0, 'liveness': 0.177, 'valence': 0.417, 'tempo': 108.038, 'type': 'audio_features', 'id': '2YlZnw2ikdb837oKMKjBkW', 'uri': 'spotify:track:2YlZnw2ikdb837oKMKjBkW', 'track_href': 'https://api.spotify.com/v1/tracks/2YlZnw2ikdb837oKMKjBkW', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2YlZnw2ikdb837oKMKjBkW', 'duration_ms': 225053, 'time_signature': 3}]
# items
# ['dance pop', 'hip pop', 'pop', 'post-teen pop']
# i = dance pop
# i = hip pop
# i = pop
# in loop: pop
# i = post-teen pop
# ['pop', 'uk pop']
# [{'danceability': 0.477, 'energy': 0.682, 'key': 1, 'loudness': -4.931, 'mode': 0, 'speechiness': 0.0925, 'acousticness': 0.153, 'instrumentalness': 0, 'liveness': 0.0763, 'valence': 0.345, 'tempo': 110.567, 'type': 'audio_features', 'id': '6b2RcmUt1g9N9mQ3CbjX2Y', 'uri': 'spotify:track:6b2RcmUt1g9N9mQ3CbjX2Y', 'track_href': 'https://api.spotify.com/v1/tracks/6b2RcmUt1g9N9mQ3CbjX2Y', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6b2RcmUt1g9N9mQ3CbjX2Y', 'duration_ms': 202205, 'time_signature': 5}]
# items
# ['pop', 'uk pop']
# i = pop
# in loop: pop
# i = uk pop
# ['pop', 'uk pop']
# [{'danceability': 0.64, 'energy': 0.648, 'key': 5, 'loudness': -8.113, 'mode': 0, 'speechiness': 0.187, 'acousticness': 0.124, 'instrumentalness': 0, 'liveness': 0.0802, 'valence': 0.548, 'tempo': 92.977, 'type': 'audio_features', 'id': '4evmHXcjt3bTUHD1cvny97', 'uri': 'spotify:track:4evmHXcjt3bTUHD1cvny97', 'track_href': 'https://api.spotify.com/v1/tracks/4evmHXcjt3bTUHD1cvny97', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4evmHXcjt3bTUHD1cvny97', 'duration_ms': 197867, 'time_signature': 4}]
# items
# ['pop', 'uk pop']
# i = pop
# in loop: pop
# i = uk pop
# ['pop', 'pop rock']
# [{'danceability': 0.764, 'energy': 0.32, 'key': 11, 'loudness': -7.209, 'mode': 1, 'speechiness': 0.0546, 'acousticness': 0.837, 'instrumentalness': 0, 'liveness': 0.0822, 'valence': 0.575, 'tempo': 91.019, 'type': 'audio_features', 'id': '2b8fOow8UzyDFAE27YhOZM', 'uri': 'spotify:track:2b8fOow8UzyDFAE27YhOZM', 'track_href': 'https://api.spotify.com/v1/tracks/2b8fOow8UzyDFAE27YhOZM', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2b8fOow8UzyDFAE27YhOZM', 'duration_ms': 189486, 'time_signature': 4}]
# items
# ['pop', 'pop rock']
# i = pop
# in loop: pop
# i = pop rock
# ['pop', 'post-teen pop']
# [{'danceability': 0.359, 'energy': 0.543, 'key': 7, 'loudness': -7.582, 'mode': 1, 'speechiness': 0.0919, 'acousticness': 0.492, 'instrumentalness': 1.58e-05, 'liveness': 0.118, 'valence': 0.453, 'tempo': 68.534, 'type': 'audio_features', 'id': '1dGr1c8CrMLDpV6mPbImSI', 'uri': 'spotify:track:1dGr1c8CrMLDpV6mPbImSI', 'track_href': 'https://api.spotify.com/v1/tracks/1dGr1c8CrMLDpV6mPbImSI', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1dGr1c8CrMLDpV6mPbImSI', 'duration_ms': 221307, 'time_signature': 4}]
# items
# ['pop', 'post-teen pop']
# i = pop
# in loop: pop
# i = post-teen pop
# ['dance pop', 'pop', 'post-teen pop', 'viral pop']
# [{'danceability': 0.653, 'energy': 0.623, 'key': 6, 'loudness': -5.273, 'mode': 0, 'speechiness': 0.082, 'acousticness': 0.253, 'instrumentalness': 0, 'liveness': 0.144, 'valence': 0.401, 'tempo': 123.999, 'type': 'audio_features', 'id': '3lSDIJ2abCrOdDJ6pshUap', 'uri': 'spotify:track:3lSDIJ2abCrOdDJ6pshUap', 'track_href': 'https://api.spotify.com/v1/tracks/3lSDIJ2abCrOdDJ6pshUap', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3lSDIJ2abCrOdDJ6pshUap', 'duration_ms': 234213, 'time_signature': 4}]
# items
# ['dance pop', 'pop', 'post-teen pop', 'viral pop']
# i = dance pop
# i = pop
# in loop: pop
# i = post-teen pop
# i = viral pop
# ['dance pop', 'pop', 'post-teen pop']
# [{'danceability': 0.505, 'energy': 0.34, 'key': 4, 'loudness': -9.005, 'mode': 1, 'speechiness': 0.0438, 'acousticness': 0.576, 'instrumentalness': 0, 'liveness': 0.21, 'valence': 0.0916, 'tempo': 101.993, 'type': 'audio_features', 'id': '1HfMVBKM75vxSfsQ5VefZ5', 'uri': 'spotify:track:1HfMVBKM75vxSfsQ5VefZ5', 'track_href': 'https://api.spotify.com/v1/tracks/1HfMVBKM75vxSfsQ5VefZ5', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1HfMVBKM75vxSfsQ5VefZ5', 'duration_ms': 206459, 'time_signature': 4}]
# items
# ['dance pop', 'pop', 'post-teen pop']
# i = dance pop
# i = pop
# in loop: pop
# i = post-teen pop
# ['emo', 'modern rock', 'pop punk']
# [{'danceability': 0.494, 'energy': 0.841, 'key': 7, 'loudness': -4.784, 'mode': 1, 'speechiness': 0.0838, 'acousticness': 0.00579, 'instrumentalness': 0, 'liveness': 0.122, 'valence': 0.567, 'tempo': 162.013, 'type': 'audio_features', 'id': '2TfSHkHiFO4gRztVIkggkE', 'uri': 'spotify:track:2TfSHkHiFO4gRztVIkggkE', 'track_href': 'https://api.spotify.com/v1/tracks/2TfSHkHiFO4gRztVIkggkE', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2TfSHkHiFO4gRztVIkggkE', 'duration_ms': 229093, 'time_signature': 4}]
# items
# ['emo', 'modern rock', 'pop punk']
# i = emo
# i = modern rock
# i = pop punk
# ['hip hop', 'melodic rap', 'pop rap', 'rap', 'southern hip hop', 'trap']
# [{'danceability': 0.689, 'energy': 0.564, 'key': 2, 'loudness': -6.226, 'mode': 1, 'speechiness': 0.136, 'acousticness': 0.187, 'instrumentalness': 0, 'liveness': 0.0721, 'valence': 0.123, 'tempo': 185.023, 'type': 'audio_features', 'id': '1Ser4X0TKttOvo8bgdytTP', 'uri': 'spotify:track:1Ser4X0TKttOvo8bgdytTP', 'track_href': 'https://api.spotify.com/v1/tracks/1Ser4X0TKttOvo8bgdytTP', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Ser4X0TKttOvo8bgdytTP', 'duration_ms': 212947, 'time_signature': 4}]
# items
# ['hip hop', 'melodic rap', 'pop rap', 'rap', 'southern hip hop', 'trap']
# i = hip hop
# i = melodic rap
# i = pop rap
# i = rap
# i = southern hip hop
# i = trap
# ['dance pop', 'electropop', 'metropopolis', 'pop', 'post-teen pop', 'swedish electropop', 'swedish pop', 'swedish synthpop', 'tropical house']
# [{'danceability': 0.598, 'energy': 0.532, 'key': 3, 'loudness': -6.833, 'mode': 0, 'speechiness': 0.0295, 'acousticness': 0.0668, 'instrumentalness': 3.22e-06, 'liveness': 0.0617, 'valence': 0.261, 'tempo': 74.963, 'type': 'audio_features', 'id': '5aOpzm8W8zysk4asB9hxJw', 'uri': 'spotify:track:5aOpzm8W8zysk4asB9hxJw', 'track_href': 'https://api.spotify.com/v1/tracks/5aOpzm8W8zysk4asB9hxJw', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5aOpzm8W8zysk4asB9hxJw', 'duration_ms': 262521, 'time_signature': 4}]
# items
# ['dance pop', 'electropop', 'metropopolis', 'pop', 'post-teen pop', 'swedish electropop', 'swedish pop', 'swedish synthpop', 'tropical house']
# i = dance pop
# i = electropop
# i = metropopolis
# i = pop
# in loop: pop
# i = post-teen pop
# i = swedish electropop
# i = swedish pop
# i = swedish synthpop
# i = tropical house
# ['tropical house']
# [{'danceability': 0.547, 'energy': 0.795, 'key': 8, 'loudness': -3.721, 'mode': 1, 'speechiness': 0.0489, 'acousticness': 0.145, 'instrumentalness': 0, 'liveness': 0.11, 'valence': 0.723, 'tempo': 118.118, 'type': 'audio_features', 'id': '35MKhw2YBKApmD7fAnPERC', 'uri': 'spotify:track:35MKhw2YBKApmD7fAnPERC', 'track_href': 'https://api.spotify.com/v1/tracks/35MKhw2YBKApmD7fAnPERC', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/35MKhw2YBKApmD7fAnPERC', 'duration_ms': 186805, 'time_signature': 4}]
# items
# ['tropical house']
# i = tropical house
# ['pop', 'uk pop']
# [{'danceability': 0.64, 'energy': 0.648, 'key': 5, 'loudness': -8.113, 'mode': 0, 'speechiness': 0.187, 'acousticness': 0.124, 'instrumentalness': 0, 'liveness': 0.0802, 'valence': 0.548, 'tempo': 92.977, 'type': 'audio_features', 'id': '4evmHXcjt3bTUHD1cvny97', 'uri': 'spotify:track:4evmHXcjt3bTUHD1cvny97', 'track_href': 'https://api.spotify.com/v1/tracks/4evmHXcjt3bTUHD1cvny97', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4evmHXcjt3bTUHD1cvny97', 'duration_ms': 197867, 'time_signature': 4}]
# items
# ['pop', 'uk pop']
# i = pop
# in loop: pop
# i = uk pop
# ['nyc rap', 'pop rap', 'trap']
# [{'danceability': 0.794, 'energy': 0.51, 'key': 9, 'loudness': -7.314, 'mode': 1, 'speechiness': 0.42, 'acousticness': 0.0505, 'instrumentalness': 1.81e-06, 'liveness': 0.0562, 'valence': 0.18, 'tempo': 167.879, 'type': 'audio_features', 'id': '19gEmPjfqSZT0ulDRfjl0m', 'uri': 'spotify:track:19gEmPjfqSZT0ulDRfjl0m', 'track_href': 'https://api.spotify.com/v1/tracks/19gEmPjfqSZT0ulDRfjl0m', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/19gEmPjfqSZT0ulDRfjl0m', 'duration_ms': 194561, 'time_signature': 4}]
# items
# ['nyc rap', 'pop rap', 'trap']
# i = nyc rap
# i = pop rap
# i = trap
# ['pop', 'uk pop']
# [{'danceability': 0.477, 'energy': 0.682, 'key': 1, 'loudness': -4.931, 'mode': 0, 'speechiness': 0.0925, 'acousticness': 0.153, 'instrumentalness': 0, 'liveness': 0.0763, 'valence': 0.345, 'tempo': 110.567, 'type': 'audio_features', 'id': '6b2RcmUt1g9N9mQ3CbjX2Y', 'uri': 'spotify:track:6b2RcmUt1g9N9mQ3CbjX2Y', 'track_href': 'https://api.spotify.com/v1/tracks/6b2RcmUt1g9N9mQ3CbjX2Y', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6b2RcmUt1g9N9mQ3CbjX2Y', 'duration_ms': 202205, 'time_signature': 5}]
# items
# ['pop', 'uk pop']
# i = pop
# in loop: pop
# i = uk pop
# ['dance pop', 'pop', 'r&b']
# [{'danceability': 0.508, 'energy': 0.72, 'key': 11, 'loudness': -5.908, 'mode': 0, 'speechiness': 0.0628, 'acousticness': 0.272, 'instrumentalness': 0, 'liveness': 0.0563, 'valence': 0.472, 'tempo': 79.983, 'type': 'audio_features', 'id': '4JehYebiI9JE8sR8MisGVb', 'uri': 'spotify:track:4JehYebiI9JE8sR8MisGVb', 'track_href': 'https://api.spotify.com/v1/tracks/4JehYebiI9JE8sR8MisGVb', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4JehYebiI9JE8sR8MisGVb', 'duration_ms': 261640, 'time_signature': 4}]
# items
# ['dance pop', 'pop', 'r&b']
# i = dance pop
# i = pop
# in loop: pop
# i = r&b
# ['gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap', 'viral trap']
# [{'danceability': 0.873, 'energy': 0.591, 'key': 2, 'loudness': -5.928, 'mode': 1, 'speechiness': 0.226, 'acousticness': 0.168, 'instrumentalness': 0, 'liveness': 0.117, 'valence': 0.277, 'tempo': 100.515, 'type': 'audio_features', 'id': '7kUycEYvdRdHmXmxRiywPE', 'uri': 'spotify:track:7kUycEYvdRdHmXmxRiywPE', 'track_href': 'https://api.spotify.com/v1/tracks/7kUycEYvdRdHmXmxRiywPE', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7kUycEYvdRdHmXmxRiywPE', 'duration_ms': 143333, 'time_signature': 4}]
# items
# ['gangster rap', 'hip hop', 'pop rap', 'rap', 'southern hip hop', 'trap', 'viral trap']
# i = gangster rap
# i = hip hop
# i = pop rap
# i = rap
# i = southern hip hop
# i = trap
# i = viral trap
# ['dance pop', 'pop', 'pop rap', 'post-teen pop', 'urban contemporary']
# [{'danceability': 0.615, 'energy': 0.711, 'key': 11, 'loudness': -5.507, 'mode': 1, 'speechiness': 0.0779, 'acousticness': 0.0444, 'instrumentalness': 0, 'liveness': 0.145, 'valence': 0.711, 'tempo': 144.036, 'type': 'audio_features', 'id': '67T6l4q3zVjC5nZZPXByU8', 'uri': 'spotify:track:67T6l4q3zVjC5nZZPXByU8', 'track_href': 'https://api.spotify.com/v1/tracks/67T6l4q3zVjC5nZZPXByU8', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/67T6l4q3zVjC5nZZPXByU8', 'duration_ms': 221253, 'time_signature': 4}]
# items
# ['dance pop', 'pop', 'pop rap', 'post-teen pop', 'urban contemporary']
# i = dance pop
# i = pop
# in loop: pop
# i = pop rap
# i = post-teen pop
# i = urban contemporary
# ['folk-pop', 'modern rock', 'pop', 'pop rock']
# [{'danceability': 0.484, 'energy': 0.731, 'key': 1, 'loudness': -6.694, 'mode': 1, 'speechiness': 0.0379, 'acousticness': 0.431, 'instrumentalness': 0, 'liveness': 0.151, 'valence': 0.51, 'tempo': 101.654, 'type': 'audio_features', 'id': '3JvrhDOgAt6p7K8mDyZwRd', 'uri': 'spotify:track:3JvrhDOgAt6p7K8mDyZwRd', 'track_href': 'https://api.spotify.com/v1/tracks/3JvrhDOgAt6p7K8mDyZwRd', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3JvrhDOgAt6p7K8mDyZwRd', 'duration_ms': 204280, 'time_signature': 4}]
# items
# ['folk-pop', 'modern rock', 'pop', 'pop rock']
# i = folk-pop
# i = modern rock
# i = pop
# in loop: pop
# i = pop rock
# ['boy band', 'dance pop', 'pop', 'post-teen pop', 'talent show']
# [{'danceability': 0.6, 'energy': 0.663, 'key': 3, 'loudness': -5.802, 'mode': 1, 'speechiness': 0.0477, 'acousticness': 0.225, 'instrumentalness': 0, 'liveness': 0.119, 'valence': 0.286, 'tempo': 121.07, 'type': 'audio_features', 'id': '4nVBt6MZDDP6tRVdQTgxJg', 'uri': 'spotify:track:4nVBt6MZDDP6tRVdQTgxJg', 'track_href': 'https://api.spotify.com/v1/tracks/4nVBt6MZDDP6tRVdQTgxJg', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4nVBt6MZDDP6tRVdQTgxJg', 'duration_ms': 245493, 'time_signature': 4}]
# items
# ['boy band', 'dance pop', 'pop', 'post-teen pop', 'talent show']
# i = boy band
# i = dance pop
# i = pop
# in loop: pop
# i = post-teen pop
# i = talent show
# ['pop', 'reggae fusion']
# [{'danceability': 0.647, 'energy': 0.706, 'key': 6, 'loudness': -6.023, 'mode': 0, 'speechiness': 0.137, 'acousticness': 0.264, 'instrumentalness': 0, 'liveness': 0.114, 'valence': 0.577, 'tempo': 153.973, 'type': 'audio_features', 'id': '5NqOsPI4rA9Bl6LcCftzI2', 'uri': 'spotify:track:5NqOsPI4rA9Bl6LcCftzI2', 'track_href': 'https://api.spotify.com/v1/tracks/5NqOsPI4rA9Bl6LcCftzI2', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5NqOsPI4rA9Bl6LcCftzI2', 'duration_ms': 182338, 'time_signature': 4}]
# items
# ['pop', 'reggae fusion']
# i = pop
# in loop: pop
# i = reggae fusion
# ['contemporary country', 'country', 'country dawn', 'oklahoma country', 'pop', 'post-teen pop']
# [{'danceability': 0.519, 'energy': 0.749, 'key': 6, 'loudness': -3.318, 'mode': 0, 'speechiness': 0.0405, 'acousticness': 0.271, 'instrumentalness': 0, 'liveness': 0.119, 'valence': 0.29, 'tempo': 147.905, 'type': 'audio_features', 'id': '0ZUo4YjG4saFnEJhdWp9Bt', 'uri': 'spotify:track:0ZUo4YjG4saFnEJhdWp9Bt', 'track_href': 'https://api.spotify.com/v1/tracks/0ZUo4YjG4saFnEJhdWp9Bt', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0ZUo4YjG4saFnEJhdWp9Bt', 'duration_ms': 199947, 'time_signature': 4}]
# items
# ['contemporary country', 'country', 'country dawn', 'oklahoma country', 'pop', 'post-teen pop']
# i = contemporary country
# i = country
# i = country dawn
# i = oklahoma country
# i = pop
# in loop: pop
# i = post-teen pop
# ['dance pop', 'pop', 'pop rap', 'post-teen pop', 'urban contemporary']
# [{'danceability': 0.906, 'energy': 0.584, 'key': 8, 'loudness': -7.72, 'mode': 0, 'speechiness': 0.316, 'acousticness': 0.0576, 'instrumentalness': 0, 'liveness': 0.128, 'valence': 0.831, 'tempo': 129.055, 'type': 'audio_features', 'id': '1D066zixBwqFYqBhKgdPzp', 'uri': 'spotify:track:1D066zixBwqFYqBhKgdPzp', 'track_href': 'https://api.spotify.com/v1/tracks/1D066zixBwqFYqBhKgdPzp', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1D066zixBwqFYqBhKgdPzp', 'duration_ms': 292373, 'time_signature': 4}]
# items
# ['dance pop', 'pop', 'pop rap', 'post-teen pop', 'urban contemporary']
# i = dance pop
# i = pop
# in loop: pop
# i = pop rap
# i = post-teen pop
# i = urban contemporary
# ['australian dance', 'australian pop', 'dance pop', 'pop']
# [{'danceability': 0.604, 'energy': 0.787, 'key': 0, 'loudness': -3.674, 'mode': 0, 'speechiness': 0.103, 'acousticness': 0.0679, 'instrumentalness': 0.15, 'liveness': 0.127, 'valence': 0.301, 'tempo': 126.062, 'type': 'audio_features', 'id': '77TT8Xvx637TpzV8kKGkUw', 'uri': 'spotify:track:77TT8Xvx637TpzV8kKGkUw', 'track_href': 'https://api.spotify.com/v1/tracks/77TT8Xvx637TpzV8kKGkUw', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/77TT8Xvx637TpzV8kKGkUw', 'duration_ms': 245040, 'time_signature': 4}]
# items
# ['australian dance', 'australian pop', 'dance pop', 'pop']
# i = australian dance
# i = australian pop
# i = dance pop
# i = pop
# in loop: pop
# ['dance pop', 'girl group', 'pop', 'post-teen pop', 'talent show']
# [{'danceability': 0.803, 'energy': 0.585, 'key': 8, 'loudness': -5.861, 'mode': 1, 'speechiness': 0.0432, 'acousticness': 0.103, 'instrumentalness': 3.94e-06, 'liveness': 0.0644, 'valence': 0.593, 'tempo': 105.017, 'type': 'audio_features', 'id': '4tCtwWceOPWzenK2HAIJSb', 'uri': 'spotify:track:4tCtwWceOPWzenK2HAIJSb', 'track_href': 'https://api.spotify.com/v1/tracks/4tCtwWceOPWzenK2HAIJSb', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4tCtwWceOPWzenK2HAIJSb', 'duration_ms': 214480, 'time_signature': 4}]
# items
# ['dance pop', 'girl group', 'pop', 'post-teen pop', 'talent show']
# i = dance pop
# i = girl group
# i = pop
# in loop: pop
# i = post-teen pop
# i = talent show
# ['contemporary country', 'country', 'country road']
# [{'danceability': 0.355, 'energy': 0.48, 'key': 11, 'loudness': -7.31, 'mode': 1, 'speechiness': 0.0282, 'acousticness': 0.679, 'instrumentalness': 2.28e-06, 'liveness': 0.12, 'valence': 0.137, 'tempo': 100.956, 'type': 'audio_features', 'id': '4Pn0JlCUusD2QHjADuOzuV', 'uri': 'spotify:track:4Pn0JlCUusD2QHjADuOzuV', 'track_href': 'https://api.spotify.com/v1/tracks/4Pn0JlCUusD2QHjADuOzuV', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Pn0JlCUusD2QHjADuOzuV', 'duration_ms': 259267, 'time_signature': 3}]
# items
# ['contemporary country', 'country', 'country road']
# i = contemporary country
# i = country
# i = country road
# ['dance pop', 'pop', 'post-teen pop', 'talent show', 'tropical house', 'uk pop']
# [{'danceability': 0.684, 'energy': 0.819, 'key': 6, 'loudness': -5.072, 'mode': 1, 'speechiness': 0.0413, 'acousticness': 0.0259, 'instrumentalness': 0.0775, 'liveness': 0.0985, 'valence': 0.607, 'tempo': 122.008, 'type': 'audio_features', 'id': '1pRShUtGOG6ZP5fsnw9G4h', 'uri': 'spotify:track:1pRShUtGOG6ZP5fsnw9G4h', 'track_href': 'https://api.spotify.com/v1/tracks/1pRShUtGOG6ZP5fsnw9G4h', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1pRShUtGOG6ZP5fsnw9G4h', 'duration_ms': 199160, 'time_signature': 4}]
# items
# ['dance pop', 'pop', 'post-teen pop', 'talent show', 'tropical house', 'uk pop']
# i = dance pop
# i = pop
# in loop: pop
# i = post-teen pop
# i = talent show
# i = tropical house
# i = uk pop
# ['deep pop r&b', 'detroit hip hop', 'pop rap', 'rap', 'trap', 'trap queen']
# [{'danceability': 0.79, 'energy': 0.472, 'key': 1, 'loudness': -6.999, 'mode': 0, 'speechiness': 0.0656, 'acousticness': 0.325, 'instrumentalness': 5.83e-06, 'liveness': 0.276, 'valence': 0.287, 'tempo': 115.055, 'type': 'audio_features', 'id': '7izlgARoZsidRx23DOBhad', 'uri': 'spotify:track:7izlgARoZsidRx23DOBhad', 'track_href': 'https://api.spotify.com/v1/tracks/7izlgARoZsidRx23DOBhad', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7izlgARoZsidRx23DOBhad', 'duration_ms': 218697, 'time_signature': 4}]
# items
# ['deep pop r&b', 'detroit hip hop', 'pop rap', 'rap', 'trap', 'trap queen']
# i = deep pop r&b
# i = detroit hip hop
# i = pop rap
# i = rap
# i = trap
# i = trap queen
# ['german pop']
# [{'danceability': 0.887, 'energy': 0.584, 'key': 11, 'loudness': -8.798, 'mode': 1, 'speechiness': 0.0381, 'acousticness': 0.41, 'instrumentalness': 0.000314, 'liveness': 0.101, 'valence': 0.677, 'tempo': 114.016, 'type': 'audio_features', 'id': '6vECYJHxYmm3Ydt3fF01pE', 'uri': 'spotify:track:6vECYJHxYmm3Ydt3fF01pE', 'track_href': 'https://api.spotify.com/v1/tracks/6vECYJHxYmm3Ydt3fF01pE', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6vECYJHxYmm3Ydt3fF01pE', 'duration_ms': 313684, 'time_signature': 4}]
# items
# ['german pop']
# i = german pop
# ['dance pop', 'hip pop', 'pop', 'pop rap', 'post-teen pop', 'rap']
# [{'danceability': 0.872, 'energy': 0.814, 'key': 0, 'loudness': -4.568, 'mode': 1, 'speechiness': 0.155, 'acousticness': 0.00485, 'instrumentalness': 1.96e-06, 'liveness': 0.214, 'valence': 0.57, 'tempo': 98.985, 'type': 'audio_features', 'id': '5N1o6d8zGcSZSeMFkOUQOk', 'uri': 'spotify:track:5N1o6d8zGcSZSeMFkOUQOk', 'track_href': 'https://api.spotify.com/v1/tracks/5N1o6d8zGcSZSeMFkOUQOk', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5N1o6d8zGcSZSeMFkOUQOk', 'duration_ms': 199427, 'time_signature': 4}]
# items
# ['dance pop', 'hip pop', 'pop', 'pop rap', 'post-teen pop', 'rap']
# i = dance pop
# i = hip pop
# i = pop
# in loop: pop
# i = pop rap
# i = post-teen pop
# i = rap
# ['canadian contemporary r&b', 'canadian pop', 'pop']
# [{'danceability': 0.531, 'energy': 0.75, 'key': 10, 'loudness': -5.831, 'mode': 0, 'speechiness': 0.111, 'acousticness': 0.00632, 'instrumentalness': 7.6e-05, 'liveness': 0.117, 'valence': 0.198, 'tempo': 169.954, 'type': 'audio_features', 'id': '57vxBYXtHMk6H1aD29V7PU', 'uri': 'spotify:track:57vxBYXtHMk6H1aD29V7PU', 'track_href': 'https://api.spotify.com/v1/tracks/57vxBYXtHMk6H1aD29V7PU', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/57vxBYXtHMk6H1aD29V7PU', 'duration_ms': 200080, 'time_signature': 4}]
# items
# ['canadian contemporary r&b', 'canadian pop', 'pop']
# i = canadian contemporary r&b
# i = canadian pop
# i = pop
# in loop: pop
# ['dance pop', 'pop', 'post-teen pop']
# [{'danceability': 0.668, 'energy': 0.892, 'key': 5, 'loudness': -3.001, 'mode': 0, 'speechiness': 0.0645, 'acousticness': 0.298, 'instrumentalness': 0, 'liveness': 0.735, 'valence': 0.478, 'tempo': 95.927, 'type': 'audio_features', 'id': '07Oz5StQ7GRoygNLaXs2pd', 'uri': 'spotify:track:07Oz5StQ7GRoygNLaXs2pd', 'track_href': 'https://api.spotify.com/v1/tracks/07Oz5StQ7GRoygNLaXs2pd', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/07Oz5StQ7GRoygNLaXs2pd', 'duration_ms': 159011, 'time_signature': 4}]
# items
# ['dance pop', 'pop', 'post-teen pop']
# i = dance pop
# i = pop
# in loop: pop
# i = post-teen pop
# ['boy band', 'dance pop', 'pop', 'post-teen pop', 'talent show']
# [{'danceability': 0.6, 'energy': 0.663, 'key': 3, 'loudness': -5.802, 'mode': 1, 'speechiness': 0.0477, 'acousticness': 0.225, 'instrumentalness': 0, 'liveness': 0.119, 'valence': 0.286, 'tempo': 121.07, 'type': 'audio_features', 'id': '4nVBt6MZDDP6tRVdQTgxJg', 'uri': 'spotify:track:4nVBt6MZDDP6tRVdQTgxJg', 'track_href': 'https://api.spotify.com/v1/tracks/4nVBt6MZDDP6tRVdQTgxJg', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4nVBt6MZDDP6tRVdQTgxJg', 'duration_ms': 245493, 'time_signature': 4}]
# items
# ['boy band', 'dance pop', 'pop', 'post-teen pop', 'talent show']
# i = boy band
# i = dance pop
# i = pop
# in loop: pop
# i = post-teen pop
# i = talent show
# ['contemporary country', 'country', 'country road', 'modern country rock']
# [{'danceability': 0.616, 'energy': 0.849, 'key': 0, 'loudness': -4.897, 'mode': 1, 'speechiness': 0.0373, 'acousticness': 0.308, 'instrumentalness': 0, 'liveness': 0.311, 'valence': 0.639, 'tempo': 113.066, 'type': 'audio_features', 'id': '17TSJlshgQ5zu0e8dedAla', 'uri': 'spotify:track:17TSJlshgQ5zu0e8dedAla', 'track_href': 'https://api.spotify.com/v1/tracks/17TSJlshgQ5zu0e8dedAla', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/17TSJlshgQ5zu0e8dedAla', 'duration_ms': 223320, 'time_signature': 4}]
# items
# ['contemporary country', 'country', 'country road', 'modern country rock']
# i = contemporary country
# i = country
# i = country road
# i = modern country rock
# ['contemporary country', 'country', 'country pop', 'country road', 'modern country rock']
# [{'danceability': 0.643, 'energy': 0.783, 'key': 10, 'loudness': -6.458, 'mode': 1, 'speechiness': 0.0856, 'acousticness': 0.047, 'instrumentalness': 0, 'liveness': 0.083, 'valence': 0.579, 'tempo': 154.084, 'type': 'audio_features', 'id': '7iDa6hUg2VgEL1o1HjmfBn', 'uri': 'spotify:track:7iDa6hUg2VgEL1o1HjmfBn', 'track_href': 'https://api.spotify.com/v1/tracks/7iDa6hUg2VgEL1o1HjmfBn', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7iDa6hUg2VgEL1o1HjmfBn', 'duration_ms': 163870, 'time_signature': 4}]
# items
# ['contemporary country', 'country', 'country pop', 'country road', 'modern country rock']
# i = contemporary country
# i = country
# i = country pop
# i = country road
# i = modern country rock
# ['modern rock']
# [{'danceability': 0.776, 'energy': 0.78, 'key': 10, 'loudness': -4.374, 'mode': 0, 'speechiness': 0.128, 'acousticness': 0.0622, 'instrumentalness': 0, 'liveness': 0.081, 'valence': 0.666, 'tempo': 124.949, 'type': 'audio_features', 'id': '0pqnGHJpmpxLKifKRmU6WP', 'uri': 'spotify:track:0pqnGHJpmpxLKifKRmU6WP', 'track_href': 'https://api.spotify.com/v1/tracks/0pqnGHJpmpxLKifKRmU6WP', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0pqnGHJpmpxLKifKRmU6WP', 'duration_ms': 204347, 'time_signature': 4}]
# items
# ['modern rock']
# i = modern rock
# ['contemporary country', 'country', 'country road']
# [{'danceability': 0.739, 'energy': 0.682, 'key': 2, 'loudness': -3.728, 'mode': 1, 'speechiness': 0.205, 'acousticness': 0.129, 'instrumentalness': 0, 'liveness': 0.328, 'valence': 0.634, 'tempo': 131.983, 'type': 'audio_features', 'id': '6ERR6e7h6wCqGoz1TjiUJb', 'uri': 'spotify:track:6ERR6e7h6wCqGoz1TjiUJb', 'track_href': 'https://api.spotify.com/v1/tracks/6ERR6e7h6wCqGoz1TjiUJb', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6ERR6e7h6wCqGoz1TjiUJb', 'duration_ms': 199382, 'time_signature': 4}]
# items
# ['contemporary country', 'country', 'country road']
# i = contemporary country
# i = country
# i = country road
# ['contemporary country', 'country', 'country road', 'modern country rock']
# [{'danceability': 0.655, 'energy': 0.56, 'key': 9, 'loudness': -6.857, 'mode': 1, 'speechiness': 0.0486, 'acousticness': 0.749, 'instrumentalness': 0, 'liveness': 0.115, 'valence': 0.599, 'tempo': 140.975, 'type': 'audio_features', 'id': '56eGOeSsqdg3FLxdo83TwV', 'uri': 'spotify:track:56eGOeSsqdg3FLxdo83TwV', 'track_href': 'https://api.spotify.com/v1/tracks/56eGOeSsqdg3FLxdo83TwV', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/56eGOeSsqdg3FLxdo83TwV', 'duration_ms': 198440, 'time_signature': 4}]
# items
# ['contemporary country', 'country', 'country road', 'modern country rock']
# i = contemporary country
# i = country
# i = country road
# i = modern country rock
# ['contemporary country', 'country pop', 'deep talent show']
# [{'danceability': 0.588, 'energy': 0.722, 'key': 6, 'loudness': -4.667, 'mode': 1, 'speechiness': 0.0289, 'acousticness': 0.0663, 'instrumentalness': 0, 'liveness': 0.0721, 'valence': 0.243, 'tempo': 145.931, 'type': 'audio_features', 'id': '2Wj1AZdBPMA1mkuuoTfOPg', 'uri': 'spotify:track:2Wj1AZdBPMA1mkuuoTfOPg', 'track_href': 'https://api.spotify.com/v1/tracks/2Wj1AZdBPMA1mkuuoTfOPg', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Wj1AZdBPMA1mkuuoTfOPg', 'duration_ms': 224107, 'time_signature': 4}]
# items
# ['contemporary country', 'country pop', 'deep talent show']
# i = contemporary country
# i = country pop
# i = deep talent show
# ['dance pop', 'neo mellow', 'piano rock', 'pop', 'pop rock']
# [{'danceability': 0.759, 'energy': 0.605, 'key': 7, 'loudness': -7.737, 'mode': 1, 'speechiness': 0.0433, 'acousticness': 0.156, 'instrumentalness': 0, 'liveness': 0.694, 'valence': 0.64, 'tempo': 121.049, 'type': 'audio_features', 'id': '0mjAU3yKR1QnXnHtjGJqTM', 'uri': 'spotify:track:0mjAU3yKR1QnXnHtjGJqTM', 'track_href': 'https://api.spotify.com/v1/tracks/0mjAU3yKR1QnXnHtjGJqTM', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0mjAU3yKR1QnXnHtjGJqTM', 'duration_ms': 158900, 'time_signature': 4}]
# items
# ['dance pop', 'neo mellow', 'piano rock', 'pop', 'pop rock']
# i = dance pop
# i = neo mellow
# i = piano rock
# i = pop
# in loop: pop
# i = pop rock
# ['contemporary country', 'country', 'country road', 'modern country rock']
# [{'danceability': 0.355, 'energy': 0.478, 'key': 0, 'loudness': -8.323, 'mode': 1, 'speechiness': 0.0335, 'acousticness': 0.569, 'instrumentalness': 2.9e-06, 'liveness': 0.194, 'valence': 0.269, 'tempo': 102.971, 'type': 'audio_features', 'id': '3dAgQFdruU8ufWc5GE05xC', 'uri': 'spotify:track:3dAgQFdruU8ufWc5GE05xC', 'track_href': 'https://api.spotify.com/v1/tracks/3dAgQFdruU8ufWc5GE05xC', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3dAgQFdruU8ufWc5GE05xC', 'duration_ms': 266920, 'time_signature': 4}]
# items
# ['contemporary country', 'country', 'country road', 'modern country rock']
# i = contemporary country
# i = country
# i = country road
# i = modern country rock
# ['dance pop', 'hip pop', 'pop', 'post-teen pop']
# [{'danceability': 0.63, 'energy': 0.53, 'key': 0, 'loudness': -7.259, 'mode': 1, 'speechiness': 0.0434, 'acousticness': 0.4, 'instrumentalness': 0, 'liveness': 0.177, 'valence': 0.417, 'tempo': 108.038, 'type': 'audio_features', 'id': '2YlZnw2ikdb837oKMKjBkW', 'uri': 'spotify:track:2YlZnw2ikdb837oKMKjBkW', 'track_href': 'https://api.spotify.com/v1/tracks/2YlZnw2ikdb837oKMKjBkW', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2YlZnw2ikdb837oKMKjBkW', 'duration_ms': 225053, 'time_signature': 3}]
# items
# ['dance pop', 'hip pop', 'pop', 'post-teen pop']
# i = dance pop
# i = hip pop
# i = pop
# in loop: pop
# i = post-teen pop
# ['canadian contemporary r&b', 'canadian pop', 'pop']
# [{'danceability': 0.531, 'energy': 0.75, 'key': 10, 'loudness': -5.831, 'mode': 0, 'speechiness': 0.111, 'acousticness': 0.00632, 'instrumentalness': 7.6e-05, 'liveness': 0.117, 'valence': 0.198, 'tempo': 169.954, 'type': 'audio_features', 'id': '57vxBYXtHMk6H1aD29V7PU', 'uri': 'spotify:track:57vxBYXtHMk6H1aD29V7PU', 'track_href': 'https://api.spotify.com/v1/tracks/57vxBYXtHMk6H1aD29V7PU', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/57vxBYXtHMk6H1aD29V7PU', 'duration_ms': 200080, 'time_signature': 4}]
# items
# ['canadian contemporary r&b', 'canadian pop', 'pop']
# i = canadian contemporary r&b
# i = canadian pop
# i = pop
# in loop: pop
# ['dance pop', 'folk-pop', 'neo mellow', 'pop', 'pop rock', 'post-teen pop', 'viral pop']
# [{'danceability': 0.697, 'energy': 0.474, 'key': 9, 'loudness': -6.663, 'mode': 1, 'speechiness': 0.0351, 'acousticness': 0.603, 'instrumentalness': 0, 'liveness': 0.11, 'valence': 0.249, 'tempo': 127.907, 'type': 'audio_features', 'id': '0rFOs9paloAvEtzwDX1Kmc', 'uri': 'spotify:track:0rFOs9paloAvEtzwDX1Kmc', 'track_href': 'https://api.spotify.com/v1/tracks/0rFOs9paloAvEtzwDX1Kmc', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0rFOs9paloAvEtzwDX1Kmc', 'duration_ms': 196280, 'time_signature': 4}]
# items
# ['dance pop', 'folk-pop', 'neo mellow', 'pop', 'pop rock', 'post-teen pop', 'viral pop']
# i = dance pop
# i = folk-pop
# i = neo mellow
# i = pop
# in loop: pop
# i = pop rock
# i = post-teen pop
# i = viral pop
# ['a cappella']
# [{'danceability': 0.364, 'energy': 0.378, 'key': 7, 'loudness': -7.381, 'mode': 0, 'speechiness': 0.0331, 'acousticness': 0.47, 'instrumentalness': 0, 'liveness': 0.339, 'valence': 0.366, 'tempo': 89.918, 'type': 'audio_features', 'id': '0HZk0QsXPhMNAWNDR3rYE8', 'uri': 'spotify:track:0HZk0QsXPhMNAWNDR3rYE8', 'track_href': 'https://api.spotify.com/v1/tracks/0HZk0QsXPhMNAWNDR3rYE8', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0HZk0QsXPhMNAWNDR3rYE8', 'duration_ms': 268960, 'time_signature': 3}]
# items
# ['a cappella']
# i = a cappella
# ['australian pop', 'dance pop', 'pop', 'pop rap', 'post-teen pop', 'uk pop', 'viral pop']
# [{'danceability': 0.706, 'energy': 0.786, 'key': 0, 'loudness': -3.417, 'mode': 0, 'speechiness': 0.0909, 'acousticness': 0.26, 'instrumentalness': 0, 'liveness': 0.38, 'valence': 0.749, 'tempo': 150.035, 'type': 'audio_features', 'id': '0puf9yIluy9W0vpMEUoAnN', 'uri': 'spotify:track:0puf9yIluy9W0vpMEUoAnN', 'track_href': 'https://api.spotify.com/v1/tracks/0puf9yIluy9W0vpMEUoAnN', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0puf9yIluy9W0vpMEUoAnN', 'duration_ms': 199387, 'time_signature': 4}]
# items
# ['australian pop', 'dance pop', 'pop', 'pop rap', 'post-teen pop', 'uk pop', 'viral pop']
# i = australian pop
# i = dance pop
# i = pop
# in loop: pop
# i = pop rap
# i = post-teen pop
# i = uk pop
# i = viral pop
# ['contemporary country', 'country', 'country road']
# [{'danceability': 0.68, 'energy': 0.741, 'key': 2, 'loudness': -5.055, 'mode': 1, 'speechiness': 0.0357, 'acousticness': 0.347, 'instrumentalness': 1.87e-06, 'liveness': 0.117, 'valence': 0.635, 'tempo': 127.024, 'type': 'audio_features', 'id': '2qYsSHsYkihWx043HVJQRV', 'uri': 'spotify:track:2qYsSHsYkihWx043HVJQRV', 'track_href': 'https://api.spotify.com/v1/tracks/2qYsSHsYkihWx043HVJQRV', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2qYsSHsYkihWx043HVJQRV', 'duration_ms': 229400, 'time_signature': 4}]
# items
# ['contemporary country', 'country', 'country road']
# i = contemporary country
# i = country
# i = country road
# ['contemporary country', 'country', 'country road', 'modern country rock']
# [{'danceability': 0.739, 'energy': 0.85, 'key': 2, 'loudness': -3.966, 'mode': 1, 'speechiness': 0.0308, 'acousticness': 0.0272, 'instrumentalness': 0, 'liveness': 0.181, 'valence': 0.883, 'tempo': 113.0, 'type': 'audio_features', 'id': '2KqJC0koTBUyDlsMt5ok1V', 'uri': 'spotify:track:2KqJC0koTBUyDlsMt5ok1V', 'track_href': 'https://api.spotify.com/v1/tracks/2KqJC0koTBUyDlsMt5ok1V', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2KqJC0koTBUyDlsMt5ok1V', 'duration_ms': 168960, 'time_signature': 4}]
# items
# ['contemporary country', 'country', 'country road', 'modern country rock']
# i = contemporary country
# i = country
# i = country road
# i = modern country rock
# ['contemporary country', 'country', 'country road', 'modern country rock']
# [{'danceability': 0.575, 'energy': 0.845, 'key': 10, 'loudness': -3.838, 'mode': 1, 'speechiness': 0.035, 'acousticness': 0.0282, 'instrumentalness': 0, 'liveness': 0.0814, 'valence': 0.376, 'tempo': 127.997, 'type': 'audio_features', 'id': '0H04yVa3DJxoXbLBpAb7iV', 'uri': 'spotify:track:0H04yVa3DJxoXbLBpAb7iV', 'track_href': 'https://api.spotify.com/v1/tracks/0H04yVa3DJxoXbLBpAb7iV', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0H04yVa3DJxoXbLBpAb7iV', 'duration_ms': 197280, 'time_signature': 4}]
# items
# ['contemporary country', 'country', 'country road', 'modern country rock']
# i = contemporary country
# i = country
# i = country road
# i = modern country rock
# ['contemporary country', 'country', 'country road']
# [{'danceability': 0.669, 'energy': 0.559, 'key': 5, 'loudness': -5.003, 'mode': 1, 'speechiness': 0.0251, 'acousticness': 0.0805, 'instrumentalness': 0, 'liveness': 0.0703, 'valence': 0.491, 'tempo': 95.001, 'type': 'audio_features', 'id': '40ufL61vEaDaaOitYhnlQ7', 'uri': 'spotify:track:40ufL61vEaDaaOitYhnlQ7', 'track_href': 'https://api.spotify.com/v1/tracks/40ufL61vEaDaaOitYhnlQ7', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/40ufL61vEaDaaOitYhnlQ7', 'duration_ms': 199413, 'time_signature': 4}]
# items
# ['contemporary country', 'country', 'country road']
# i = contemporary country
# i = country
# i = country road
# ['australian country', 'contemporary country', 'country', 'country road']
# [{'danceability': 0.44, 'energy': 0.803, 'key': 5, 'loudness': -6.162, 'mode': 1, 'speechiness': 0.0512, 'acousticness': 0.127, 'instrumentalness': 0, 'liveness': 0.128, 'valence': 0.633, 'tempo': 79.312, 'type': 'audio_features', 'id': '6JOeNbZ3X6dtXusG3hkHn8', 'uri': 'spotify:track:6JOeNbZ3X6dtXusG3hkHn8', 'track_href': 'https://api.spotify.com/v1/tracks/6JOeNbZ3X6dtXusG3hkHn8', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6JOeNbZ3X6dtXusG3hkHn8', 'duration_ms': 189104, 'time_signature': 4}]
# items
# ['australian country', 'contemporary country', 'country', 'country road']
# i = australian country
# i = contemporary country
# i = country
# i = country road
# ['contemporary country', 'country', 'country road', 'modern country rock']
# [{'danceability': 0.423, 'energy': 0.813, 'key': 9, 'loudness': -5.011, 'mode': 1, 'speechiness': 0.0507, 'acousticness': 0.218, 'instrumentalness': 1.62e-06, 'liveness': 0.0732, 'valence': 0.421, 'tempo': 173.995, 'type': 'audio_features', 'id': '43CFDpciGFDm226POTLEXU', 'uri': 'spotify:track:43CFDpciGFDm226POTLEXU', 'track_href': 'https://api.spotify.com/v1/tracks/43CFDpciGFDm226POTLEXU', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/43CFDpciGFDm226POTLEXU', 'duration_ms': 211720, 'time_signature': 4}]
# items
# ['contemporary country', 'country', 'country road', 'modern country rock']
# i = contemporary country
# i = country
# i = country road
# i = modern country rock
# ['pop', 'post-teen pop']
# [{'danceability': 0.359, 'energy': 0.543, 'key': 7, 'loudness': -7.582, 'mode': 1, 'speechiness': 0.0919, 'acousticness': 0.492, 'instrumentalness': 1.58e-05, 'liveness': 0.118, 'valence': 0.453, 'tempo': 68.534, 'type': 'audio_features', 'id': '1dGr1c8CrMLDpV6mPbImSI', 'uri': 'spotify:track:1dGr1c8CrMLDpV6mPbImSI', 'track_href': 'https://api.spotify.com/v1/tracks/1dGr1c8CrMLDpV6mPbImSI', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1dGr1c8CrMLDpV6mPbImSI', 'duration_ms': 221307, 'time_signature': 4}]
# items
# ['pop', 'post-teen pop']
# i = pop
# in loop: pop
# i = post-teen pop
# ['contemporary country', 'country', 'country pop', 'country road', 'modern country rock', 'modern uplift']
# [{'danceability': 0.598, 'energy': 0.861, 'key': 10, 'loudness': -3.215, 'mode': 1, 'speechiness': 0.0424, 'acousticness': 0.0453, 'instrumentalness': 0, 'liveness': 0.257, 'valence': 0.325, 'tempo': 128.025, 'type': 'audio_features', 'id': '7MPc82UJLQm5VasRVkwquM', 'uri': 'spotify:track:7MPc82UJLQm5VasRVkwquM', 'track_href': 'https://api.spotify.com/v1/tracks/7MPc82UJLQm5VasRVkwquM', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7MPc82UJLQm5VasRVkwquM', 'duration_ms': 201027, 'time_signature': 4}]
# items
# ['contemporary country', 'country', 'country pop', 'country road', 'modern country rock', 'modern uplift']
# i = contemporary country
# i = country
# i = country pop
# i = country road
# i = modern country rock
# i = modern uplift
# ['contemporary country', 'country', 'country road', 'modern country rock']
# [{'danceability': 0.537, 'energy': 0.66, 'key': 9, 'loudness': -7.174, 'mode': 1, 'speechiness': 0.0296, 'acousticness': 0.455, 'instrumentalness': 0, 'liveness': 0.135, 'valence': 0.574, 'tempo': 148.096, 'type': 'audio_features', 'id': '3xdjjKMcMOFgo1eQrfbogM', 'uri': 'spotify:track:3xdjjKMcMOFgo1eQrfbogM', 'track_href': 'https://api.spotify.com/v1/tracks/3xdjjKMcMOFgo1eQrfbogM', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3xdjjKMcMOFgo1eQrfbogM', 'duration_ms': 298373, 'time_signature': 4}]
# items
# ['contemporary country', 'country', 'country road', 'modern country rock']
# i = contemporary country
# i = country
# i = country road
# i = modern country rock
# ['dance pop', 'deep pop r&b', 'pop', 'pop rap', 'r&b', 'southern hip hop', 'trap', 'urban contemporary']
# [{'danceability': 0.492, 'energy': 0.698, 'key': 1, 'loudness': -5.606, 'mode': 1, 'speechiness': 0.171, 'acousticness': 0.0524, 'instrumentalness': 0, 'liveness': 0.428, 'valence': 0.288, 'tempo': 139.953, 'type': 'audio_features', 'id': '6HMHgBHdLBQ0QYIaOp2gse', 'uri': 'spotify:track:6HMHgBHdLBQ0QYIaOp2gse', 'track_href': 'https://api.spotify.com/v1/tracks/6HMHgBHdLBQ0QYIaOp2gse', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6HMHgBHdLBQ0QYIaOp2gse', 'duration_ms': 209707, 'time_signature': 4}]
# items
# ['dance pop', 'deep pop r&b', 'pop', 'pop rap', 'r&b', 'southern hip hop', 'trap', 'urban contemporary']
# i = dance pop
# i = deep pop r&b
# i = pop
# in loop: pop
# i = pop rap
# i = r&b
# i = southern hip hop
# i = trap
# i = urban contemporary
# ['folk-pop', 'indie pop', 'indie poptimism', 'modern rock', 'pop', 'pop rock']
# [{'danceability': 0.578, 'energy': 0.866, 'key': 1, 'loudness': -3.804, 'mode': 1, 'speechiness': 0.0619, 'acousticness': 0.00701, 'instrumentalness': 0, 'liveness': 0.257, 'valence': 0.619, 'tempo': 128.038, 'type': 'audio_features', 'id': '0kzw2tRyuL9rzipi5ntlIy', 'uri': 'spotify:track:0kzw2tRyuL9rzipi5ntlIy', 'track_href': 'https://api.spotify.com/v1/tracks/0kzw2tRyuL9rzipi5ntlIy', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0kzw2tRyuL9rzipi5ntlIy', 'duration_ms': 199080, 'time_signature': 4}]
# items
# ['folk-pop', 'indie pop', 'indie poptimism', 'modern rock', 'pop', 'pop rock']
# i = folk-pop
# i = indie pop
# i = indie poptimism
# i = modern rock
# i = pop
# in loop: pop
# i = pop rock
# ['art pop', 'dance pop', 'electropop', 'metropopolis', 'nz pop', 'pop']
# [{'danceability': 0.674, 'energy': 0.428, 'key': 7, 'loudness': -9.504, 'mode': 1, 'speechiness': 0.122, 'acousticness': 0.121, 'instrumentalness': 0, 'liveness': 0.132, 'valence': 0.337, 'tempo': 84.878, 'type': 'audio_features', 'id': '2dLLR6qlu5UJ5gk0dKz0h3', 'uri': 'spotify:track:2dLLR6qlu5UJ5gk0dKz0h3', 'track_href': 'https://api.spotify.com/v1/tracks/2dLLR6qlu5UJ5gk0dKz0h3', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2dLLR6qlu5UJ5gk0dKz0h3', 'duration_ms': 190185, 'time_signature': 4}]
# items
# ['art pop', 'dance pop', 'electropop', 'metropopolis', 'nz pop', 'pop']
# i = art pop
# i = dance pop
# i = electropop
# i = metropopolis
# i = nz pop
# i = pop
# in loop: pop
# ['candy pop', 'dance pop', 'electropop', 'metropopolis', 'pop', 'pop rap', 'post-teen pop', 'tropical house']
# [{'danceability': 0.716, 'energy': 0.757, 'key': 5, 'loudness': -2.666, 'mode': 1, 'speechiness': 0.0487, 'acousticness': 0.0249, 'instrumentalness': 0, 'liveness': 0.286, 'valence': 0.558, 'tempo': 100.007, 'type': 'audio_features', 'id': '1MfuskV4ODUp14C2dnyPgW', 'uri': 'spotify:track:1MfuskV4ODUp14C2dnyPgW', 'track_href': 'https://api.spotify.com/v1/tracks/1MfuskV4ODUp14C2dnyPgW', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1MfuskV4ODUp14C2dnyPgW', 'duration_ms': 191114, 'time_signature': 4}]
# items
# ['candy pop', 'dance pop', 'electropop', 'metropopolis', 'pop', 'pop rap', 'post-teen pop', 'tropical house']
# i = candy pop
# i = dance pop
# i = electropop
# i = metropopolis
# i = pop
# in loop: pop
# i = pop rap
# i = post-teen pop
# i = tropical house
# ['canadian pop', 'pop', 'post-teen pop', 'viral pop']
# [{'danceability': 0.448, 'energy': 0.603, 'key': 7, 'loudness': -7.176, 'mode': 1, 'speechiness': 0.064, 'acousticness': 0.433, 'instrumentalness': 0, 'liveness': 0.0862, 'valence': 0.422, 'tempo': 205.272, 'type': 'audio_features', 'id': '3i9UVldZOE0aD0JnyfAZZ0', 'uri': 'spotify:track:3i9UVldZOE0aD0JnyfAZZ0', 'track_href': 'https://api.spotify.com/v1/tracks/3i9UVldZOE0aD0JnyfAZZ0', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3i9UVldZOE0aD0JnyfAZZ0', 'duration_ms': 221307, 'time_signature': 3}]
# items
# ['canadian pop', 'pop', 'post-teen pop', 'viral pop']
# i = canadian pop
# i = pop
# in loop: pop
# i = post-teen pop
# i = viral pop
# ['conscious hip hop', 'hip hop', 'nc hip hop', 'pop rap', 'rap']
# [{'danceability': 0.796, 'energy': 0.586, 'key': 4, 'loudness': -6.946, 'mode': 0, 'speechiness': 0.147, 'acousticness': 0.0247, 'instrumentalness': 0, 'liveness': 0.132, 'valence': 0.179, 'tempo': 97.981, 'type': 'audio_features', 'id': '7DcvwMAiqKJQD1rrdfxSDx', 'uri': 'spotify:track:7DcvwMAiqKJQD1rrdfxSDx', 'track_href': 'https://api.spotify.com/v1/tracks/7DcvwMAiqKJQD1rrdfxSDx', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7DcvwMAiqKJQD1rrdfxSDx', 'duration_ms': 200107, 'time_signature': 4}]
# items
# ['conscious hip hop', 'hip hop', 'nc hip hop', 'pop rap', 'rap']
# i = conscious hip hop
# i = hip hop
# i = nc hip hop
# i = pop rap
# i = rap
# ['contemporary country', 'country', 'country road', 'modern country rock', 'redneck']
# [{'danceability': 0.678, 'energy': 0.839, 'key': 7, 'loudness': -3.617, 'mode': 1, 'speechiness': 0.0394, 'acousticness': 0.0379, 'instrumentalness': 0, 'liveness': 0.0742, 'valence': 0.772, 'tempo': 104.952, 'type': 'audio_features', 'id': '6aUhfNWYnMThF3TGtuYUUu', 'uri': 'spotify:track:6aUhfNWYnMThF3TGtuYUUu', 'track_href': 'https://api.spotify.com/v1/tracks/6aUhfNWYnMThF3TGtuYUUu', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6aUhfNWYnMThF3TGtuYUUu', 'duration_ms': 185907, 'time_signature': 4}]
# items
# ['contemporary country', 'country', 'country road', 'modern country rock', 'redneck']
# i = contemporary country
# i = country
# i = country road
# i = modern country rock
# i = redneck
# ['contemporary country', 'country', 'country road', 'oklahoma country']
# [{'danceability': 0.538, 'energy': 0.752, 'key': 10, 'loudness': -5.106, 'mode': 1, 'speechiness': 0.0396, 'acousticness': 0.0608, 'instrumentalness': 5.39e-06, 'liveness': 0.118, 'valence': 0.217, 'tempo': 139.984, 'type': 'audio_features', 'id': '1dyxS3YzBbL0t8rEVwVQ1K', 'uri': 'spotify:track:1dyxS3YzBbL0t8rEVwVQ1K', 'track_href': 'https://api.spotify.com/v1/tracks/1dyxS3YzBbL0t8rEVwVQ1K', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1dyxS3YzBbL0t8rEVwVQ1K', 'duration_ms': 205107, 'time_signature': 4}]
# items
# ['contemporary country', 'country', 'country road', 'oklahoma country']
# i = contemporary country
# i = country
# i = country road
# i = oklahoma country
# ['latin', 'latin viral pop', 'rap latina', 'reggaeton']
# [{'danceability': 0.826, 'energy': 0.817, 'key': 2, 'loudness': -4.081, 'mode': 1, 'speechiness': 0.0921, 'acousticness': 0.00502, 'instrumentalness': 1.09e-05, 'liveness': 0.294, 'valence': 0.168, 'tempo': 97.053, 'type': 'audio_features', 'id': '6wyr4ReB05D9sJB1Rsmcqo', 'uri': 'spotify:track:6wyr4ReB05D9sJB1Rsmcqo', 'track_href': 'https://api.spotify.com/v1/tracks/6wyr4ReB05D9sJB1Rsmcqo', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6wyr4ReB05D9sJB1Rsmcqo', 'duration_ms': 235497, 'time_signature': 4}]
# items
# ['latin', 'latin viral pop', 'rap latina', 'reggaeton']
# i = latin
# i = latin viral pop
# i = rap latina
# i = reggaeton
# ['dance pop', 'hip pop', 'pop', 'post-teen pop']
# [{'danceability': 0.63, 'energy': 0.53, 'key': 0, 'loudness': -7.259, 'mode': 1, 'speechiness': 0.0434, 'acousticness': 0.4, 'instrumentalness': 0, 'liveness': 0.177, 'valence': 0.417, 'tempo': 108.038, 'type': 'audio_features', 'id': '2YlZnw2ikdb837oKMKjBkW', 'uri': 'spotify:track:2YlZnw2ikdb837oKMKjBkW', 'track_href': 'https://api.spotify.com/v1/tracks/2YlZnw2ikdb837oKMKjBkW', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2YlZnw2ikdb837oKMKjBkW', 'duration_ms': 225053, 'time_signature': 3}]
# items
# ['dance pop', 'hip pop', 'pop', 'post-teen pop']
# i = dance pop
# i = hip pop
# i = pop
# in loop: pop
# i = post-teen pop
# ['pop', 'post-teen pop']
# [{'danceability': 0.359, 'energy': 0.543, 'key': 7, 'loudness': -7.582, 'mode': 1, 'speechiness': 0.0919, 'acousticness': 0.492, 'instrumentalness': 1.58e-05, 'liveness': 0.118, 'valence': 0.453, 'tempo': 68.534, 'type': 'audio_features', 'id': '1dGr1c8CrMLDpV6mPbImSI', 'uri': 'spotify:track:1dGr1c8CrMLDpV6mPbImSI', 'track_href': 'https://api.spotify.com/v1/tracks/1dGr1c8CrMLDpV6mPbImSI', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1dGr1c8CrMLDpV6mPbImSI', 'duration_ms': 221307, 'time_signature': 4}]
# items
# ['pop', 'post-teen pop']
# i = pop
# ...
# items
# ['pop', 'post-teen pop']
# i = pop
# in loop: pop
# i = post-teen pop
# ['folk-pop', 'modern rock', 'pop', 'pop rock']
# [{'danceability': 0.484, 'energy': 0.731, 'key': 1, 'loudness': -6.694, 'mode': 1, 'speechiness': 0.0379, 'acousticness': 0.431, 'instrumentalness': 0, 'liveness': 0.151, 'valence': 0.51, 'tempo': 101.654, 'type': 'audio_features', 'id': '3JvrhDOgAt6p7K8mDyZwRd', 'uri': 'spotify:track:3JvrhDOgAt6p7K8mDyZwRd', 'track_href': 'https://api.spotify.com/v1/tracks/3JvrhDOgAt6p7K8mDyZwRd', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3JvrhDOgAt6p7K8mDyZwRd', 'duration_ms': 204280, 'time_signature': 4}]
# items
# ['folk-pop', 'modern rock', 'pop', 'pop rock']
# i = folk-pop
# i = modern rock
# i = pop
# in loop: pop
# i = pop rock
# ['dance pop', 'electropop', 'metropopolis', 'pop', 'post-teen pop', 'swedish electropop', 'swedish pop', 'swedish synthpop', 'tropical house']
# [{'danceability': 0.598, 'energy': 0.532, 'key': 3, 'loudness': -6.833, 'mode': 0, 'speechiness': 0.0295, 'acousticness': 0.0668, 'instrumentalness': 3.22e-06, 'liveness': 0.0617, 'valence': 0.261, 'tempo': 74.963, 'type': 'audio_features', 'id': '5aOpzm8W8zysk4asB9hxJw', 'uri': 'spotify:track:5aOpzm8W8zysk4asB9hxJw', 'track_href': 'https://api.spotify.com/v1/tracks/5aOpzm8W8zysk4asB9hxJw', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5aOpzm8W8zysk4asB9hxJw', 'duration_ms': 262521, 'time_signature': 4}]
# items
# ['dance pop', 'electropop', 'metropopolis', 'pop', 'post-teen pop', 'swedish electropop', 'swedish pop', 'swedish synthpop', 'tropical house']
# i = dance pop
# i = electropop
# i = metropopolis
# i = pop
# in loop: pop
# i = post-teen pop
# i = swedish electropop
# i = swedish pop
# i = swedish synthpop
# i = tropical house
# ['australian dance', 'australian pop', 'dance pop', 'pop']
# [{'danceability': 0.604, 'energy': 0.787, 'key': 0, 'loudness': -3.674, 'mode': 0, 'speechiness': 0.103, 'acousticness': 0.0679, 'instrumentalness': 0.15, 'liveness': 0.127, 'valence': 0.301, 'tempo': 126.062, 'type': 'audio_features', 'id': '77TT8Xvx637TpzV8kKGkUw', 'uri': 'spotify:track:77TT8Xvx637TpzV8kKGkUw', 'track_href': 'https://api.spotify.com/v1/tracks/77TT8Xvx637TpzV8kKGkUw', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/77TT8Xvx637TpzV8kKGkUw', 'duration_ms': 245040, 'time_signature': 4}]
# items
# ['australian dance', 'australian pop', 'dance pop', 'pop']
# i = australian dance
# i = australian pop
# i = dance pop
# i = pop
# in loop: pop
# ['australian dance', 'australian pop', 'dance pop', 'pop']
# [{'danceability': 0.604, 'energy': 0.787, 'key': 0, 'loudness': -3.674, 'mode': 0, 'speechiness': 0.103, 'acousticness': 0.0679, 'instrumentalness': 0.15, 'liveness': 0.127, 'valence': 0.301, 'tempo': 126.062, 'type': 'audio_features', 'id': '77TT8Xvx637TpzV8kKGkUw', 'uri': 'spotify:track:77TT8Xvx637TpzV8kKGkUw', 'track_href': 'https://api.spotify.com/v1/tracks/77TT8Xvx637TpzV8kKGkUw', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/77TT8Xvx637TpzV8kKGkUw', 'duration_ms': 245040, 'time_signature': 4}]
# items
# ['australian dance', 'australian pop', 'dance pop', 'pop']
# i = australian dance
# i = australian pop
# i = dance pop
# i = pop
# in loop: pop
# ['canadian contemporary r&b', 'canadian pop', 'pop']
# [{'danceability': 0.531, 'energy': 0.75, 'key': 10, 'loudness': -5.831, 'mode': 0, 'speechiness': 0.111, 'acousticness': 0.00632, 'instrumentalness': 7.6e-05, 'liveness': 0.117, 'valence': 0.198, 'tempo': 169.954, 'type': 'audio_features', 'id': '57vxBYXtHMk6H1aD29V7PU', 'uri': 'spotify:track:57vxBYXtHMk6H1aD29V7PU', 'track_href': 'https://api.spotify.com/v1/tracks/57vxBYXtHMk6H1aD29V7PU', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/57vxBYXtHMk6H1aD29V7PU', 'duration_ms': 200080, 'time_signature': 4}]
# items
# ['canadian contemporary r&b', 'canadian pop', 'pop']
# i = canadian contemporary r&b
# i = canadian pop
# i = pop
# in loop: pop
# ['tropical house']
# [{'danceability': 0.547, 'energy': 0.795, 'key': 8, 'loudness': -3.721, 'mode': 1, 'speechiness': 0.0489, 'acousticness': 0.145, 'instrumentalness': 0, 'liveness': 0.11, 'valence': 0.723, 'tempo': 118.118, 'type': 'audio_features', 'id': '35MKhw2YBKApmD7fAnPERC', 'uri': 'spotify:track:35MKhw2YBKApmD7fAnPERC', 'track_href': 'https://api.spotify.com/v1/tracks/35MKhw2YBKApmD7fAnPERC', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/35MKhw2YBKApmD7fAnPERC', 'duration_ms': 186805, 'time_signature': 4}]
# items
# ['tropical house']
# i = tropical house
# ['pop', 'uk pop']
# [{'danceability': 0.64, 'energy': 0.648, 'key': 5, 'loudness': -8.113, 'mode': 0, 'speechiness': 0.187, 'acousticness': 0.124, 'instrumentalness': 0, 'liveness': 0.0802, 'valence': 0.548, 'tempo': 92.977, 'type': 'audio_features', 'id': '4evmHXcjt3bTUHD1cvny97', 'uri': 'spotify:track:4evmHXcjt3bTUHD1cvny97', 'track_href': 'https://api.spotify.com/v1/tracks/4evmHXcjt3bTUHD1cvny97', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4evmHXcjt3bTUHD1cvny97', 'duration_ms': 197867, 'time_signature': 4}]
# items
# ['pop', 'uk pop']
# i = pop
# in loop: pop
# i = uk pop
# ['contemporary country', 'country', 'country road']
# [{'danceability': 0.739, 'energy': 0.682, 'key': 2, 'loudness': -3.728, 'mode': 1, 'speechiness': 0.205, 'acousticness': 0.129, 'instrumentalness': 0, 'liveness': 0.328, 'valence': 0.634, 'tempo': 131.983, 'type': 'audio_features', 'id': '6ERR6e7h6wCqGoz1TjiUJb', 'uri': 'spotify:track:6ERR6e7h6wCqGoz1TjiUJb', 'track_href': 'https://api.spotify.com/v1/tracks/6ERR6e7h6wCqGoz1TjiUJb', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6ERR6e7h6wCqGoz1TjiUJb', 'duration_ms': 199382, 'time_signature': 4}]
# items
# ['contemporary country', 'country', 'country road']
# i = contemporary country
# i = country
# i = country road
# ['pop', 'reggae fusion']
# [{'danceability': 0.647, 'energy': 0.706, 'key': 6, 'loudness': -6.023, 'mode': 0, 'speechiness': 0.137, 'acousticness': 0.264, 'instrumentalness': 0, 'liveness': 0.114, 'valence': 0.577, 'tempo': 153.973, 'type': 'audio_features', 'id': '5NqOsPI4rA9Bl6LcCftzI2', 'uri': 'spotify:track:5NqOsPI4rA9Bl6LcCftzI2', 'track_href': 'https://api.spotify.com/v1/tracks/5NqOsPI4rA9Bl6LcCftzI2', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5NqOsPI4rA9Bl6LcCftzI2', 'duration_ms': 182338, 'time_signature': 4}]
# items
# ['pop', 'reggae fusion']
# i = pop
# in loop: pop
# i = reggae fusion
# ['dance pop', 'neo mellow', 'piano rock', 'pop', 'pop rock']
# [{'danceability': 0.759, 'energy': 0.605, 'key': 7, 'loudness': -7.737, 'mode': 1, 'speechiness': 0.0433, 'acousticness': 0.156, 'instrumentalness': 0, 'liveness': 0.694, 'valence': 0.64, 'tempo': 121.049, 'type': 'audio_features', 'id': '0mjAU3yKR1QnXnHtjGJqTM', 'uri': 'spotify:track:0mjAU3yKR1QnXnHtjGJqTM', 'track_href': 'https://api.spotify.com/v1/tracks/0mjAU3yKR1QnXnHtjGJqTM', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0mjAU3yKR1QnXnHtjGJqTM', 'duration_ms': 158900, 'time_signature': 4}]
# items
# ['dance pop', 'neo mellow', 'piano rock', 'pop', 'pop rock']
# i = dance pop
# i = neo mellow
# i = piano rock
# i = pop
# in loop: pop
# i = pop rock
# ['contemporary country', 'country', 'country road', 'modern country rock']
# [{'danceability': 0.616, 'energy': 0.849, 'key': 0, 'loudness': -4.897, 'mode': 1, 'speechiness': 0.0373, 'acousticness': 0.308, 'instrumentalness': 0, 'liveness': 0.311, 'valence': 0.639, 'tempo': 113.066, 'type': 'audio_features', 'id': '17TSJlshgQ5zu0e8dedAla', 'uri': 'spotify:track:17TSJlshgQ5zu0e8dedAla', 'track_href': 'https://api.spotify.com/v1/tracks/17TSJlshgQ5zu0e8dedAla', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/17TSJlshgQ5zu0e8dedAla', 'duration_ms': 223320, 'time_signature': 4}]
# items
# ['contemporary country', 'country', 'country road', 'modern country rock']
# i = contemporary country
# i = country
# i = country road
# i = modern country rock
# ['contemporary country', 'country', 'country pop', 'country road', 'modern country rock']
# [{'danceability': 0.643, 'energy': 0.783, 'key': 10, 'loudness': -6.458, 'mode': 1, 'speechiness': 0.0856, 'acousticness': 0.047, 'instrumentalness': 0, 'liveness': 0.083, 'valence': 0.579, 'tempo': 154.084, 'type': 'audio_features', 'id': '7iDa6hUg2VgEL1o1HjmfBn', 'uri': 'spotify:track:7iDa6hUg2VgEL1o1HjmfBn', 'track_href': 'https://api.spotify.com/v1/tracks/7iDa6hUg2VgEL1o1HjmfBn', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7iDa6hUg2VgEL1o1HjmfBn', 'duration_ms': 163870, 'time_signature': 4}]
# items
# ['contemporary country', 'country', 'country pop', 'country road', 'modern country rock']
# i = contemporary country
# i = country
# i = country pop
# i = country road
# i = modern country rock
# ['contemporary country', 'country pop']
# [{'danceability': 0.732, 'energy': 0.458, 'key': 5, 'loudness': -7.225, 'mode': 1, 'speechiness': 0.0311, 'acousticness': 0.447, 'instrumentalness': 0, 'liveness': 0.136, 'valence': 0.661, 'tempo': 98.938, 'type': 'audio_features', 'id': '7mldq42yDuxiUNn08nvzHO', 'uri': 'spotify:track:7mldq42yDuxiUNn08nvzHO', 'track_href': 'https://api.spotify.com/v1/tracks/7mldq42yDuxiUNn08nvzHO', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7mldq42yDuxiUNn08nvzHO', 'duration_ms': 165387, 'time_signature': 4}]
# items
# ['contemporary country', 'country pop']
# i = contemporary country
# i = country pop
# ['boy band', 'dance pop', 'pop', 'post-teen pop', 'talent show']
# [{'danceability': 0.6, 'energy': 0.663, 'key': 3, 'loudness': -5.802, 'mode': 1, 'speechiness': 0.0477, 'acousticness': 0.225, 'instrumentalness': 0, 'liveness': 0.119, 'valence': 0.286, 'tempo': 121.07, 'type': 'audio_features', 'id': '4nVBt6MZDDP6tRVdQTgxJg', 'uri': 'spotify:track:4nVBt6MZDDP6tRVdQTgxJg', 'track_href': 'https://api.spotify.com/v1/tracks/4nVBt6MZDDP6tRVdQTgxJg', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4nVBt6MZDDP6tRVdQTgxJg', 'duration_ms': 245493, 'time_signature': 4}]
# items
# ['boy band', 'dance pop', 'pop', 'post-teen pop', 'talent show']
# i = boy band
# i = dance pop
# i = pop
# in loop: pop
# i = post-teen pop
# i = talent show
# ['contemporary country', 'country', 'country road', 'modern country rock']
# [{'danceability': 0.739, 'energy': 0.85, 'key': 2, 'loudness': -3.966, 'mode': 1, 'speechiness': 0.0308, 'acousticness': 0.0272, 'instrumentalness': 0, 'liveness': 0.181, 'valence': 0.883, 'tempo': 113.0, 'type': 'audio_features', 'id': '2KqJC0koTBUyDlsMt5ok1V', 'uri': 'spotify:track:2KqJC0koTBUyDlsMt5ok1V', 'track_href': 'https://api.spotify.com/v1/tracks/2KqJC0koTBUyDlsMt5ok1V', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2KqJC0koTBUyDlsMt5ok1V', 'duration_ms': 168960, 'time_signature': 4}]
# items
# ['contemporary country', 'country', 'country road', 'modern country rock']
# i = contemporary country
# i = country
# i = country road
# i = modern country rock
# ['contemporary country', 'country', 'country road', 'modern country rock']
# [{'danceability': 0.355, 'energy': 0.478, 'key': 0, 'loudness': -8.323, 'mode': 1, 'speechiness': 0.0335, 'acousticness': 0.569, 'instrumentalness': 2.9e-06, 'liveness': 0.194, 'valence': 0.269, 'tempo': 102.971, 'type': 'audio_features', 'id': '3dAgQFdruU8ufWc5GE05xC', 'uri': 'spotify:track:3dAgQFdruU8ufWc5GE05xC', 'track_href': 'https://api.spotify.com/v1/tracks/3dAgQFdruU8ufWc5GE05xC', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3dAgQFdruU8ufWc5GE05xC', 'duration_ms': 266920, 'time_signature': 4}]
# items
# ['contemporary country', 'country', 'country road', 'modern country rock']
# i = contemporary country
# i = country
# i = country road
# i = modern country rock
# ['dance pop', 'pop']
# [{'danceability': 0.572, 'energy': 0.385, 'key': 7, 'loudness': -6.362, 'mode': 1, 'speechiness': 0.0308, 'acousticness': 0.371, 'instrumentalness': 0, 'liveness': 0.231, 'valence': 0.323, 'tempo': 95.799, 'type': 'audio_features', 'id': '2VxeLyX666F8uXCJ0dZF8B', 'uri': 'spotify:track:2VxeLyX666F8uXCJ0dZF8B', 'track_href': 'https://api.spotify.com/v1/tracks/2VxeLyX666F8uXCJ0dZF8B', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2VxeLyX666F8uXCJ0dZF8B', 'duration_ms': 215733, 'time_signature': 4}]
# items
# ['dance pop', 'pop']
# i = dance pop
# i = pop
# in loop: pop
# ['conscious hip hop', 'hip hop', 'nc hip hop', 'pop rap', 'rap']
# [{'danceability': 0.796, 'energy': 0.586, 'key': 4, 'loudness': -6.946, 'mode': 0, 'speechiness': 0.147, 'acousticness': 0.0247, 'instrumentalness': 0, 'liveness': 0.132, 'valence': 0.179, 'tempo': 97.981, 'type': 'audio_features', 'id': '7DcvwMAiqKJQD1rrdfxSDx', 'uri': 'spotify:track:7DcvwMAiqKJQD1rrdfxSDx', 'track_href': 'https://api.spotify.com/v1/tracks/7DcvwMAiqKJQD1rrdfxSDx', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7DcvwMAiqKJQD1rrdfxSDx', 'duration_ms': 200107, 'time_signature': 4}]
# items
# ['conscious hip hop', 'hip hop', 'nc hip hop', 'pop rap', 'rap']
# i = conscious hip hop
# i = hip hop
# i = nc hip hop
# i = pop rap
# i = rap
# ['hawaiian hip hop', 'pop', 'pop rap', 'rap']
# [{'danceability': 0.568, 'energy': 0.764, 'key': 5, 'loudness': -3.465, 'mode': 0, 'speechiness': 0.255, 'acousticness': 0.217, 'instrumentalness': 0, 'liveness': 0.0931, 'valence': 0.625, 'tempo': 179.985, 'type': 'audio_features', 'id': '2Xo3rLHjXfdb4avN68aQyi', 'uri': 'spotify:track:2Xo3rLHjXfdb4avN68aQyi', 'track_href': 'https://api.spotify.com/v1/tracks/2Xo3rLHjXfdb4avN68aQyi', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Xo3rLHjXfdb4avN68aQyi', 'duration_ms': 160720, 'time_signature': 4}]
# items
# ['hawaiian hip hop', 'pop', 'pop rap', 'rap']
# i = hawaiian hip hop
# i = pop
# in loop: pop
# i = pop rap
# i = rap
# ['contemporary country', 'country', 'country road', 'modern country rock', 'redneck', 'texas country']
# [{'danceability': 0.488, 'energy': 0.833, 'key': 11, 'loudness': -6.571, 'mode': 1, 'speechiness': 0.0437, 'acousticness': 0.0352, 'instrumentalness': 0.0172, 'liveness': 0.34, 'valence': 0.751, 'tempo': 174.006, 'type': 'audio_features', 'id': '6naYpFIKihKbGg6lGxpveI', 'uri': 'spotify:track:6naYpFIKihKbGg6lGxpveI', 'track_href': 'https://api.spotify.com/v1/tracks/6naYpFIKihKbGg6lGxpveI', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6naYpFIKihKbGg6lGxpveI', 'duration_ms': 236787, 'time_signature': 4}]
# items
# ['contemporary country', 'country', 'country road', 'modern country rock', 'redneck', 'texas country']
# i = contemporary country
# i = country
# i = country road
# i = modern country rock
# i = redneck
# i = texas country
# ['pop', 'uk pop']
# [{'danceability': 0.64, 'energy': 0.648, 'key': 5, 'loudness': -8.113, 'mode': 0, 'speechiness': 0.187, 'acousticness': 0.124, 'instrumentalness': 0, 'liveness': 0.0802, 'valence': 0.548, 'tempo': 92.977, 'type': 'audio_features', 'id': '4evmHXcjt3bTUHD1cvny97', 'uri': 'spotify:track:4evmHXcjt3bTUHD1cvny97', 'track_href': 'https://api.spotify.com/v1/tracks/4evmHXcjt3bTUHD1cvny97', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4evmHXcjt3bTUHD1cvny97', 'duration_ms': 197867, 'time_signature': 4}]
# items
# ['pop', 'uk pop']
# i = pop
# in loop: pop
# i = uk pop
# ['electropop', 'pop', 'tropical house']
# [{'danceability': 0.575, 'energy': 0.571, 'key': 1, 'loudness': -7.906, 'mode': 1, 'speechiness': 0.0439, 'acousticness': 0.0558, 'instrumentalness': 0, 'liveness': 0.0912, 'valence': 0.449, 'tempo': 105.049, 'type': 'audio_features', 'id': '4NBTZtAt1F13VvlSKe6KTl', 'uri': 'spotify:track:4NBTZtAt1F13VvlSKe6KTl', 'track_href': 'https://api.spotify.com/v1/tracks/4NBTZtAt1F13VvlSKe6KTl', 'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4NBTZtAt1F13VvlSKe6KTl', 'duration_ms': 197947, 'time_signature': 4}]
# items
# ['electropop', 'pop', 'tropical house']
# i = electropop
# i = pop
# in loop: pop
# i = tropical house
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-238-b9a40ccdd450> in <module>
#       8     song_uri = query['tracks']['items'][0]['uri']
#       9
# ---> 10     print(results['artists']['items'][0]['genres'])
#      11     print(sp.audio_features(song_uri))
#      12     print
#
# IndexError: list index out of range

# %%
index = 0
while index < 5:
    name = songTitles[index] 
    artist = songArtist[index]
    
    #print(name)
    #print(artist)
    song_id = query['tracks']['items'][0]['id']
    song_uri = query['tracks']['items'][0]['uri']
    
    print(results['artists']['items'][0]['genres'])
    results = sp.search(q='artist:' + name, type='artist')
    #print(results)
    #
    #if 'genres' in results['artists']['items'][0]:
    if results['artists']['items'][0]['genres'] != []:
        items = results['artists']['items'][0]['genres']
        #print(items)

        for i in items:
            if len(items.intersection(top5)) > 0:
                a = sp.audio_features(song_uri)
                if i == "pop":
                    popDance.append(a[0]['danceability'])
                    popEnergy.append(a[0]['energy'])
                    popLoudness.append(a[0]['loudness'])
                    popTempo.append(a[0]['tempo'])
                    popDuration.append(a[0]['Instrumentalness'])
                    popAcoustic.append(a[0]['Acousticness'])
                
                if i == "contemporary country":
                    contemporaryDance.append(a[0]['danceability'])
                    contemporaryEnergy.append(a[0]['energy'])
                    contemporaryLoudness.append(a[0]['loudness'])
                    contemporaryTempo.append(a[0]['tempo'])
                    contemporaryDuration.append(a[0]['Instrumentalness'])
                    contemporaryAcoustic.append(a[0]['Acousticness'])
                    
                if i == "dance pop":
                        danceDance.append(a[0]['danceability'])
                        danceEnergy.append(a[0]['energy'])
                        danceLoudness.append(a[0]['loudness'])
                        danceTempo.append(a[0]['tempo'])
                        danceDuration.append(a[0]['Instrumentalness'])
                        danceAcoustic.append(a[0]['Acousticness'])
                
                if i == "post-teen pop":
                        teenDance.append(a[0]['danceability'])
                        teenEnergy.append(a[0]['energy'])
                        teenLoudness.append(a[0]['loudness'])
                        teenTempo.append(a[0]['tempo'])
                        teenDuration.append(a[0]['Instrumentalness'])
                        teenAcoustic.append(a[0]['Acousticness'])
                
                if i == "country":
                        countryDance.append(a[0]['danceability'])
                        countryEnergy.append(a[0]['energy'])
                        countryLoudness.append(a[0]['loudness'])
                        countryTempo.append(a[0]['tempo'])
                        countryDuration.append(a[0]['Instrumentalness'])
                        countryAcoustic.append(a[0]['Acousticness'])
    index = index + 1

# print(popDance)
# print(teenDance)
# print(contemporaryDance)
# print(countryDance)
# print(danceDance)

# %%
import statistics

dancedict = {}
energydict = {}
loudnessdict = {}
tempodict = {}
durationdict = {}
acousticdict = {}

print("best audio features for Pop")
print("dance:")
print(statistics.mean(popDance))
dancedict["pop"] = statistics.mean(popDance)
print("energy:")
print(statistics.mean(popEnergy))
energydict["pop"] = statistics.mean(popEnergy)
print("loudness:")
print(statistics.mean(popLoudness))
loudnessdict["pop"] = statistics.mean(popLoudness)
print("tempo:")
print(statistics.mean(popTempo))
tempodict["pop"] = statistics.mean(popTempo)
print("instrumentalness:")
print(statistics.mean(popInstrumentalness))
durationdict["pop"] = statistics.mean(popInstrumentalness)
print("acousticness:")
print(statistics.mean(popAcousticness))
acousticdict["pop"] = statistics.mean(popAcousticness)
print()

print("best audio features for Contemporary Country")
print("dance:")
print(statistics.mean(contemporaryDance))
dancedict["contemporary"] = statistics.mean(contemporaryDance)
print("energy:")
print(statistics.mean(contemporaryEnergy))
energydict["contemporary"] = statistics.mean(contemporaryEnergy)
print("loudness:")
print(statistics.mean(contemporaryLoudness))
loudnessdict["contemporary"] = statistics.mean(contemporaryLoudness)
print("tempo:")
print(statistics.mean(contemporaryTempo))
tempodict["contemporary"] = statistics.mean(contemporaryTempo)
print("instrumentalness:")
print(statistics.mean(contemporaryInstrumentalness))
durationdict["contemporary"] = statistics.mean(contemporaryInstrumentalness)
print("acousticness:")
print(statistics.mean(contemporaryAcousticness))
acousticdict["contemporary"] = statistics.mean(contemporaryAcousticness)
print()

print("best audio features for Dance Pop")
print("dance:")
print(statistics.mean(danceDance))
dancedict["dance"] = statistics.mean(danceDance)
print("energy:")
print(statistics.mean(danceEnergy))
energydict["dance"] = statistics.mean(danceEnergy)
print("loudness:")
print(statistics.mean(danceLoudness))
loudnessdict["dance"] = statistics.mean(danceLoudness)
print("tempo:")
print(statistics.mean(danceTempo))
tempodict["dance"] = statistics.mean(danceTempo)
print("instrumentalness:")
print(statistics.mean(danceInstrumentalness))
durationdict["dance"] = statistics.mean(danceInstrumentalness)
print("acousticness:")
print(statistics.mean(danceAcousticness))
acousticdict["dance"] = statistics.mean(danceAcousticness)
print()

print("best audio features for Post-teen Pop")
print("dance:")
print(statistics.mean(teenDance))
dancedict["teen"] = statistics.mean(teenDance)
print("energy:")
print(statistics.mean(teenEnergy))
energydict["teen"] = statistics.mean(teenEnergy)
print("loudness:")
print(statistics.mean(teenLoudness))
loudnessdict["teen"] = statistics.mean(teenLoudness)
print("tempo:")
print(statistics.mean(teenTempo))
tempodict["teen"] = statistics.mean(teenTempo)
print("instrumentalness:")
print(statistics.mean(teenInstrumentalness))
durationdict["teen"] = statistics.mean(teenInstrumentalness)
print("acousticness:")
print(statistics.mean(teenAcousticness))
acousticdict["teen"] = statistics.mean(teenAcousticness)
print()

print("best audio features for Country")
print("dance:")
print(statistics.mean(countryDance))
dancedict["country"] = statistics.mean(countryDance)
print("energy:")
print(statistics.mean(countryEnergy))
energydict["country"] = statistics.mean(countryEnergy)
print("loudness:")
print(statistics.mean(countryLoudness))
loudnessdict["country"] = statistics.mean(countryLoudness)
print("tempo:")
print(statistics.mean(countryTempo))
tempodict["country"] = statistics.mean(countryTempo)
print("instrumentalness:")
print(statistics.mean(countryInstrumentalness))
durationdict["country"] = statistics.mean(countryInstrumentalness)
print("acousticness:")
print(statistics.mean(countryAcousticness))
acousticdict["country"] = statistics.mean(countryAcousticness)
print()
# Out:
# best audio features for Pop
# dance:
# 0.5911782178217821
# energy:
# 0.6331089108910891
# loudness:
# -6.252381188118812
# tempo:
# 111.85607425742575
# instrumentalness:
# 0.009733678910891089
# acousticness:
# 0.25114935643564357
#
# best audio features for Contemporary Country
# dance:
# 0.5833826086956522
# energy:
# 0.7188086956521739
# loudness:
# -5.208947826086956
# tempo:
# 124.57712173913043
# instrumentalness:
# 0.000150108
# acousticness:
# 0.23532904347826086
#
# best audio features for Dance Pop
# dance:
# 0.6403644859813085
# energy:
# 0.6313644859813085
# loudness:
# -6.160813084112149
# tempo:
# 112.77695327102803
# instrumentalness:
# 0.01836525925233645
# acousticness:
# 0.20944672897196262
#
# best audio features for Post-teen Pop
# dance:
# 0.5936470588235294
# energy:
# 0.6067254901960785
# loudness:
# -6.388176470588236
# tempo:
# 107.52854901960784
# instrumentalness:
# 0.004562422941176471
# acousticness:
# 0.2843843137254902
#
# best audio features for Country
# dance:
# 0.5746633663366336
# energy:
# 0.7257722772277228
# loudness:
# -5.172881188118812
# tempo:
# 124.89243564356435
# instrumentalness:
# 0.00017091504950495049
# acousticness:
# 0.24000732673267328

# %%
import matplotlib.pyplot as plt


plt.title('Dance')
plt.bar(dancedict.keys(), dancedict.values())
# Out:
# <BarContainer object of 5 artists>

# %%
plt.title('Energy')
print(plt.bar(energydict.keys(), energydict.values()))
# Out:
# <BarContainer object of 5 artists>

# %%
plt.title('Loudness')
print(plt.bar(loudnessdict.keys(), loudnessdict.values()))
# Out:
# <BarContainer object of 5 artists>

# %%
plt.title('Tempo')
print(plt.bar(tempodict.keys(), tempodict.values()))
# Out:
# <BarContainer object of 5 artists>

# %%
plt.title('Instrumental')
print(plt.bar(durationdict.keys(), durationdict.values()))
# Out:
# <BarContainer object of 5 artists>

# %%
plt.title('Acoustic')
print(plt.bar(acousticdict.keys(), acousticdict.values()))
# Out:
# <BarContainer object of 5 artists>

# %%
for uri in songURI:
    print(song)
    a = sp.audio_features(tracks = [song_uri])
    print()

# %%
spotify_albums = {}
album_count = 0

# %%
for a in artistSet:
    name = a #chosen artist
    result = sp.search(name) #search query
    #result['tracks']['items'][0]['artists']

    #Extract Artist's uri
    artist_uri = result['tracks']['items'][0]['artists'][0]['uri']
    #Pull all of the artist's albums
    sp_albums = sp.artist_albums(artist_uri, album_type='album')
    #Store artist's albums' names' and uris in separate lists
    album_names = []
    album_uris = []
    
    #Extract Artist's uri
    artist_uri = result['tracks']['items'][0]['artists'][0]['uri']
    #Pull all of the artist's albums
    sp_albums = sp.artist_albums(artist_uri, album_type='album')
    #Store artist's albums' names' and uris in separate lists
    album_names = []
    album_uris = []
    
#     for i in range(len(sp_albums['items'])):
#         album_names.append(sp_albums['items'][i]['name'])
#         album_uris.append(sp_albums['items'][i]['uri'])
    
#     for i in album_uris: #each album
#         albumSongs(i)
#         print("Album " + str(album_names[album_count]) + " songs has been added to spotify_albums dictionary")
#         #album_count+=1 #Updates album count once all tracks have been added
    
    
#     sleep_min = 2
#     sleep_max = 5
#     start_time = time.time()
#     request_count = 0
#     for i in spotify_albums:
#         audio_features(i)
#         request_count+=1
#         if request_count % 5 == 0:
#             print(str(request_count) + " playlists completed")
#             time.sleep(np.random.uniform(sleep_min, sleep_max))
#             #print('Loop #: {}'.format(request_count))
#             #print('Elapsed Time: {} seconds'.format(time.time() - start_time))
    
#     dic_df = {}
#     dic_df['album'] = []
#     dic_df['track_number'] = []
#     dic_df['id'] = []
#     dic_df['name'] = []
#     dic_df['uri'] = []
#     dic_df['acousticness'] = []
#     dic_df['danceability'] = []
#     dic_df['energy'] = []
#     dic_df['instrumentalness'] = []
#     dic_df['liveness'] = []
#     dic_df['loudness'] = []
#     dic_df['speechiness'] = []
#     dic_df['tempo'] = []
#     dic_df['valence'] = []
#     dic_df['popularity'] = []
#     for album in spotify_albums: 
#         for feature in spotify_albums[album]:
#             dic_df[feature].extend(spotify_albums[album][feature])

#     len(dic_df['album'])

#     for i in range(len(dic_df['name'])):
#         if dic_df['name'][i] in songTitles:
#             print(dic_df['name'][i])
#             print(dic_df['popularity'][i])
#             print(dic_df['danceability'][i])
#             print(dic_df['liveness'][i])
            
#     for i in range(len(sp_albums['items'])):
#         album_names.append(sp_albums['items'][i]['name'])
#         album_uris.append(sp_albums['items'][i]['uri'])
    
#     for i in album_uris: #each album
#         albumSongs(i)
#         #print("Album " + str(album_names[album_count]) + " songs has been added to spotify_albums dictionary")
#         album_count+=1 #Updates album count once all tracks have been added
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-83-d1118a8a9444> in <module>
#       1 for a in artistSet:
#       2     name = a #chosen artist
# ----> 3     result = sp.search(name) #search query
#       4     #result['tracks']['items'][0]['artists']
#       5
#
# ~/anaconda3/lib/python3.7/site-packages/spotipy/client.py in search(self, q, limit, offset, type, market)
#     337                 - market - An ISO 3166-1 alpha-2 country code or the string from_token.
#     338         '''
# --> 339         return self._get('search', q=q, limit=limit, offset=offset, type=type, market=market)
#     340
#     341     def user(self, user):
#
# ~/anaconda3/lib/python3.7/site-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     144         while retries > 0:
#     145             try:
# --> 146                 return self._internal_call('GET', url, payload, kwargs)
#     147             except SpotifyException as e:
#     148                 retries -= 1
#
# ~/anaconda3/lib/python3.7/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     106         if self.trace_out:
#     107             print(url)
# --> 108         r = self._session.request(method, url, headers=headers, proxies=self.proxies, **args)
#     109
#     110         if self.trace:  # pragma: no cover
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     341         # Trigger any extra validation we need to do.
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#     345             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     837         # Force connect early to allow us to validate the connection.
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#     841         if not conn.is_verified:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     299     def connect(self):
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#     303
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     157         try:
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#     161         except SocketTimeout as e:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      68             if source_address:
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#      72
#
# KeyboardInterrupt:

# %%
    #Extract Artist's uri
    artist_uri = result['tracks']['items'][0]['artists'][0]['uri']
    #Pull all of the artist's albums
    sp_albums = sp.artist_albums(artist_uri, album_type='album')
    #Store artist's albums' names' and uris in separate lists
    album_names = []
    album_uris = []
    for i in range(len(sp_albums['items'])):
        album_names.append(sp_albums['items'][i]['name'])
        album_uris.append(sp_albums['items'][i]['uri'])
#Keep names and uris in same order to keep track of duplicate albums
# Out:
# ['spotify:album:1gMxiQQSg5zeu4htBosASY',
#  'spotify:album:4gCNyS7pidfK3rKWhB3JOY',
#  'spotify:album:3XTK1sQfPaaTwQvsO0o5mY',
#  'spotify:album:7p1fX8aUySrBdx4WSYspOu',
#  'spotify:album:1BTF8r9zpGVuymP6QBC3r9',
#  'spotify:album:6l7RpHJcIxG3UcA4ITTC2e',
#  'spotify:album:5SxEsi1PNyo1XfEKDYcFKF',
#  'spotify:album:3Cq8bOhMlOAoY9zCHPicwr',
#  'spotify:album:6cunQQ7YZisYOoiFu2ywIq',
#  'spotify:album:7qfrZ8W7EbA3Hm5TqrkMtX',
#  'spotify:album:1SjJJYvFuMaR0j2zSJRT41',
#  'spotify:album:53DrBEDi1AvhWOtCdljUiu',
#  'spotify:album:5nVUqrdkEMlWTm9sqjrYBt']

# %%
def albumSongs(uri):
    album = uri #assign album uri to a_name
    spotify_albums[album] = {} #Creates dictionary for that specific album
    #Create keys-values of empty lists inside nested dictionary for album
    spotify_albums[album]['album'] = [] #create empty list
    spotify_albums[album]['track_number'] = []
    spotify_albums[album]['id'] = []
    spotify_albums[album]['name'] = []
    spotify_albums[album]['uri'] = []
    tracks = sp.album_tracks(album) #pull data on album tracks
    for n in range(len(tracks['items'])): #for each song track
        spotify_albums[album]['album'].append(album_names[album_count]) #append album name tracked via album_count
        spotify_albums[album]['track_number'].append(tracks['items'][n]['track_number'])
        spotify_albums[album]['id'].append(tracks['items'][n]['id'])
        spotify_albums[album]['name'].append(tracks['items'][n]['name'])
        spotify_albums[album]['uri'].append(tracks['items'][n]['uri'])

# %%
for i in album_uris: #each album
    albumSongs(i)
    print("Album " + str(album_names[album_count]) + " songs has been added to spotify_albums dictionary")
    album_count+=1 #Updates album count once all tracks have been added
# Out:
# Album Made In The A.M. (Deluxe Edition) songs has been added to spotify_albums dictionary
# Album FOUR (Deluxe) songs has been added to spotify_albums dictionary
# Album Midnight Memories songs has been added to spotify_albums dictionary
# Album Midnight Memories (Deluxe) songs has been added to spotify_albums dictionary
# Album Take Me Home: Special Deluxe Edition songs has been added to spotify_albums dictionary
# Album Take Me Home songs has been added to spotify_albums dictionary
# Album Take Me Home: Yearbook Edition songs has been added to spotify_albums dictionary
# Album Up All Night songs has been added to spotify_albums dictionary
# Album Up All Night songs has been added to spotify_albums dictionary
# Album Up All Night songs has been added to spotify_albums dictionary
# Album Up All Night songs has been added to spotify_albums dictionary
# Album Up All Night songs has been added to spotify_albums dictionary
# Album Up All Night songs has been added to spotify_albums dictionary

# %%
def audio_features(album):
    #Add new key-values to store audio features
    spotify_albums[album]['acousticness'] = []
    spotify_albums[album]['danceability'] = []
    spotify_albums[album]['energy'] = []
    spotify_albums[album]['instrumentalness'] = []
    spotify_albums[album]['liveness'] = []
    spotify_albums[album]['loudness'] = []
    spotify_albums[album]['speechiness'] = []
    spotify_albums[album]['tempo'] = []
    spotify_albums[album]['valence'] = []
    spotify_albums[album]['popularity'] = []
    #create a track counter
    track_count = 0
    for track in spotify_albums[album]['uri']:
        #pull audio features per track
        features = sp.audio_features(track)
        
        #Append to relevant key-value
        spotify_albums[album]['acousticness'].append(features[0]['acousticness'])
        spotify_albums[album]['danceability'].append(features[0]['danceability'])
        spotify_albums[album]['energy'].append(features[0]['energy'])
        spotify_albums[album]['instrumentalness'].append(features[0]['instrumentalness'])
        spotify_albums[album]['liveness'].append(features[0]['liveness'])
        spotify_albums[album]['loudness'].append(features[0]['loudness'])
        spotify_albums[album]['speechiness'].append(features[0]['speechiness'])
        spotify_albums[album]['tempo'].append(features[0]['tempo'])
        spotify_albums[album]['valence'].append(features[0]['valence'])
        #popularity is stored elsewhere
        pop = sp.track(track)
        spotify_albums[album]['popularity'].append(pop['popularity'])
        track_count+=1

# %%
import time
import numpy as np
sleep_min = 2
sleep_max = 5
start_time = time.time()
request_count = 0
for i in spotify_albums:
    audio_features(i)
    request_count+=1
    if request_count % 5 == 0:
        print(str(request_count) + " playlists completed")
        time.sleep(np.random.uniform(sleep_min, sleep_max))
        print('Loop #: {}'.format(request_count))
        print('Elapsed Time: {} seconds'.format(time.time() - start_time))
# Out:
# 5 playlists completed
# Loop #: 5
# Elapsed Time: 98.6119749546051 seconds
# 10 playlists completed
# Loop #: 10
# Elapsed Time: 192.86661005020142 seconds

# %%
dic_df = {}
dic_df['album'] = []
dic_df['track_number'] = []
dic_df['id'] = []
dic_df['name'] = []
dic_df['uri'] = []
dic_df['acousticness'] = []
dic_df['danceability'] = []
dic_df['energy'] = []
dic_df['instrumentalness'] = []
dic_df['liveness'] = []
dic_df['loudness'] = []
dic_df['speechiness'] = []
dic_df['tempo'] = []
dic_df['valence'] = []
dic_df['popularity'] = []
for album in spotify_albums: 
    for feature in spotify_albums[album]:
        dic_df[feature].extend(spotify_albums[album][feature])
        
len(dic_df['album'])

for i in range(len(dic_df['name'])):
    if dic_df['name'][i] in songTitles:0
        print(dic_df['name'][i])
        print(dic_df['popularity'][i])
        print(dic_df['danceability'][i])
        print(dic_df['liveness'][i])
# Out:
# ['Hey Angel', 'Drag Me Down', 'Perfect', 'Infinity', 'End of the Day', 'If I Could Fly', 'Long Way Down', 'Never Enough', 'Olivia', 'What a Feeling', 'Love You Goodbye', 'I Want to Write You a Song', 'History', 'Temporary Fix', 'Walking in the Wind', 'Wolves', 'A.M.', 'Steal My Girl', 'Ready to Run', 'Where Do Broken Hearts Go', '18', 'Girl Almighty', "Fool's Gold", 'Night Changes', 'No Control', 'Fireproof', 'Spaces', 'Stockholm Syndrome', 'Clouds', 'Change Your Ticket', 'Illusion', 'Once in a Lifetime', 'Act My Age', 'Best Song Ever', 'Story of My Life', 'Diana', 'Midnight Memories', 'You & I', "Don't Forget Where You Belong", 'Strong', 'Happily', 'Right Now', 'Little Black Dress', 'Through the Dark', 'Something Great', 'Little White Lies', 'Better Than Words', 'Best Song Ever', 'Story of My Life', 'Diana', 'Midnight Memories', 'You & I', "Don't Forget Where You Belong", 'Strong', 'Happily', 'Right Now', 'Little Black Dress', 'Through the Dark', 'Something Great', 'Little White Lies', 'Better Than Words', "Why Don't We Go There", 'Does He Know?', 'Alive', 'Half a Heart', "Live While We're Young", 'Kiss You', 'Little Things', "C'mon, C'mon", 'Last First Kiss', 'Heart Attack', 'Rock Me', 'Change My Mind', 'I Would', 'Over Again', 'Back For You', "They Don't Know About Us", 'Summer Love', "She's Not Afraid", 'Loved You First', 'Nobody Compares', 'Still The One', 'Truly Madly Deeply', 'Magic', 'Irresistible', "Live While We're Young - Dave Aude Remix", 'Kiss You - Sharoque Remix', "Live While We're Young", 'Kiss You', 'Little Things', "C'mon, C'mon", 'Last First Kiss', 'Heart Attack', 'Rock Me', 'Change My Mind', 'I Would', 'Over Again', 'Back For You', "They Don't Know About Us", 'Summer Love', "Live While We're Young", 'Kiss You', 'Little Things', "C'mon, C'mon", 'Last First Kiss', 'Heart Attack', 'Rock Me', 'Change My Mind', 'I Would', 'Over Again', 'Back For You', "They Don't Know About Us", 'Summer Love', "She's Not Afraid", 'Loved You First', 'Nobody Compares', 'Still The One', 'What Makes You Beautiful', 'Gotta Be You', 'One Thing', 'More Than This', 'Up All Night', 'I Wish', 'Tell Me a Lie', 'Taken', 'I Want', 'Everything About You', 'Same Mistakes', 'Save You Tonight', 'Stole My Heart', 'Stand Up', 'Moments', 'Another World', 'Na Na Na', 'I Should Have Kissed You', 'What Makes You Beautiful', 'Gotta Be You', 'One Thing', 'More Than This', 'Up All Night', 'I Wish', 'Tell Me a Lie', 'Taken', 'I Want', 'Everything About You', 'Same Mistakes', 'Save You Tonight', 'Stole My Heart', 'Stand Up', 'Moments', 'Another World', 'Na Na Na', 'I Should Have Kissed You', 'What Makes You Beautiful', 'Gotta Be You', 'One Thing', 'More Than This', 'Up All Night', 'I Wish', 'Tell Me a Lie', 'Taken', 'I Want', 'Everything About You', 'Same Mistakes', 'Save You Tonight', 'Stole My Heart', 'Stand Up', 'Moments', 'What Makes You Beautiful', 'Gotta Be You', 'One Thing', 'More Than This', 'Up All Night', 'I Wish', 'Tell Me a Lie', 'Taken', 'I Want', 'Everything About You', 'Same Mistakes', 'Save You Tonight', 'Stole My Heart', 'What Makes You Beautiful', 'Gotta Be You', 'One Thing', 'More Than This', 'Up All Night', 'I Wish', 'Tell Me a Lie', 'Taken', 'I Want', 'Everything About You', 'Same Mistakes', 'Save You Tonight', 'Stole My Heart', 'What Makes You Beautiful', 'Gotta Be You', 'One Thing', 'More Than This', 'Up All Night', 'I Wish', 'Tell Me a Lie', 'Taken', 'I Want', 'Everything About You', 'Same Mistakes', 'Save You Tonight', 'Stole My Heart']
# Perfect
# 75
# 0.647
# 0.119
# ['Hey Angel', 'Drag Me Down', 'Perfect', 'Infinity', 'End of the Day', 'If I Could Fly', 'Long Way Down', 'Never Enough', 'Olivia', 'What a Feeling', 'Love You Goodbye', 'I Want to Write You a Song', 'History', 'Temporary Fix', 'Walking in the Wind', 'Wolves', 'A.M.', 'Steal My Girl', 'Ready to Run', 'Where Do Broken Hearts Go', '18', 'Girl Almighty', "Fool's Gold", 'Night Changes', '
 'What Makes You Beautiful', 'Gotta Be You', 'One Thing', 'More Than This', 'Up All Night', 'I Wish', 'Tell Me a Lie', 'Taken', 'I Want', 'Everything About You', 'Same Mistakes', 'Save You Tonight', 'Stole My Heart', 'Stand Up', 'Moments', 'Another World', 'Na Na Na', 'I Should Have Kissed You', 'What Makes You Beautiful', 'Gotta Be You', 'One Thing', 'More Than This', 'Up All Night', 'I Wish', 'Tell Me a Lie', 'Taken', 'I Want', 'Everything About You', 'Same Mistakes', 'Save You Tonight', 'Stole My Heart', 'Stand Up', 'Moments', 'Another World', 'Na Na Na', 'I Should Have Kissed You', 'What Makes You Beautiful', 'Gotta Be You', 'One Thing', 'More Than This', 'Up All Night', 'I Wish', 'Tell Me a Lie', 'Taken', 'I Want', 'Everything About You', 'Same Mistakes', 'Save You Tonight', 'Stole My Heart', 'Stand Up', 'Moments', 'What Makes You Beautiful', 'Gotta Be You', 'One Thing', 'More Than This', 'Up All Night', 'I Wish', 'Tell Me a Lie', 'Taken', 'I Want', 'Everything About You', 'Same Mistakes', 'Save You Tonight', 'Stole My Heart', 'What Makes You Beautiful', 'Gotta Be You', 'One Thing', 'More Than This', 'Up All Night', 'I Wish', 'Tell Me a Lie', 'Taken', 'I Want', 'Everything About You', 'Same Mistakes', 'Save You Tonight', 'Stole My Heart', 'What Makes You Beautiful', 'Gotta Be You', 'One Thing', 'More Than This', 'Up All Night', 'I Wish', 'Tell Me a Lie', 'Taken', 'I Want', 'Everything About You', 'Same Mistakes', 'Save You Tonight', 'Stole My Heart']
# Night Changes
# 77
# 0.672
# 0.115
# ['Hey Angel', 'Drag Me Down', 'Perfect', 'Infinity', 'End of the Day', 'If I Could Fly', 'Long Way Down', 'Never Enough', 'Olivia', 'What a Feeling', 'Love You Goodbye', 'I Want to Write You a Song', 'History', 'Temporary Fix', 'Walking in the Wind', 'Wolves', 'A.M.', 'Steal My Girl', 'Ready to Run', 'Where Do Broken Hearts Go', '18', 'Girl Almighty', "Fool's Gold", 'Night Changes', 'No Control', 'Fireproof', 'Spaces', 'Stockholm Syndrome', 'Clouds', 'Change Your Ticket', 'Illusion', 'Once in a Lifetime', 'Act My Age', 'Best Song Ever', 'Story of My Life', 'Diana', 'Midnight Memories', 'You & I', "Don't Forget Where You Belong", 'Strong', 'Happily', 'Right Now', 'Little Black Dress', 'Through the Dark', 'Something Great', 'Little White Lies', 'Better Than Words', 'Best Song Ever', 'Story of My Life', 'Diana', 'Midnight Memories', 'You & I', "Don't Forget Where You Belong", 'Strong', 'Happily', 'Right Now', 'Little Black Dress', 'Through the Dark', 'Something Great', 'Little White Lies', 'Better Than Words', "Why Don't We Go There", 'Does He Know?', 'Alive', 'Half a Heart', "Live While We're Young", 'Kiss You', 'Little Things', "C'mon, C'mon", 'Last First Kiss', 'Heart Attack', 'Rock Me', 'Change My Mind', 'I Would', 'Over Again', 'Back For You', "They Don't Know About Us", 'Summer Love', "She's Not Afraid", 'Loved You First', 'Nobody Compares', 'Still The One', 'Truly Madly Deeply', 'Magic', 'Irresistible', "Live While We're Young - Dave Aude Remix", 'Kiss You - Sharoque Remix', "Live While We're Young", 'Kiss You', 'Little Things', "C'mon, C'mon", 'Last First Kiss', 'Heart Attack', 'Rock Me', 'Change My Mind', 'I Would', 'Over Again', 'Back For You', "They Don't Know About Us", 'Summer Love', "Live While We're Young", 'Kiss You', 'Little Things', "C'mon, C'mon", 'Last First Kiss', 'Heart Attack', 'Rock Me', 'Change My Mind', 'I Would', 'Over Again', 'Back For You', "They Don't Know About Us", 'Summer Love', "She's Not Afraid", 'Loved You First', 'Nobody Compares', 'Still The One', 'What Makes You Beautiful', 'Gotta Be You', 'One Thing', 'More Than This', 'Up All Night', 'I Wish', 'Tell Me a Lie', 'Taken', 'I Want', 'Everything About You', 'Same Mistakes', 'Save You Tonight', 'Stole My Heart', 'Stand Up', 'Moments', 'Another World', 'Na Na Na', 'I Should Have Kissed You', 'What Makes You Beautiful', 'Gotta Be You', 'One Thing', 'More Than This', 'Up All Night', 'I Wish', 'Tell Me a Lie', 'Taken', 'I Want', 'Everything About You', 'Same Mistakes', 'Save You Tonight', 'Stole My Heart', 'Stand Up', 'Moments', 'Another World', 'Na Na Na', 'I Should Have Kissed You', 'What Makes You Beautiful', 'Gotta Be You', 'One Thing', 'More Than This', 'Up All Night', 'I Wish', 'Tell Me a Lie', 'Taken', 'I Want', 'Everything About You', 'Same Mistakes', 'Save You Tonight', 'Stole My Heart', 'Stand Up', 'Moments', 'What Makes You Beautiful', 'Gotta Be You', 'One Thing', 'More Than This', 'Up All Night', 'I Wish', 'Tell Me a Lie', 'Taken', 'I Want', 'Everything About You', 'Same Mistakes', 'Save You Tonight', 'Stole My Heart', 'What Makes You Beautiful', 'Gotta Be You', 'One Thing', 'More Than This', 'Up All Night', 'I Wish', 'Tell Me a Lie', 'Taken', 'I Want', 'Everything About You', 'Same Mistakes', 'Save You Tonight', 'Stole My Heart', 'What Makes You Beautiful', 'Gotta Be You', 'One Thing', 'More Than This', 'Up All Night', 'I Wish', 'Tell Me a Lie', 'Taken', 'I Want', 'Everything About You', 'Same Mistakes', 'Save You Tonight', 'Stole My Heart']
# Irresistible
# 18
# 0.536
# 0.113

# %%
import pandas as pd
df = pd.DataFrame.from_dict(dic_df)

print(len(df))
final_df = df.sort_values('popularity', ascending=False).drop_duplicates('name').sort_index()
print(len(final_df))
# Out:
# 141
# 32
