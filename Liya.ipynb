# %%
import billboard
from datetime import timedelta, date
import time
d = {}
def daterange(start_date, end_date):
    for n in range(int ((end_date - start_date).days)):
        yield start_date + timedelta(n)

start_date = date(2018, 1, 7)
end_date = date(2019, 11, 26)
fileSong = open("liya.txt", "x")
for single_date in daterange(start_date, end_date):
    if single_date.weekday() == 0:
        day = single_date.strftime("%Y-%m-%d")
        
        while True:
            try:
                chart = billboard.ChartData('hot-100', date=day)
                #chart2 = billboard.ChartData('artist-100', date=day)
                break
            except:
                print('waiting 60 sec...')
                time.sleep(60)
        
        for s in chart:
            fileSong = open("liya.txt", "a")
            fileSong.write(s.title + ": " + s.artist + "\n")
# Out:
# waiting 60 sec...
# waiting 60 sec...
# waiting 60 sec...
# waiting 60 sec...
# waiting 60 sec...
# waiting 60 sec...
# waiting 60 sec...
# waiting 60 sec...
# waiting 60 sec...
# waiting 60 sec...

# %%
artistArray = []
for line in open("Songtest.txt"):
    data = line.split(": ")
    artist = data[1]
    index = line.find('\\')
    artistArray.append(artist[0: index])
artistSet = set(artistArray)
print(artistSet)
# Out:
# {'Big Sean & Metro Boomin Featuring Travis Scott', 'Macklemore Featuring Skylar Grey', 'Maroon 5 Featuring SZA', 'Kesha', 'Rich Gang Featuring Young Thug & Rich Homie Quan', 'G-Eazy Featuring Remo', 'Parmalee', 'Sam Smith', 'Florida Georgia Line', 'Chris Brown & Tyga', 'Ne-Yo Featuring Juicy J', 'Louis Tomlinson Featuring Bebe Rexha & Digital Farm Animals', 'Wisin Featuring Ozuna', 'Migos Featuring Lil Uzi Vert', 'Migos & Marshmello', 'Miguel Featuring Travis Scott', 'Playboi Carti', 'Luis Fonsi & Demi Lovato', 'Trey Songz Featuring Nicki Minaj', 'The Chainsmokers Featuring Halsey', 'Future', 'Meek Mill', 'MAGIC!', 'G-Eazy', 'Kendrick Lamar', 'Childish Gambino', 'Wiz Khalifa Featuring Ty Dolla $ign', 'Billy Currington', 'Offset & Metro Boomin', 'Kodak Black Featuring Lil Wayne', 'Maroon 5 Featuring Kendrick Lamar', 'Gucci Mane Featuring Slim Jxmmi & Young Dolph', '21 Savage & Metro Boomin', 'Sam Hunt', 'Natti Natasha x Ozuna', 'DJ Khaled Featuring Justin Bieber, Quavo, Chance The Rapper & Lil Wayne', 'Migos, Nicki Minaj & Cardi B', 'Metro Boomin Featuring Offset & Drake', 'Jacquees', 'LANCO', 'Zac Brown Band', 'Enrique Iglesias Featuring Descemer Bueno, Zion & Lennox Or Sean Paul', '21 Savage', 'Post Malone Featuring 21 Savage', 'Camila Cabello Featuring Young Thug', 'Justin Moore', 'Linkin Park Featuring Kiiara', 'Mariah Carey', 'Calvin Harris Featuring Ellie Goulding', 'James Arthur', 'Jake Owen', 'JAY-Z', 'SZA Featuring Travis Scott', 'A$AP Ferg Featuring Nicki Minaj', 'Becky G', 'Eric Church', 'Kygo x Selena Gomez', 'Jason Aldean', 'Travis Scott', 'Meek Mill Featuring Lil Uzi Vert', 'blackbear', 'WALK THE MOON', 'Hozier', 'Wham!', 'Shawn Mendes', 'Luke Combs', 'John Legend', 'Sia', 'Logic Featuring Alessia Cara & Khalid', 'Selena Gomez X Marshmello', 'Nicki Minaj Featuring Drake & Lil Wayne', 'Taylor Swift', 'Kelly Clarkson', 'David Guetta Featuring Sam Martin', 'P!nk', 'Big Sean Featuring E-40', 'Nicky Jam', 'DJ Khaled Featuring Chris Brown, August Alsina, Future & Jeremih', 'Fergie', 'Liam Payne', 'Famous Dex Featuring A$AP Rocky', 'Kesha Featuring The Dap-Kings Horns', 'Farruko, Nicki Minaj, Bad Bunny, 21 Savage & Rvssian', 'Kane Brown', 'One Direction', 'Big Sean', 'Kane Brown Featuring Lauren Alaina', 'Sofia Carson, Cameron Boyce, Booboo Stewart & Mitchell Hope', 'Lil Xan', 'A Boogie Wit da Hoodie', 'Brett Eldredge', 'Bebe Rexha & Florida Georgia Line', 'Iggy Azalea Featuring Rita Ora', 'Tay-K', 'Dua Lipa', 'MAX Featuring gnash', 'Taylor Swift Featuring Ed Sheeran & Future', 'Future Featuring Nicki Minaj', '6ix9ine', 'NF', 'J. Cole', 'Young Thug Featuring Future', 'Lil Uzi Vert Featuring Nicki Minaj', 'Chris Stapleton', 'Calvin Harris Featuring John Newman', 'Nicki Minaj Featuring Drake, Lil Wayne & Chris Brown', 'Lil Baby', 'The Weeknd Featuring Daft Punk', 'Lil Uzi Vert Featuring Pharrell Williams', 'Pitbull & Ne-Yo', 'Bruno Mars', 'YBN Nahmir', 'Lorde Featuring Khalid, Post Malone & SZA', 'Trey Songz', 'Jake Paul Featuring Team 10', 'Dierks Bentley', 'Devin Dawson', 'Tim McGraw & Faith Hill', 'Natalie La Rose Featuring Jeremih', 'Cardi B', 'Burl Ives', 'Alesso Featuring Tove Lo', 'Taylor Swift Featuring Kendrick Lamar', 'RaeLynn', 'Brothers Osborne', 'A Boogie Wit da Hoodie Featuring Kodak Black', 'Major Lazer Featuring Travis Scott, Camila Cabello & Quavo', 'Sia Featuring Sean Paul', 'Keith Urban', 'David Guetta Featuring Justin Bieber', 'Yo Gotti Featuring Nicki Minaj', 'Hailee Steinfeld', 'Russ', 'Omarion Featuring Chris Brown & Jhene Aiko', 'Luke Bryan', 'SZA', 'Hailee Steinfeld & Grey Featuring Zedd', 'Darius Rucker', 'Steve Aoki & Louis Tomlinson', 'Khalid', 'Ariana Grande & The Weeknd', 'Sam Smith Featuring Logic', 'Maren Morris Featuring Vince Gill', 'Wale Featuring Jeremih', 'Chris Young', 'Sheppard', 'Tee Grizzley', 'Beyonce', 'Russell Dickerson', 'Lil Uzi Vert Featuring The Weeknd', 'Drake', 'Jason Derulo', 'The Weeknd', 'DJ Snake Featuring Justin Bieber', 'Thomas Rhett Featuring Maren Morris', 'Macklemo ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials #To access authorised Spotify data

client_id = "93d31c01487f4b4c982f44ba2d6546a4"
client_secret = "9d8244915bda4809958c7771e3ae5fc9"
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager) #spotify object to access API

for artist in artistArray:
    name = artist #chosen artist
    result = sp.search(name) #search query
    
    
print(result['tracks']['items'][0]['artists'])

artist_uri = result['tracks']['items'][0]['artists'][0]['uri']
print(artist_uri)

#Pull all of the artist's albums
sp_albums = sp.artist_albums(artist_uri, album_type='album')
#Store artist's albums' names' and uris in separate lists
album_names = []
album_uris = []
for i in range(len(sp_albums['items'])):
    album_names.append(sp_albums['items'][i]['name'])
    album_uris.append(sp_albums['items'][i]['uri'])
    
print(album_names)
print(album_uris)
#Keep names and uris in same order to keep track of duplicate albums
# Out:
# Taylor Swift
# Mark Ronson Featuring Bruno Mars
# Hozier
# Meghan Trainor
# Meghan Trainor
# Sam Smith
# Ed Sheeran
# Maroon 5
# Taylor Swift
# Nick Jonas
# Ariana Grande & The Weeknd
# Big Sean Featuring E-40
# Selena Gomez
# Fall Out Boy
# Nicki Minaj Featuring Drake, Lil Wayne & Chris Brown
# James Newton Howard Featuring Jennifer Lawrence
# Jessie J, Ariana Grande & Nicki Minaj
# I LOVE MAKONNEN Featuring Drake
# Rae Sremmurd
# Tove Lo
# Mr. Probz
# Ed Sheeran
# Bobby Shmurda
# Sam Smith
# Beyonce
# O.T. Genasis
# Iggy Azalea Featuring M0
# Jeremih Featuring YG
# Iggy Azalea Featuring Rita Ora
# Jason Derulo
# Calvin Harris Featuring John Newman
# Vance Joy
# Usher Featuring Juicy J
# One Direction
# MAGIC!
# Alesso Featuring Tove Lo
# Carrie Underwood
# Fergie
# Sia
# Fifth Harmony
# Tim McGraw
# Rich Gang Featuring Young Thug & Rich Homie Quan
# Ella Henderson
# Clean Bandit Featuring Jess Glynne
# DeJ Loaf
# Pitbull & Ne-Yo
# Milky Chance
# Nicki Minaj
# The Weeknd
# Ariana Grande
# One Direction
# Eric Church
# Florida Georgia Line
# Imagine Dragons
# DJ Khaled Featuring Chris Brown, August Alsina, Future & Jeremih
# Trey Songz Featuring Nicki Minaj
# Luke Bryan
# Flo Rida Featuring Sage The Gemini & Lookas
# Nicki Minaj Featuring Beyonce
# Lee Brice
# RaeLynn
# OneRepublic
# Brad Paisley
# Meghan Trainor
# The Weeknd
# Colbie Caillat
# Pentatonix
# Jessie J
# Blake Shelton Featuring Ashley Monroe
# David Guetta Featuring Sam Martin
# Lillywood & Robin Schulz
# Kid Ink Featuring Usher & Tinashe
# Ne-Yo Featuring Juicy J
# Jason Aldean
# Beyonce Featuring Nicki Minaj Or Chimamanda Ngozi Adichie
# Thomas Rhett
# Chris Young
# Taylor Swift Featuring Kendrick Lamar
# Nico & Vinz
# Nicki Minaj Featuring Skylar Grey
# Kenny Chesney
# Keith Urban
# Brett Eldredge
# Taylor Swift
# Parmalee
# Darius Rucker
# Jessie J Featuring 2 Chainz
# August Alsina
# WALK THE MOON
# Lorde
# Charli XCX
# Shawn Mendes
# Prince Royce Featuring Snoop Dogg
# J. Cole
# French Montana Featuring Jeremih
# Randy Houser
# Blake Shelton
# Becky G
# Juicy J, Wiz Khalifa & Ty Dolla $ign Featuring Kill The Noise & Madsonik
# Meghan Trainor
# Mark Ronson Featuring Bruno Mars
# Taylor Swift
# Hozier
# Ed Sheeran
# Meghan Trainor
# Meghan Trainor
# Taylor Swift
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-bc1adc916672> in <module>
#       9 for artist in artistArray:
#      10     name = artist #chosen artist
# ---> 11     result = sp.search(name) #search query
#      12     print(name)
#      13
#
# ~/anaconda3/lib/python3.7/site-packages/spotipy/client.py in search(self, q, limit, offset, type, market)
#     337                 - market - An ISO 3166-1 alpha-2 country code or the string from_token.
#     338         '''
# --> 339         return self._get('search', q=q, limit=limit, offset=offset, type=type, market=market)
#     340
#     341     def user(self, user):
#
# ~/anaconda3/lib/python3.7/site-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     144         while retries > 0:
#     145             try:
# --> 146                 return self._internal_call('GET', url, payload, kwargs)
#     147             except SpotifyException as e:
#     148                 retries -= 1
#
# ~/anaconda3/lib/python3.7/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     106         if self.trace_out:
#     107             print(url)
# --> 108         r = self._session.request(method, url, headers=headers, proxies=self.proxies, **args)
#     109
#     110         if self.trace:  # pragma: no cover
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# ~/anaconda3/lib/python3.7/http/client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# ~/anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     295     def recv_into(self, *args, **kwargs):
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#     299             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1819             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820         else:
# -> 1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# KeyboardInterrupt:
